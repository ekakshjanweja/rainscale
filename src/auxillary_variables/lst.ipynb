# %%
# %pip install rioxarray
# %pip install xarray
# %pip install earthengine-api rasterio
# %pip install geopandas
# %pip install gdal==$(gdal-config --version) geemap
# %pip install setuptools

# %%
import ee
ee.Authenticate()
ee.Initialize(project='btech-project-443813')

# %% [markdown]
# ### Donwload LST Composite 8 Day (Not Working)

# %%
import ee
import geemap
import os
from datetime import datetime, timedelta

def get_composite_lst(start_date, roi):
    """Get 8-day composite LST"""
    try:
        ee_start_date = ee.Date(start_date.strftime('%Y-%m-%d'))
        ee_end_date = ee_start_date.advance(8, 'day')
        
        dataset = ee.ImageCollection('MODIS/061/MOD11A2') \
            .filterDate(ee_start_date, ee_end_date) \
            .filterBounds(roi)
        
        lst_image = dataset.mean()  # Use mean to get composite
        
        if dataset.size().getInfo() == 0:
            raise Exception("No LST data available for this period")
        
        qc = lst_image.select('QC_Day').toUint8()
        
        good_quality = qc.bitwiseAnd(ee.Number(3)).eq(0)
        
        return lst_image.select('LST_Day_1km').multiply(0.02).subtract(273.15).updateMask(good_quality).clip(roi)
    
    except Exception as e:
        print(f"Error processing LST composite for {start_date.strftime('%Y-%m-%d')}: {str(e)}")
        raise

def download_composite_lst(start_date, roi, output_directory):
    """Download 8-day composite LST"""
    try:
        date_str = start_date.strftime('%Y-%m-%d')
        lst = get_composite_lst(start_date, roi)
        filename = os.path.join(output_directory, f'lst_delhi_composite_{date_str}.tif')
        
        region = roi.getInfo()['coordinates'][0]
        
        geemap.ee_export_image(
            lst,
            filename=filename,
            scale=1000,  # 1km resolution
            region=region,
            crs='EPSG:4326',
            file_per_band=False
        )
        
        if os.path.exists(filename):
            file_size = os.path.getsize(filename)
            print(f"Successfully downloaded LST composite for {date_str} (Size: {file_size/1024:.1f} KB)")
            return True
        else:
            print(f"Failed to download LST composite for {date_str}")
            return False
            
    except Exception as e:
        print(f"Error downloading LST composite for {date_str}: {str(e)}")
        return False

def main():
    ee.Initialize()
    
    roi = ee.Geometry.Rectangle([
        76.8,
        28.4,
        77.6,
        28.9 
    ])
    
    start_date = datetime(2000, 1, 1)
    end_date = datetime(2023, 12, 31)
    
    output_directory = r"/home/stormej/dev/rainscale/data/lst/lst_tif_temp"
    os.makedirs(output_directory, exist_ok=True)
    
    current_date = start_date
    successful_downloads = 0
    failed_downloads = 0
    
    print(f"\nStarting download of 8-day composite LST data from {start_date.strftime('%Y-%m-%d')} to {end_date.strftime('%Y-%m-%d')}...")
    
    while current_date <= end_date:
        try:
            print(f"\nProcessing {current_date.strftime('%Y-%m-%d')} to {(current_date + timedelta(days=7)).strftime('%Y-%m-%d')}")
            
            if download_composite_lst(current_date, roi, output_directory):
                successful_downloads += 1
            else:
                failed_downloads += 1
                
        except Exception as e:
            print(f"Error processing {current_date.strftime('%Y-%m-%d')}: {str(e)}")
            failed_downloads += 1
            
        # Move to the next 8-day period
        current_date += timedelta(days=8)
    
    print("\nDownload Summary:")
    print(f"Successfully downloaded: {successful_downloads} periods")
    print(f"Failed downloads: {failed_downloads} periods")
    print("Process completed.")

if __name__ == "__main__":
    main()

# %% [markdown]
# ### Create Monthly LST

# %%
import os
import glob
import numpy as np
import rasterio
from datetime import datetime
from collections import defaultdict

def fill_nan_values(data_array, method='nearest_neighbor', max_search_radius=100):
    filled_array = np.copy(data_array)
    if not np.isnan(filled_array).any():
        return filled_array
    
    if method == 'global_mean':
        valid_mean = np.nanmean(filled_array)
        filled_array = np.where(np.isnan(filled_array), valid_mean, filled_array)
    
    elif method == 'nearest_neighbor':
        nan_mask = np.isnan(filled_array)
        nan_indices = np.where(nan_mask)
        for i, j in zip(nan_indices[0], nan_indices[1]):
            value_set = False
            for radius in range(1, max_search_radius + 1):
                i_min, i_max = max(0, i - radius), min(filled_array.shape[0], i + radius + 1)
                j_min, j_max = max(0, j - radius), min(filled_array.shape[1], j + radius + 1)
                neighborhood = filled_array[i_min:i_max, j_min:j_max]
                if np.count_nonzero(~np.isnan(neighborhood)) > 0:
                    filled_array[i, j] = np.nanmean(neighborhood)
                    value_set = True
                    break
            if not value_set and not np.isnan(filled_array[~np.isnan(filled_array)]).all():
                filled_array[i, j] = np.nanmean(filled_array[~np.isnan(filled_array)])
    return filled_array

def calculate_lst_monthly_averages(input_dir, output_dir, start_date=None, end_date=None):
    os.makedirs(output_dir, exist_ok=True)
    if start_date:
        start_date = datetime.strptime(start_date, '%Y-%m-%d')
    if end_date:
        end_date = datetime.strptime(end_date, '%Y-%m-%d')
    
    lst_files = glob.glob(os.path.join(input_dir, 'lst_delhi_composite_*.tif'))
    print(f"Found {len(lst_files)} LST files")
    
    monthly_files = defaultdict(list)
    for file_path in lst_files:
        filename = os.path.basename(file_path)
        date_str = filename.split('_')[-1].split('.')[0]
        date = datetime.strptime(date_str, '%Y-%m-%d')
        
        if start_date and date < start_date:
            continue
        if end_date and date > end_date:
            continue
            
        month_key = date.strftime('%Y-%m')
        monthly_files[month_key].append(file_path)
    
    print(f"Processing {len(monthly_files)} months")
    
    for month_key, files in monthly_files.items():
        print(f"Processing {month_key} with {len(files)} files")
        
        with rasterio.open(files[0]) as src:
            metadata = src.profile
            data_shape = src.shape
        
        data_sum = np.zeros(data_shape)
        data_count = np.zeros(data_shape)
        
        for file_path in files:
            with rasterio.open(file_path) as src:
                data = src.read(1).astype(float)
                if src.nodata is not None:
                    mask = (data == src.nodata)
                    data[mask] = np.nan
                
                valid_mask = ~np.isnan(data)
                data_sum[valid_mask] += data[valid_mask]
                data_count[valid_mask] += 1
        
        with np.errstate(divide='ignore', invalid='ignore'):
            monthly_avg = np.where(data_count > 0, data_sum / data_count, np.nan)
        
        # Fill NaN values in the monthly average
        monthly_avg = fill_nan_values(monthly_avg, method='nearest_neighbor')
        
        metadata.update({
            'dtype': rasterio.float32,
            'nodata': np.nan
        })
        
        output_file = os.path.join(output_dir, f'lst_delhi_{month_key}.tif')
        with rasterio.open(output_file, 'w', **metadata) as dst:
            dst.write(monthly_avg.astype(rasterio.float32), 1)
        
        print(f"  Saved {output_file}")
    
    print(f"Successfully processed {len(monthly_files)} monthly averages")

input_dir = "/home/stormej/dev/rainscale/data/lst/lst_tif"
output_dir = "/home/stormej/dev/rainscale/data/lst/lst_monthly_avg"

calculate_lst_monthly_averages(input_dir, output_dir)
# Out:
# Found 1055 LST files
# Processing 278 months
# Processing 2000-02 with 2 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2000-02.tif
# Processing 2000-03 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2000-03.tif
# Processing 2000-04 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2000-04.tif
# Processing 2000-05 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2000-05.tif
# Processing 2000-06 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2000-06.tif
# Processing 2000-07 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2000-07.tif
# Processing 2000-08 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2000-08.tif
# Processing 2000-09 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2000-09.tif
# Processing 2000-10 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2000-10.tif
# Processing 2000-11 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2000-11.tif
# Processing 2000-12 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2000-12.tif
# Processing 2001-01 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2001-01.tif
# Processing 2001-02 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2001-02.tif
# Processing 2001-03 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2001-03.tif
# Processing 2001-04 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2001-04.tif
# Processing 2001-05 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2001-05.tif
# Processing 2001-06 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2001-06.tif
# Processing 2001-07 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2001-07.tif
# Processing 2001-08 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2001-08.tif
# Processing 2001-09 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2001-09.tif
# Processing 2001-10 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2001-10.tif
# Processing 2001-11 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2001-11.tif
# Processing 2001-12 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2001-12.tif
# Processing 2002-01 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2002-01.tif
# Processing 2002-02 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2002-02.tif
# Processing 2002-03 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2002-03.tif
# Processing 2002-04 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2002-04.tif
# Processing 2002-05 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2002-05.tif
# Processing 2002-06 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2002-06.tif
# Processing 2002-07 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2002-07.tif
# Processing 2002-08 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2002-08.tif
# Processing 2002-09 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2002-09.tif
# Processing 2002-10 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2002-10.tif
# Processing 2002-11 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2002-11.tif
# Processing 2002-12 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2002-12.tif
# Processing 2003-01 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2003-01.tif
# Processing 2003-02 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2003-02.tif
# Processing 2003-03 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2003-03.tif
# Processing 2003-04 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2003-04.tif
# Processing 2003-05 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2003-05.tif
# Processing 2003-06 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2003-06.tif
# Processing 2003-07 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2003-07.tif
# Processing 2003-08 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2003-08.tif
# Processing 2003-09 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2003-09.tif
# Processing 2003-10 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2003-10.tif
# Processing 2003-11 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2003-11.tif
# Processing 2003-12 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2003-12.tif
# Processing 2004-01 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2004-01.tif
# Processing 2004-02 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2004-02.tif
# Processing 2004-03 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2004-03.tif
# Processing 2004-04 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2004-04.tif
# Processing 2004-05 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2004-05.tif
# Processing 2004-06 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2004-06.tif
# Processing 2004-07 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2004-07.tif
# Processing 2004-08 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2004-08.tif
# Processing 2004-09 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2004-09.tif
# Processing 2004-10 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2004-10.tif
# Processing 2004-11 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2004-11.tif
# Processing 2004-12 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2004-12.tif
# Processing 2005-01 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2005-01.tif
# Processing 2005-02 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2005-02.tif
# Processing 2005-03 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2005-03.tif
# Processing 2005-04 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2005-04.tif
# Processing 2005-05 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2005-05.tif
# Processing 2005-06 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2005-06.tif
# Processing 2005-07 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2005-07.tif
# Processing 2005-08 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2005-08.tif
# Processing 2005-09 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2005-09.tif
# Processing 2005-10 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2005-10.tif
# Processing 2005-11 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2005-11.tif
# Processing 2005-12 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2005-12.tif
# Processing 2006-01 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2006-01.tif
# Processing 2006-02 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2006-02.tif
# Processing 2006-03 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2006-03.tif
# Processing 2006-04 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2006-04.tif
# Processing 2006-05 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2006-05.tif
# Processing 2006-06 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2006-06.tif
# Processing 2006-07 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2006-07.tif
# Processing 2006-08 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2006-08.tif
# Processing 2006-09 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2006-09.tif
# Processing 2006-10 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2006-10.tif
# Processing 2006-11 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2006-11.tif
# Processing 2006-12 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2006-12.tif
# Processing 2007-01 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2007-01.tif
# Processing 2007-02 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2007-02.tif
# Processing 2007-03 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2007-03.tif
# Processing 2007-04 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2007-04.tif
# Processing 2007-05 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2007-05.tif
# Processing 2007-06 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2007-06.tif
# Processing 2007-07 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2007-07.tif
# Processing 2007-08 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2007-08.tif
# Processing 2007-09 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2007-09.tif
# Processing 2007-10 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2007-10.tif
# Processing 2007-11 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2007-11.tif
# Processing 2007-12 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2007-12.tif
# Processing 2008-01 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2008-01.tif
# Processing 2008-02 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2008-02.tif
# Processing 2008-03 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2008-03.tif
# Processing 2008-04 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2008-04.tif
# Processing 2008-05 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2008-05.tif
# Processing 2008-06 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2008-06.tif
# Processing 2008-07 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2008-07.tif
# Processing 2008-08 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2008-08.tif
# Processing 2008-09 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2008-09.tif
# Processing 2008-10 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2008-10.tif
# Processing 2008-11 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2008-11.tif
# Processing 2008-12 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2008-12.tif
# Processing 2009-01 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2009-01.tif
# Processing 2009-02 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2009-02.tif
# Processing 2009-03 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2009-03.tif
# Processing 2009-04 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2009-04.tif
# Processing 2009-05 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2009-05.tif
# Processing 2009-06 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2009-06.tif
# Processing 2009-07 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2009-07.tif
# Processing 2009-08 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2009-08.tif
# Processing 2009-09 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2009-09.tif
# Processing 2009-10 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2009-10.tif
# Processing 2009-11 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2009-11.tif
# Processing 2009-12 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2009-12.tif
# Processing 2010-01 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2010-01.tif
# Processing 2010-02 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2010-02.tif
# Processing 2010-03 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2010-03.tif
# Processing 2010-04 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2010-04.tif
# Processing 2010-05 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2010-05.tif
# Processing 2010-06 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2010-06.tif
# Processing 2010-07 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2010-07.tif
# Processing 2010-08 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2010-08.tif
# Processing 2010-09 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2010-09.tif
# Processing 2010-10 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2010-10.tif
# Processing 2010-11 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2010-11.tif
# Processing 2010-12 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2010-12.tif
# Processing 2011-01 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2011-01.tif
# Processing 2011-02 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2011-02.tif
# Processing 2011-03 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2011-03.tif
# Processing 2011-04 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2011-04.tif
# Processing 2011-05 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2011-05.tif
# Processing 2011-06 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2011-06.tif
# Processing 2011-07 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2011-07.tif
# Processing 2011-08 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2011-08.tif
# Processing 2011-09 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2011-09.tif
# Processing 2011-10 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2011-10.tif
# Processing 2011-11 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2011-11.tif
# Processing 2011-12 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2011-12.tif
# Processing 2012-01 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2012-01.tif
# Processing 2012-02 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2012-02.tif
# Processing 2012-03 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2012-03.tif
# Processing 2012-04 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2012-04.tif
# Processing 2012-05 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2012-05.tif
# Processing 2012-06 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2012-06.tif
# Processing 2012-07 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2012-07.tif
# Processing 2012-08 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2012-08.tif
# Processing 2012-09 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2012-09.tif
# Processing 2012-10 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2012-10.tif
# Processing 2012-11 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2012-11.tif
# Processing 2012-12 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2012-12.tif
# Processing 2013-01 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2013-01.tif
# Processing 2013-02 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2013-02.tif
# Processing 2013-03 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2013-03.tif
# Processing 2013-04 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2013-04.tif
# Processing 2013-05 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2013-05.tif
# Processing 2013-06 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2013-06.tif
# Processing 2013-07 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2013-07.tif
# Processing 2013-08 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2013-08.tif
# Processing 2013-09 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2013-09.tif
# Processing 2013-10 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2013-10.tif
# Processing 2013-11 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2013-11.tif
# Processing 2013-12 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2013-12.tif
# Processing 2014-01 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2014-01.tif
# Processing 2014-02 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2014-02.tif
# Processing 2014-03 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2014-03.tif
# Processing 2014-04 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2014-04.tif
# Processing 2014-05 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2014-05.tif
# Processing 2014-06 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2014-06.tif
# Processing 2014-07 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2014-07.tif
# Processing 2014-08 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2014-08.tif
# Processing 2014-09 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2014-09.tif
# Processing 2014-10 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2014-10.tif
# Processing 2014-11 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2014-11.tif
# Processing 2014-12 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2014-12.tif
# Processing 2015-01 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2015-01.tif
# Processing 2015-02 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2015-02.tif
# Processing 2015-03 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2015-03.tif
# Processing 2015-04 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2015-04.tif
# Processing 2015-05 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2015-05.tif
# Processing 2015-06 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2015-06.tif
# Processing 2015-07 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2015-07.tif
# Processing 2015-08 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2015-08.tif
# Processing 2015-09 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2015-09.tif
# Processing 2015-10 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2015-10.tif
# Processing 2015-11 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2015-11.tif
# Processing 2015-12 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2015-12.tif
# Processing 2016-01 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2016-01.tif
# Processing 2016-02 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2016-02.tif
# Processing 2016-03 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2016-03.tif
# Processing 2016-04 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2016-04.tif
# Processing 2016-05 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2016-05.tif
# Processing 2016-06 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2016-06.tif
# Processing 2016-07 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2016-07.tif
# Processing 2016-08 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2016-08.tif
# Processing 2016-09 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2016-09.tif
# Processing 2016-10 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2016-10.tif
# Processing 2016-11 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2016-11.tif
# Processing 2016-12 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2016-12.tif
# Processing 2017-01 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2017-01.tif
# Processing 2017-02 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2017-02.tif
# Processing 2017-03 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2017-03.tif
# Processing 2017-04 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2017-04.tif
# Processing 2017-05 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2017-05.tif
# Processing 2017-06 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2017-06.tif
# Processing 2017-07 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2017-07.tif
# Processing 2017-08 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2017-08.tif
# Processing 2017-09 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2017-09.tif
# Processing 2017-10 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2017-10.tif
# Processing 2017-11 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2017-11.tif
# Processing 2017-12 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2017-12.tif
# Processing 2018-01 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2018-01.tif
# Processing 2018-02 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2018-02.tif
# Processing 2018-03 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2018-03.tif
# Processing 2018-04 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2018-04.tif
# Processing 2018-05 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2018-05.tif
# Processing 2018-06 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2018-06.tif
# Processing 2018-07 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2018-07.tif
# Processing 2018-08 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2018-08.tif
# Processing 2018-09 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2018-09.tif
# Processing 2018-10 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2018-10.tif
# Processing 2018-11 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2018-11.tif
# Processing 2018-12 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2018-12.tif
# Processing 2019-01 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2019-01.tif
# Processing 2019-02 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2019-02.tif
# Processing 2019-03 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2019-03.tif
# Processing 2019-04 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2019-04.tif
# Processing 2019-05 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2019-05.tif
# Processing 2019-06 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2019-06.tif
# Processing 2019-07 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2019-07.tif
# Processing 2019-08 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2019-08.tif
# Processing 2019-09 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2019-09.tif
# Processing 2019-10 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2019-10.tif
# Processing 2019-11 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2019-11.tif
# Processing 2019-12 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2019-12.tif
# Processing 2020-01 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2020-01.tif
# Processing 2020-02 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2020-02.tif
# Processing 2020-03 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2020-03.tif
# Processing 2020-04 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2020-04.tif
# Processing 2020-05 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2020-05.tif
# Processing 2020-06 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2020-06.tif
# Processing 2020-07 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2020-07.tif
# Processing 2020-08 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2020-08.tif
# Processing 2020-09 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2020-09.tif
# Processing 2020-10 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2020-10.tif
# Processing 2020-11 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2020-11.tif
# Processing 2020-12 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2020-12.tif
# Processing 2021-01 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2021-01.tif
# Processing 2021-02 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2021-02.tif
# Processing 2021-03 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2021-03.tif
# Processing 2021-04 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2021-04.tif
# Processing 2021-05 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2021-05.tif
# Processing 2021-06 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2021-06.tif
# Processing 2021-07 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2021-07.tif
# Processing 2021-08 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2021-08.tif
# Processing 2021-09 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2021-09.tif
# Processing 2021-10 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2021-10.tif
# Processing 2021-11 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2021-11.tif
# Processing 2021-12 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2021-12.tif
# Processing 2022-01 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2022-01.tif
# Processing 2022-02 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2022-02.tif
# Processing 2022-03 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2022-03.tif
# Processing 2022-04 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2022-04.tif
# Processing 2022-05 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2022-05.tif
# Processing 2022-06 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2022-06.tif
# Processing 2022-07 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2022-07.tif
# Processing 2022-08 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2022-08.tif
# Processing 2022-09 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2022-09.tif
# Processing 2022-10 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2022-10.tif
# Processing 2022-11 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2022-11.tif
# Processing 2022-12 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2022-12.tif
# Processing 2023-01 with 3 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2023-01.tif
# Processing 2023-02 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2023-02.tif
# Processing 2023-03 with 4 files
#   Saved /home/stormej/dev/rainscale/data/lst/lst_monthly_avg/lst_delhi_2023-03.tif
# Successfully processed 278 monthly averages

# %% [markdown]
# ### Resample LST to 0.25 degree

# %%
import os
import rasterio
from rasterio.enums import Resampling
from affine import Affine

input_dir = r"/home/stormej/dev/rainscale/data/lst/lst_monthly_avg"
output_dir = r"/home/stormej/dev/rainscale/data/lst/lst_monthly_resampled_0.25"
os.makedirs(output_dir, exist_ok=True)

crs = 'EPSG:4326'
shape = (3, 5)
transform = Affine(0.25, 0, 76.5, 0, -0.25, 28.9)

for file in os.listdir(input_dir):
    if file.endswith('.tif'):
        path = os.path.join(input_dir, file)
        with rasterio.open(path) as src:
            resample = src.read(
                out_shape = (1, shape[0], shape[1]),
                resampling= Resampling.average,
            )
        parts = file.split('_')
        month = parts[2].replace('.tif', '')
        
        output_filename = f"lst_resampled_{month}.tif"
        output_path = os.path.join(output_dir, output_filename)
        
        with rasterio.open(
            output_path,
            'w',
            driver='GTiff',
            height=shape[0],
            width=shape[1],
            count=1,
            dtype=resample.dtype,
            crs=crs,
            transform=transform,
        ) as dst:
            dst.write(resample[0], 1)
        
print("All LST images resampled successfully.")
# Out:
# All LST images resampled successfully.

# %% [markdown]
# ### Resample LST to 0.01 degree

# %%
import os
import rasterio
from rasterio.enums import Resampling
from affine import Affine


bounds = {
    'min_lon': 76.5,  # Western boundary of Delhi
    'max_lon': 77.5,  # Eastern boundary of Delhi
    'min_lat': 28.3,  # Southern boundary of Delhi
    'max_lat': 28.9   # Northern boundary of Delhi
}

input_dir = r"/home/stormej/dev/rainscale/data/lst/lst_monthly_avg"
output_dir = r"/home/stormej/dev/rainscale/data/lst/lst_monthly_resampled_0.01"
os.makedirs(output_dir, exist_ok=True)

crs = 'EPSG:4326'
width = int((bounds['max_lon'] - bounds['min_lon']) / 0.01)  # 100 pixels
height = int((bounds['max_lat'] - bounds['min_lat']) / 0.01)  # 60 pixels
shape = (height, width)
transform = Affine(0.01, 0, bounds['min_lon'], 0, -0.01, bounds['max_lat'])


for file in os.listdir(input_dir):
    if file.endswith('.tif'):
        path = os.path.join(input_dir, file)
        with rasterio.open(path) as src:
            resample = src.read(
                out_shape = (1, shape[0], shape[1]),
                resampling= Resampling.average,
            )
        parts = file.split('_')
        month = parts[2].replace('.tif', '')
        
        output_filename = f"lst_resampled_{month}.tif"
        output_path = os.path.join(output_dir, output_filename)
        
        with rasterio.open(
            output_path,
            'w',
            driver='GTiff',
            height=shape[0],
            width=shape[1],
            count=1,
            dtype=resample.dtype,
            crs=crs,
            transform=transform,
        ) as dst:
            dst.write(resample[0], 1)
        
print("All LST images resampled successfully.")
# Out:
# All LST images resampled successfully.

# %% [markdown]
# ### Resample LST to 0.1 degree

# %%
import os
import rasterio
from rasterio.enums import Resampling
from affine import Affine


bounds = {
    'min_lon': 76.5,  # Western boundary of Delhi
    'max_lon': 77.5,  # Eastern boundary of Delhi
    'min_lat': 28.3,  # Southern boundary of Delhi
    'max_lat': 28.9   # Northern boundary of Delhi
}

input_dir = r"/home/stormej/dev/rainscale/data/lst/lst_monthly_avg"
output_dir = r"/home/stormej/dev/rainscale/data/lst/lst_monthly_resampled_0.1"
os.makedirs(output_dir, exist_ok=True)

crs = 'EPSG:4326'
width = int((bounds['max_lon'] - bounds['min_lon']) / 0.1)  # 10 pixels
height = int((bounds['max_lat'] - bounds['min_lat']) / 0.1)  # 6 pixels
shape = (height, width)
transform = Affine(0.1, 0, bounds['min_lon'], 0, -0.1, bounds['max_lat'])


for file in os.listdir(input_dir):
    if file.endswith('.tif'):
        path = os.path.join(input_dir, file)
        with rasterio.open(path) as src:
            resample = src.read(
                out_shape = (1, shape[0], shape[1]),
                resampling= Resampling.average,
            )
        parts = file.split('_')
        month = parts[2].replace('.tif', '')
        
        output_filename = f"lst_resampled_{month}.tif"
        output_path = os.path.join(output_dir, output_filename)
        
        with rasterio.open(
            output_path,
            'w',
            driver='GTiff',
            height=shape[0],
            width=shape[1],
            count=1,
            dtype=resample.dtype,
            crs=crs,
            transform=transform,
        ) as dst:
            dst.write(resample[0], 1)
        
print("All LST images resampled successfully.")
# Out:
# All LST images resampled successfully.
