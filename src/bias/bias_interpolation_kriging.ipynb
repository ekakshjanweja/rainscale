# %% [markdown]
# ### Interpolate Bias Obtained at 0.25 Degree to 0.01 Degree Using Kriging Interpolation

# %%
# %pip install pykrige

# %%
import os 
import rasterio
from pykrige.ok import OrdinaryKriging
from rasterio.mask import mask
from shapely.geometry import box, Point, Polygon
import geopandas as gpd
import numpy as np

def create_bounds(src_bounds, dst_shape, dst_transform):
    rows, cols = dst_shape
    mask = np.zeros((rows, cols), dtype=bool)
    
    xs = np.linspace(dst_transform[2], 
                    dst_transform[2] + cols * dst_transform[0], 
                    cols)
    ys = np.linspace(dst_transform[5], 
                    dst_transform[5] + rows * dst_transform[4], 
                    rows)
    boundary = box(src_bounds.left, src_bounds.bottom,
                  src_bounds.right, src_bounds.top).buffer(0.1)
    
    X, Y = np.meshgrid(xs, ys)
    points = np.column_stack((X.ravel(), Y.ravel()))
    
    batch_size = 10000
    
    for i in range(0, len(points), batch_size):
        batch_points = points[i:i+batch_size]
        batch_results = [boundary.contains(Point(x, y)) for x, y in batch_points]
        mask.ravel()[i:i+batch_size] = batch_results
    
    return mask

def interpolate_tiff(input_dir, output_dir, variogram_model='spherical', max_points=1000):
    os.makedirs(output_dir, exist_ok=True)
    
    dst_crs = 'EPSG:4326'
    dst_bounds = (76.5, 28.31, 77.5, 28.9)
    width = int((dst_bounds[2] - dst_bounds[0]) / 0.01)
    height = int((dst_bounds[3] - dst_bounds[1]) / 0.01)
    dst_shape = (height, width)
    
    dst_transform = rasterio.transform.from_bounds(
        dst_bounds[0], dst_bounds[1], 
        dst_bounds[2], dst_bounds[3], 
        dst_shape[1], dst_shape[0]
    )
    
    dst_y, dst_x = np.mgrid[dst_bounds[1]:dst_bounds[3]:dst_shape[0]*1j,
                           dst_bounds[0]:dst_bounds[2]:dst_shape[1]*1j]
    
    tiff_files = sorted([f for f in os.listdir(input_dir) if f.endswith('.tif')])
    
    for file in tiff_files:
        try:
            input_path = os.path.join(input_dir, file)
            output_path = os.path.join(output_dir, file)
            
            with rasterio.open(input_path) as src:
                src_data = src.read(1)
                nodata_value = src.nodata if src.nodata is not None else -9999
                src_mask = src_data != nodata_value
                
                profile = src.profile.copy()
                profile.update({
                    'crs': dst_crs,
                    'transform': dst_transform,
                    'width': dst_shape[1],
                    'height': dst_shape[0],
                    'nodata': nodata_value,
                })
                
                rows, cols = src_data.shape
                src_y, src_x = np.mgrid[src.bounds.bottom:src.bounds.top:rows*1j,
                                      src.bounds.left:src.bounds.right:cols*1j]
                
                valid_mask = (src_mask & 
                            ~np.isnan(src_data) & 
                            ~np.isinf(src_data) &
                            (src_data != nodata_value))
                
                x_valid = src_x[valid_mask].flatten()
                y_valid = src_y[valid_mask].flatten()
                z_valid = src_data[valid_mask].flatten()
                
                if len(z_valid) < 3:
                    print(f"Warning: Too few valid points ({len(z_valid)}) in {file}")
                    continue
                
                print(f"Number of valid points: {len(z_valid)}")
                print(f"X range: {np.min(x_valid):.2f} to {np.max(x_valid):.2f}")
                print(f"Y range: {np.min(y_valid):.2f} to {np.max(y_valid):.2f}")
                print(f"Z range: {np.min(z_valid):.2f} to {np.max(z_valid):.2f}")
                
                valid_min = np.min(z_valid)
                valid_max = np.max(z_valid)
                
                if len(z_valid) > max_points:
                    idx = np.random.choice(len(z_valid), max_points, replace=False)
                    x_valid = x_valid[idx]
                    y_valid = y_valid[idx]
                    z_valid = z_valid[idx]
                
                try:
                    boundary_mask = create_bounds(src.bounds, dst_shape, dst_transform)
                    
                    ok = OrdinaryKriging(
                        x_valid, y_valid, z_valid,
                        variogram_model=variogram_model,
                        verbose=False,
                        enable_plotting=False
                    )
                    
                    dst_array, _ = ok.execute('grid', dst_x[0, :], dst_y[:, 0])
                    
                    dst_array[~boundary_mask] = nodata_value
                    
                    valid_pixels = (dst_array != nodata_value) & ~np.isnan(dst_array)
                    if np.any(valid_pixels):
                        dst_array[valid_pixels] = np.clip(
                            dst_array[valid_pixels],
                            valid_min,
                            valid_max
                        )
                        
                        with rasterio.open(output_path, 'w', **profile) as dst:
                            dst.write(dst_array.astype(profile['dtype']), 1)
                            dst.update_tags(
                                interpolation_method=f'ordinary_kriging_{variogram_model}',
                                original_value_range=f"{valid_min:.2f} to {valid_max:.2f}",
                                valid_points_count=str(len(z_valid))
                            )
                        print(f"Successfully processed {file}")
                        print(f"Original value range: {valid_min:.2f} to {valid_max:.2f}")
                        print(f"Output value range: {np.min(dst_array[valid_pixels]):.2f} "
                              f"to {np.max(dst_array[valid_pixels]):.2f}")
                    else:
                        print(f"Warning: No valid pixels in output after masking for {file}")
                        
                except Exception as e:
                    print(f"Error in kriging for {file}: {str(e)}")
                    continue
        except Exception as e:
            print(f"Error processing {file}: {str(e)}")
            continue

def main():
    input_dir = r"/home/stormej/dev/rainscale/data/bias/bias_0.25"
    output_dir = r"/home/stormej/dev/rainscale/data/bias/bias_kriging_0.01"
    
    interpolate_tiff(input_dir, output_dir, variogram_model='spherical', max_points=1000)

main()
# Out:
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.32 to 45.95
# Successfully processed bias_2000_02.tif
# Original value range: -3.32 to 45.95
# Output value range: 6.48 to 6.48
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -12.33 to -1.15
# Successfully processed bias_2000_03.tif
# Original value range: -12.33 to -1.15
# Output value range: -11.80 to -4.02
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -15.45 to -2.04
# Successfully processed bias_2000_04.tif
# Original value range: -15.45 to -2.04
# Output value range: -15.26 to -5.02
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -21.97 to 0.76
# Successfully processed bias_2000_05.tif
# Original value range: -21.97 to 0.76
# Output value range: -16.43 to -0.96
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -19.28 to 63.18
# Successfully processed bias_2000_06.tif
# Original value range: -19.28 to 63.18
# Output value range: -12.66 to 59.27
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -53.60 to 107.48
# Successfully processed bias_2000_07.tif
# Original value range: -53.60 to 107.48
# Output value range: 2.28 to 74.74
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -24.30 to 230.10
# Successfully processed bias_2000_08.tif
# Original value range: -24.30 to 230.10
# Output value range: 9.69 to 186.21
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -51.20 to -7.88
# Successfully processed bias_2000_09.tif
# Original value range: -51.20 to -7.88
# Output value range: -22.20 to -22.20
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -20.43 to -1.87
# Successfully processed bias_2000_10.tif
# Original value range: -20.43 to -1.87
# Output value range: -18.57 to -7.09
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -14.81 to -0.35
# Successfully processed bias_2000_11.tif
# Original value range: -14.81 to -0.35
# Output value range: -14.22 to -1.29
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -4.38 to -0.34
# Successfully processed bias_2000_12.tif
# Original value range: -4.38 to -0.34
# Output value range: -4.29 to -1.08
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.41 to 12.70
# Successfully processed bias_2001_01.tif
# Original value range: -3.41 to 12.70
# Output value range: -1.11 to 9.55
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -9.18 to -1.16
# Successfully processed bias_2001_02.tif
# Original value range: -9.18 to -1.16
# Output value range: -3.82 to -3.08
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -8.13 to -0.01
# Successfully processed bias_2001_03.tif
# Original value range: -8.13 to -0.01
# Output value range: -6.51 to -2.15
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -7.69 to 6.37
# Successfully processed bias_2001_04.tif
# Original value range: -7.69 to 6.37
# Output value range: -6.35 to 4.15
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -20.37 to 53.07
# Successfully processed bias_2001_05.tif
# Original value range: -20.37 to 53.07
# Output value range: -13.06 to 43.08
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -11.82 to 98.45
# Successfully processed bias_2001_06.tif
# Original value range: -11.82 to 98.45
# Output value range: 8.21 to 95.75
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -33.47 to 76.05
# Successfully processed bias_2001_07.tif
# Original value range: -33.47 to 76.05
# Output value range: -32.40 to 73.26
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -20.82 to 127.92
# Successfully processed bias_2001_08.tif
# Original value range: -20.82 to 127.92
# Output value range: -7.61 to 80.48
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -42.92 to -8.45
# Successfully processed bias_2001_09.tif
# Original value range: -42.92 to -8.45
# Output value range: -40.24 to -13.97
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -23.95 to 9.73
# Successfully processed bias_2001_10.tif
# Original value range: -23.95 to 9.73
# Output value range: -22.70 to 2.41
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -5.04 to -0.26
# Successfully processed bias_2001_11.tif
# Original value range: -5.04 to -0.26
# Output value range: -4.78 to -1.25
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -5.31 to -0.36
# Successfully processed bias_2001_12.tif
# Original value range: -5.31 to -0.36
# Output value range: -4.76 to -1.96
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -1.36 to 13.93
# Successfully processed bias_2002_01.tif
# Original value range: -1.36 to 13.93
# Output value range: 1.64 to 11.84
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -4.67 to 13.70
# Successfully processed bias_2002_02.tif
# Original value range: -4.67 to 13.70
# Output value range: -2.01 to 9.92
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -10.44 to -1.45
# Successfully processed bias_2002_03.tif
# Original value range: -10.44 to -1.45
# Output value range: -9.94 to -3.94
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.50 to -2.20
# Successfully processed bias_2002_04.tif
# Original value range: -16.50 to -2.20
# Output value range: -15.28 to -7.09
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -14.16 to 111.61
# Successfully processed bias_2002_05.tif
# Original value range: -14.16 to 111.61
# Output value range: 5.30 to 100.81
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -23.23 to 40.54
# Successfully processed bias_2002_06.tif
# Original value range: -23.23 to 40.54
# Output value range: -12.88 to 37.88
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -50.22 to -8.30
# Successfully processed bias_2002_07.tif
# Original value range: -50.22 to -8.30
# Output value range: -45.49 to -18.69
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -76.27 to 250.94
# Successfully processed bias_2002_08.tif
# Original value range: -76.27 to 250.94
# Output value range: -56.59 to 21.00
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -21.67 to 134.50
# Successfully processed bias_2002_09.tif
# Original value range: -21.67 to 134.50
# Output value range: 20.36 to 122.12
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.23 to -1.82
# Successfully processed bias_2002_10.tif
# Original value range: -16.23 to -1.82
# Output value range: -14.95 to -5.90
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.99 to -0.26
# Successfully processed bias_2002_11.tif
# Original value range: -3.99 to -0.26
# Output value range: -3.86 to -1.25
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -0.76 to 10.79
# Successfully processed bias_2002_12.tif
# Original value range: -0.76 to 10.79
# Output value range: 0.29 to 10.37
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -4.22 to 24.19
# Successfully processed bias_2003_01.tif
# Original value range: -4.22 to 24.19
# Output value range: 1.58 to 1.58
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.34 to 53.29
# Successfully processed bias_2003_02.tif
# Original value range: -3.34 to 53.29
# Output value range: 6.41 to 51.86
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -8.78 to -1.15
# Successfully processed bias_2003_03.tif
# Original value range: -8.78 to -1.15
# Output value range: -6.56 to -3.74
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.67 to -2.21
# Successfully processed bias_2003_04.tif
# Original value range: -16.67 to -2.21
# Output value range: -15.99 to -5.87
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -23.67 to -2.87
# Successfully processed bias_2003_05.tif
# Original value range: -23.67 to -2.87
# Output value range: -22.22 to -7.71
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -49.43 to 37.91
# Successfully processed bias_2003_06.tif
# Original value range: -49.43 to 37.91
# Output value range: -22.39 to 33.31
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -58.79 to 479.64
# Successfully processed bias_2003_07.tif
# Original value range: -58.79 to 479.64
# Output value range: 16.03 to 442.86
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -19.74 to 214.97
# Successfully processed bias_2003_08.tif
# Original value range: -19.74 to 214.97
# Output value range: 16.69 to 179.86
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -21.76 to 121.76
# Successfully processed bias_2003_09.tif
# Original value range: -21.76 to 121.76
# Output value range: -14.88 to 59.73
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -17.37 to -1.81
# Successfully processed bias_2003_10.tif
# Original value range: -17.37 to -1.81
# Output value range: -16.37 to -6.69
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -12.89 to -0.27
# Successfully processed bias_2003_11.tif
# Original value range: -12.89 to -0.27
# Output value range: -11.08 to -2.12
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.28 to 32.34
# Successfully processed bias_2003_12.tif
# Original value range: -3.28 to 32.34
# Output value range: 0.72 to 19.53
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.31 to 13.44
# Successfully processed bias_2004_01.tif
# Original value range: -3.31 to 13.44
# Output value range: 0.07 to 13.16
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -10.39 to -1.07
# Successfully processed bias_2004_02.tif
# Original value range: -10.39 to -1.07
# Output value range: -10.05 to -3.74
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -10.80 to -1.46
# Successfully processed bias_2004_03.tif
# Original value range: -10.80 to -1.46
# Output value range: -10.14 to -3.67
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -6.92 to 22.65
# Successfully processed bias_2004_04.tif
# Original value range: -6.92 to 22.65
# Output value range: -5.74 to 6.67
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -6.01 to 31.45
# Successfully processed bias_2004_05.tif
# Original value range: -6.01 to 31.45
# Output value range: 2.72 to 30.35
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -14.18 to 14.52
# Successfully processed bias_2004_06.tif
# Original value range: -14.18 to 14.52
# Output value range: -12.44 to 11.06
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -54.07 to 3.07
# Successfully processed bias_2004_07.tif
# Original value range: -54.07 to 3.07
# Output value range: -50.41 to -15.01
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -26.87 to 292.07
# Successfully processed bias_2004_08.tif
# Original value range: -26.87 to 292.07
# Output value range: 23.20 to 289.56
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -49.22 to -7.88
# Successfully processed bias_2004_09.tif
# Original value range: -49.22 to -7.88
# Output value range: -42.89 to -16.53
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -6.28 to 97.52
# Successfully processed bias_2004_10.tif
# Original value range: -6.28 to 97.52
# Output value range: 17.81 to 17.81
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.17 to -0.28
# Successfully processed bias_2004_11.tif
# Original value range: -3.17 to -0.28
# Output value range: -3.06 to -1.01
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -6.85 to -0.33
# Successfully processed bias_2004_12.tif
# Original value range: -6.85 to -0.33
# Output value range: -2.56 to -1.94
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -4.81 to -0.71
# Successfully processed bias_2005_01.tif
# Original value range: -4.81 to -0.71
# Output value range: -3.59 to -1.91
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.25 to 36.80
# Successfully processed bias_2005_02.tif
# Original value range: -3.25 to 36.80
# Output value range: 3.48 to 27.29
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -2.40 to 19.82
# Successfully processed bias_2005_03.tif
# Original value range: -2.40 to 19.82
# Output value range: -2.15 to 15.23
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -19.94 to -2.33
# Successfully processed bias_2005_04.tif
# Original value range: -19.94 to -2.33
# Output value range: -18.90 to -6.35
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -15.57 to 5.89
# Successfully processed bias_2005_05.tif
# Original value range: -15.57 to 5.89
# Output value range: -6.31 to -4.14
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -14.69 to 25.76
# Successfully processed bias_2005_06.tif
# Original value range: -14.69 to 25.76
# Output value range: -14.30 to 25.05
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -28.49 to 238.77
# Successfully processed bias_2005_07.tif
# Original value range: -28.49 to 238.77
# Output value range: 9.92 to 172.50
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -31.57 to 15.38
# Successfully processed bias_2005_08.tif
# Original value range: -31.57 to 15.38
# Output value range: -26.57 to 8.60
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -24.15 to 210.14
# Successfully processed bias_2005_09.tif
# Original value range: -24.15 to 210.14
# Output value range: 11.72 to 152.54
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.48 to -1.80
# Successfully processed bias_2005_10.tif
# Original value range: -16.48 to -1.80
# Output value range: -15.38 to -5.33
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.30 to -0.26
# Successfully processed bias_2005_11.tif
# Original value range: -3.30 to -0.26
# Output value range: -3.17 to -0.99
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -5.66 to -0.40
# Successfully processed bias_2005_12.tif
# Original value range: -5.66 to -0.40
# Output value range: -2.14 to -1.90
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -7.85 to -0.67
# Successfully processed bias_2006_01.tif
# Original value range: -7.85 to -0.67
# Output value range: -7.45 to -2.73
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -12.13 to -1.07
# Successfully processed bias_2006_02.tif
# Original value range: -12.13 to -1.07
# Output value range: -11.64 to -4.04
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.95 to 25.35
# Successfully processed bias_2006_03.tif
# Original value range: -3.95 to 25.35
# Output value range: 2.01 to 23.94
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.88 to -2.25
# Successfully processed bias_2006_04.tif
# Original value range: -16.88 to -2.25
# Output value range: -16.23 to -7.10
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -13.05 to 0.23
# Successfully processed bias_2006_05.tif
# Original value range: -13.05 to 0.23
# Output value range: -9.37 to -3.83
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -17.45 to 32.16
# Successfully processed bias_2006_06.tif
# Original value range: -17.45 to 32.16
# Output value range: -13.08 to 2.42
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -30.16 to 271.54
# Successfully processed bias_2006_07.tif
# Original value range: -30.16 to 271.54
# Output value range: 7.33 to 89.52
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -38.56 to -5.53
# Successfully processed bias_2006_08.tif
# Original value range: -38.56 to -5.53
# Output value range: -36.81 to -13.53
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -17.67 to 68.21
# Successfully processed bias_2006_09.tif
# Original value range: -17.67 to 68.21
# Output value range: -4.82 to 52.99
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -14.86 to -1.30
# Successfully processed bias_2006_10.tif
# Original value range: -14.86 to -1.30
# Output value range: -4.98 to -4.98
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -4.86 to 5.00
# Successfully processed bias_2006_11.tif
# Original value range: -4.86 to 5.00
# Output value range: -3.31 to 1.44
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -5.37 to -0.37
# Successfully processed bias_2006_12.tif
# Original value range: -5.37 to -0.37
# Output value range: -4.94 to -1.57
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -6.83 to -0.65
# Successfully processed bias_2007_01.tif
# Original value range: -6.83 to -0.65
# Output value range: -4.40 to -2.54
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -6.06 to 43.30
# Successfully processed bias_2007_02.tif
# Original value range: -6.06 to 43.30
# Output value range: 8.09 to 31.55
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -2.46 to 55.28
# Successfully processed bias_2007_03.tif
# Original value range: -2.46 to 55.28
# Output value range: 9.79 to 53.11
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.23 to -2.04
# Successfully processed bias_2007_04.tif
# Original value range: -16.23 to -2.04
# Output value range: -12.69 to -6.29
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.91 to 4.98
# Successfully processed bias_2007_05.tif
# Original value range: -16.91 to 4.98
# Output value range: -7.38 to -3.02
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -11.95 to 65.59
# Successfully processed bias_2007_06.tif
# Original value range: -11.95 to 65.59
# Output value range: -7.72 to 55.33
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -18.74 to 68.25
# Successfully processed bias_2007_07.tif
# Original value range: -18.74 to 68.25
# Output value range: -6.24 to 65.54
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -21.39 to 61.16
# Successfully processed bias_2007_08.tif
# Original value range: -21.39 to 61.16
# Output value range: -17.50 to 48.28
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -49.94 to 31.56
# Successfully processed bias_2007_09.tif
# Original value range: -49.94 to 31.56
# Output value range: -25.04 to 6.22
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -18.46 to -1.82
# Successfully processed bias_2007_10.tif
# Original value range: -18.46 to -1.82
# Output value range: -18.22 to -4.88
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.08 to -0.30
# Successfully processed bias_2007_11.tif
# Original value range: -16.08 to -0.30
# Output value range: -15.56 to -2.32
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -5.83 to 2.81
# Successfully processed bias_2007_12.tif
# Original value range: -5.83 to 2.81
# Output value range: -1.94 to -1.20
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -9.71 to -0.81
# Successfully processed bias_2008_01.tif
# Original value range: -9.71 to -0.81
# Output value range: -9.49 to -2.54
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -15.72 to -1.16
# Successfully processed bias_2008_02.tif
# Original value range: -15.72 to -1.16
# Output value range: -14.83 to -5.06
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -15.44 to -1.62
# Successfully processed bias_2008_03.tif
# Original value range: -15.44 to -1.62
# Output value range: -15.10 to -4.39
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -15.12 to 3.27
# Successfully processed bias_2008_04.tif
# Original value range: -15.12 to 3.27
# Output value range: -13.48 to 2.39
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -24.20 to 77.64
# Successfully processed bias_2008_05.tif
# Original value range: -24.20 to 77.64
# Output value range: -23.55 to 75.82
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -37.18 to 93.02
# Successfully processed bias_2008_06.tif
# Original value range: -37.18 to 93.02
# Output value range: -36.55 to 82.55
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -17.52 to 77.77
# Successfully processed bias_2008_07.tif
# Original value range: -17.52 to 77.77
# Output value range: -10.01 to 41.55
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -24.95 to 80.07
# Successfully processed bias_2008_08.tif
# Original value range: -24.95 to 80.07
# Output value range: 2.57 to 2.57
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -31.55 to 51.70
# Successfully processed bias_2008_09.tif
# Original value range: -31.55 to 51.70
# Output value range: -29.13 to 46.85
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -20.94 to -1.82
# Successfully processed bias_2008_10.tif
# Original value range: -20.94 to -1.82
# Output value range: -20.60 to -5.55
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -5.65 to 5.94
# Successfully processed bias_2008_11.tif
# Original value range: -5.65 to 5.94
# Output value range: -0.80 to -0.05
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -5.91 to -0.37
# Successfully processed bias_2008_12.tif
# Original value range: -5.91 to -0.37
# Output value range: -5.01 to -2.00
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -8.11 to -0.66
# Successfully processed bias_2009_01.tif
# Original value range: -8.11 to -0.66
# Output value range: -7.83 to -2.53
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -10.97 to 1.20
# Successfully processed bias_2009_02.tif
# Original value range: -10.97 to 1.20
# Output value range: -10.28 to -3.42
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -14.72 to 0.71
# Successfully processed bias_2009_03.tif
# Original value range: -14.72 to 0.71
# Output value range: -14.17 to -3.44
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -14.67 to 3.19
# Successfully processed bias_2009_04.tif
# Original value range: -14.67 to 3.19
# Output value range: -12.43 to -3.57
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -10.67 to 13.43
# Successfully processed bias_2009_05.tif
# Original value range: -10.67 to 13.43
# Output value range: -9.43 to 12.88
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -23.69 to -3.65
# Successfully processed bias_2009_06.tif
# Original value range: -23.69 to -3.65
# Output value range: -22.80 to -7.46
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -35.17 to 43.14
# Successfully processed bias_2009_07.tif
# Original value range: -35.17 to 43.14
# Output value range: -33.25 to 38.18
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -40.64 to 66.56
# Successfully processed bias_2009_08.tif
# Original value range: -40.64 to 66.56
# Output value range: -16.27 to -5.52
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -20.94 to 208.14
# Successfully processed bias_2009_09.tif
# Original value range: -20.94 to 208.14
# Output value range: -10.79 to 185.48
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -15.92 to -1.83
# Successfully processed bias_2009_10.tif
# Original value range: -15.92 to -1.83
# Output value range: -15.56 to -4.40
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -7.51 to -0.30
# Successfully processed bias_2009_11.tif
# Original value range: -7.51 to -0.30
# Output value range: -7.16 to -2.29
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -5.39 to -0.34
# Successfully processed bias_2009_12.tif
# Original value range: -5.39 to -0.34
# Output value range: -4.50 to -1.82
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -9.11 to -1.25
# Successfully processed bias_2010_01.tif
# Original value range: -9.11 to -1.25
# Output value range: -5.56 to -3.90
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -4.52 to 3.05
# Successfully processed bias_2010_02.tif
# Original value range: -4.52 to 3.05
# Output value range: -1.82 to 1.98
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -12.46 to -1.69
# Successfully processed bias_2010_03.tif
# Original value range: -12.46 to -1.69
# Output value range: -12.33 to -3.70
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -17.86 to -2.14
# Successfully processed bias_2010_04.tif
# Original value range: -17.86 to -2.14
# Output value range: -17.56 to -5.72
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -26.69 to -2.74
# Successfully processed bias_2010_05.tif
# Original value range: -26.69 to -2.74
# Output value range: -22.54 to -4.98
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -41.87 to -3.95
# Successfully processed bias_2010_06.tif
# Original value range: -41.87 to -3.95
# Output value range: -37.67 to -14.45
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -56.59 to 142.73
# Successfully processed bias_2010_07.tif
# Original value range: -56.59 to 142.73
# Output value range: -1.25 to -1.25
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -54.84 to 226.95
# Successfully processed bias_2010_08.tif
# Original value range: -54.84 to 226.95
# Output value range: 41.47 to 41.47
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -31.23 to 329.87
# Successfully processed bias_2010_09.tif
# Original value range: -31.23 to 329.87
# Output value range: 18.63 to 231.13
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.56 to -1.71
# Successfully processed bias_2010_10.tif
# Original value range: -16.56 to -1.71
# Output value range: -6.16 to -6.16
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.16 to 9.60
# Successfully processed bias_2010_11.tif
# Original value range: -3.16 to 9.60
# Output value range: -3.01 to 9.15
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -4.74 to 4.09
# Successfully processed bias_2010_12.tif
# Original value range: -4.74 to 4.09
# Output value range: -4.53 to -0.28
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -11.53 to -0.79
# Successfully processed bias_2011_01.tif
# Original value range: -11.53 to -0.79
# Output value range: -11.26 to -2.57
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.19 to 19.45
# Successfully processed bias_2011_02.tif
# Original value range: -3.19 to 19.45
# Output value range: -1.86 to 16.35
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -13.62 to -1.62
# Successfully processed bias_2011_03.tif
# Original value range: -13.62 to -1.62
# Output value range: -5.04 to -5.04
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -12.87 to -2.20
# Successfully processed bias_2011_04.tif
# Original value range: -12.87 to -2.20
# Output value range: -11.58 to -4.65
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -6.17 to 37.51
# Successfully processed bias_2011_05.tif
# Original value range: -6.17 to 37.51
# Output value range: -4.07 to 31.74
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -15.37 to 49.36
# Successfully processed bias_2011_06.tif
# Original value range: -15.37 to 49.36
# Output value range: 1.83 to 33.68
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -52.19 to 184.31
# Successfully processed bias_2011_07.tif
# Original value range: -52.19 to 184.31
# Output value range: -10.93 to 45.73
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -32.26 to 134.35
# Successfully processed bias_2011_08.tif
# Original value range: -32.26 to 134.35
# Output value range: -15.73 to 107.89
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -22.20 to 148.57
# Successfully processed bias_2011_09.tif
# Original value range: -22.20 to 148.57
# Output value range: -12.54 to 140.46
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -17.47 to -1.82
# Successfully processed bias_2011_10.tif
# Original value range: -17.47 to -1.82
# Output value range: -17.08 to -5.19
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -14.39 to -0.27
# Successfully processed bias_2011_11.tif
# Original value range: -14.39 to -0.27
# Output value range: -13.57 to -3.39
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -5.21 to -0.38
# Successfully processed bias_2011_12.tif
# Original value range: -5.21 to -0.38
# Output value range: -4.98 to -1.73
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -6.12 to 9.67
# Successfully processed bias_2012_01.tif
# Original value range: -6.12 to 9.67
# Output value range: -4.66 to 2.72
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -15.93 to -1.19
# Successfully processed bias_2012_02.tif
# Original value range: -15.93 to -1.19
# Output value range: -14.89 to -5.56
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -11.86 to 6.38
# Successfully processed bias_2012_03.tif
# Original value range: -11.86 to 6.38
# Output value range: -11.81 to 2.78
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.51 to 4.42
# Successfully processed bias_2012_04.tif
# Original value range: -3.51 to 4.42
# Output value range: -2.53 to -0.08
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -18.84 to -2.78
# Successfully processed bias_2012_05.tif
# Original value range: -18.84 to -2.78
# Output value range: -18.50 to -5.85
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -38.59 to -4.01
# Successfully processed bias_2012_06.tif
# Original value range: -38.59 to -4.01
# Output value range: -34.81 to -13.37
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -44.65 to 42.20
# Successfully processed bias_2012_07.tif
# Original value range: -44.65 to 42.20
# Output value range: -41.83 to -0.83
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -46.29 to 130.21
# Successfully processed bias_2012_08.tif
# Original value range: -46.29 to 130.21
# Output value range: -8.51 to -7.44
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.79 to 68.00
# Successfully processed bias_2012_09.tif
# Original value range: -16.79 to 68.00
# Output value range: -10.36 to 60.32
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.55 to -1.71
# Successfully processed bias_2012_10.tif
# Original value range: -16.55 to -1.71
# Output value range: -15.68 to -6.51
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -15.63 to -0.32
# Successfully processed bias_2012_11.tif
# Original value range: -15.63 to -0.32
# Output value range: -14.97 to -2.71
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -4.23 to 5.87
# Successfully processed bias_2012_12.tif
# Original value range: -4.23 to 5.87
# Output value range: -3.28 to 2.55
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -2.36 to 23.42
# Successfully processed bias_2013_01.tif
# Original value range: -2.36 to 23.42
# Output value range: 5.59 to 20.16
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.16 to 86.33
# Successfully processed bias_2013_02.tif
# Original value range: -3.16 to 86.33
# Output value range: 12.37 to 71.85
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -8.49 to 1.50
# Successfully processed bias_2013_03.tif
# Original value range: -8.49 to 1.50
# Output value range: -7.36 to -0.11
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -14.86 to -2.12
# Successfully processed bias_2013_04.tif
# Original value range: -14.86 to -2.12
# Output value range: -14.46 to -4.45
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -19.08 to -2.73
# Successfully processed bias_2013_05.tif
# Original value range: -19.08 to -2.73
# Output value range: -18.83 to -5.94
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -17.38 to 86.34
# Successfully processed bias_2013_06.tif
# Original value range: -17.38 to 86.34
# Output value range: -1.18 to 64.91
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -53.79 to 101.08
# Successfully processed bias_2013_07.tif
# Original value range: -53.79 to 101.08
# Output value range: -18.18 to 85.30
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -38.10 to 66.65
# Successfully processed bias_2013_08.tif
# Original value range: -38.10 to 66.65
# Output value range: -17.35 to 54.55
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -40.10 to 1.76
# Successfully processed bias_2013_09.tif
# Original value range: -40.10 to 1.76
# Output value range: -17.63 to -9.86
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -8.70 to 28.10
# Successfully processed bias_2013_10.tif
# Original value range: -8.70 to 28.10
# Output value range: -8.70 to 27.58
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -7.39 to -0.27
# Successfully processed bias_2013_11.tif
# Original value range: -7.39 to -0.27
# Output value range: -6.88 to -1.17
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.56 to 1.29
# Successfully processed bias_2013_12.tif
# Original value range: -3.56 to 1.29
# Output value range: -2.96 to -0.55
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.93 to 16.72
# Successfully processed bias_2014_01.tif
# Original value range: -3.93 to 16.72
# Output value range: -1.54 to 1.93
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -5.51 to 24.36
# Successfully processed bias_2014_02.tif
# Original value range: -5.51 to 24.36
# Output value range: -1.07 to 20.27
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -2.55 to 41.35
# Successfully processed bias_2014_03.tif
# Original value range: -2.55 to 41.35
# Output value range: 6.23 to 40.41
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -12.45 to -2.12
# Successfully processed bias_2014_04.tif
# Original value range: -12.45 to -2.12
# Output value range: -11.67 to -2.93
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -11.00 to 28.42
# Successfully processed bias_2014_05.tif
# Original value range: -11.00 to 28.42
# Output value range: -3.89 to 27.11
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -14.96 to 12.64
# Successfully processed bias_2014_06.tif
# Original value range: -14.96 to 12.64
# Output value range: -10.26 to 4.51
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -27.05 to 58.18
# Successfully processed bias_2014_07.tif
# Original value range: -27.05 to 58.18
# Output value range: -11.91 to 51.04
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -25.17 to 46.11
# Successfully processed bias_2014_08.tif
# Original value range: -25.17 to 46.11
# Output value range: -22.00 to 42.94
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.79 to 33.93
# Successfully processed bias_2014_09.tif
# Original value range: -16.79 to 33.93
# Output value range: -14.53 to 27.85
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -20.98 to -1.86
# Successfully processed bias_2014_10.tif
# Original value range: -20.98 to -1.86
# Output value range: -20.61 to -5.63
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -6.90 to -0.26
# Successfully processed bias_2014_11.tif
# Original value range: -6.90 to -0.26
# Output value range: -2.06 to -1.85
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -2.02 to 9.69
# Successfully processed bias_2014_12.tif
# Original value range: -2.02 to 9.69
# Output value range: -1.01 to 4.47
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.93 to 14.67
# Successfully processed bias_2015_01.tif
# Original value range: -3.93 to 14.67
# Output value range: 1.15 to 1.15
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -15.19 to -0.10
# Successfully processed bias_2015_02.tif
# Original value range: -15.19 to -0.10
# Output value range: -14.50 to -4.29
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -2.44 to 99.43
# Successfully processed bias_2015_03.tif
# Original value range: -2.44 to 99.43
# Output value range: 22.25 to 22.25
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -6.39 to 31.34
# Successfully processed bias_2015_04.tif
# Original value range: -6.39 to 31.34
# Output value range: -2.28 to 21.22
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -13.26 to -2.68
# Successfully processed bias_2015_05.tif
# Original value range: -13.26 to -2.68
# Output value range: -9.59 to -3.91
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -9.57 to 42.09
# Successfully processed bias_2015_06.tif
# Original value range: -9.57 to 42.09
# Output value range: 0.42 to 40.11
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -35.87 to 191.13
# Successfully processed bias_2015_07.tif
# Original value range: -35.87 to 191.13
# Output value range: 10.38 to 188.37
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -18.55 to 214.77
# Successfully processed bias_2015_08.tif
# Original value range: -18.55 to 214.77
# Output value range: 4.91 to 211.51
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -42.06 to -7.95
# Successfully processed bias_2015_09.tif
# Original value range: -42.06 to -7.95
# Output value range: -40.15 to -12.97
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -14.74 to -1.81
# Successfully processed bias_2015_10.tif
# Original value range: -14.74 to -1.81
# Output value range: -14.45 to -4.94
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -6.37 to -0.26
# Successfully processed bias_2015_11.tif
# Original value range: -6.37 to -0.26
# Output value range: -1.82 to -1.82
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -5.43 to -0.33
# Successfully processed bias_2015_12.tif
# Original value range: -5.43 to -0.33
# Output value range: -1.93 to -1.77
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -9.96 to -0.68
# Successfully processed bias_2016_01.tif
# Original value range: -9.96 to -0.68
# Output value range: -8.89 to -3.52
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -15.65 to -1.08
# Successfully processed bias_2016_02.tif
# Original value range: -15.65 to -1.08
# Output value range: -15.34 to -4.69
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -2.41 to 13.01
# Successfully processed bias_2016_03.tif
# Original value range: -2.41 to 13.01
# Output value range: -0.05 to 6.50
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -18.11 to -2.08
# Successfully processed bias_2016_04.tif
# Original value range: -18.11 to -2.08
# Output value range: -17.84 to -5.59
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -4.06 to 12.78
# Successfully processed bias_2016_05.tif
# Original value range: -4.06 to 12.78
# Output value range: -1.89 to 11.25
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -22.22 to 28.47
# Successfully processed bias_2016_06.tif
# Original value range: -22.22 to 28.47
# Output value range: -20.87 to 6.37
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -74.96 to 170.65
# Successfully processed bias_2016_07.tif
# Original value range: -74.96 to 170.65
# Output value range: -0.95 to 164.25
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -24.60 to 145.26
# Successfully processed bias_2016_08.tif
# Original value range: -24.60 to 145.26
# Output value range: -1.90 to 81.02
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -47.47 to 9.33
# Successfully processed bias_2016_09.tif
# Original value range: -47.47 to 9.33
# Output value range: -31.72 to 6.55
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -14.72 to -1.82
# Successfully processed bias_2016_10.tif
# Original value range: -14.72 to -1.82
# Output value range: -14.47 to -3.73
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -6.88 to -0.27
# Successfully processed bias_2016_11.tif
# Original value range: -6.88 to -0.27
# Output value range: -5.78 to -1.61
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -5.43 to -0.34
# Successfully processed bias_2016_12.tif
# Original value range: -5.43 to -0.34
# Output value range: -2.38 to -1.81
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -1.70 to 39.61
# Successfully processed bias_2017_01.tif
# Original value range: -1.70 to 39.61
# Output value range: 5.35 to 37.38
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -10.93 to -1.13
# Successfully processed bias_2017_02.tif
# Original value range: -10.93 to -1.13
# Output value range: -10.49 to -3.31
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -9.70 to 1.78
# Successfully processed bias_2017_03.tif
# Original value range: -9.70 to 1.78
# Output value range: -8.27 to 1.32
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -13.57 to 4.33
# Successfully processed bias_2017_04.tif
# Original value range: -13.57 to 4.33
# Output value range: -11.79 to 2.84
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -8.07 to 3.59
# Successfully processed bias_2017_05.tif
# Original value range: -8.07 to 3.59
# Output value range: -4.47 to 1.33
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -10.04 to 162.94
# Successfully processed bias_2017_06.tif
# Original value range: -10.04 to 162.94
# Output value range: 6.35 to 132.57
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -13.44 to 73.94
# Successfully processed bias_2017_07.tif
# Original value range: -13.44 to 73.94
# Output value range: -1.17 to 72.36
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -27.05 to 69.83
# Successfully processed bias_2017_08.tif
# Original value range: -27.05 to 69.83
# Output value range: -14.67 to 22.49
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -29.61 to 172.63
# Successfully processed bias_2017_09.tif
# Original value range: -29.61 to 172.63
# Output value range: -8.54 to 103.60
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.73 to -1.81
# Successfully processed bias_2017_10.tif
# Original value range: -16.73 to -1.81
# Output value range: -16.19 to -6.13
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -12.29 to -0.32
# Successfully processed bias_2017_11.tif
# Original value range: -12.29 to -0.32
# Output value range: -11.96 to -1.83
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -1.90 to 1.14
# Successfully processed bias_2017_12.tif
# Original value range: -1.90 to 1.14
# Output value range: -1.23 to 1.07
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -5.28 to -0.66
# Successfully processed bias_2018_01.tif
# Original value range: -5.28 to -0.66
# Output value range: -5.13 to -1.46
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -15.58 to -1.07
# Successfully processed bias_2018_02.tif
# Original value range: -15.58 to -1.07
# Output value range: -13.51 to -5.10
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -12.62 to -1.55
# Successfully processed bias_2018_03.tif
# Original value range: -12.62 to -1.55
# Output value range: -12.34 to -4.56
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -15.40 to -2.20
# Successfully processed bias_2018_04.tif
# Original value range: -15.40 to -2.20
# Output value range: -14.02 to -3.14
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.64 to -0.97
# Successfully processed bias_2018_05.tif
# Original value range: -16.64 to -0.97
# Output value range: -15.58 to -1.46
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -15.50 to 57.91
# Successfully processed bias_2018_06.tif
# Original value range: -15.50 to 57.91
# Output value range: -14.31 to 40.90
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -53.89 to 160.17
# Successfully processed bias_2018_07.tif
# Original value range: -53.89 to 160.17
# Output value range: 6.98 to 151.15
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -79.36 to 73.69
# Successfully processed bias_2018_08.tif
# Original value range: -79.36 to 73.69
# Output value range: -53.83 to 35.10
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -23.90 to 127.00
# Successfully processed bias_2018_09.tif
# Original value range: -23.90 to 127.00
# Output value range: 6.42 to 122.76
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -17.21 to -1.69
# Successfully processed bias_2018_10.tif
# Original value range: -17.21 to -1.69
# Output value range: -16.92 to -5.05
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -1.46 to 2.75
# Successfully processed bias_2018_11.tif
# Original value range: -1.46 to 2.75
# Output value range: -0.31 to 2.55
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -5.26 to -0.32
# Successfully processed bias_2018_12.tif
# Original value range: -5.26 to -0.32
# Output value range: -4.88 to -1.66
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -1.41 to 31.96
# Successfully processed bias_2019_01.tif
# Original value range: -1.41 to 31.96
# Output value range: 4.46 to 30.09
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -5.94 to 28.07
# Successfully processed bias_2019_02.tif
# Original value range: -5.94 to 28.07
# Output value range: -2.05 to 18.43
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -8.98 to 2.40
# Successfully processed bias_2019_03.tif
# Original value range: -8.98 to 2.40
# Output value range: -3.78 to -2.83
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -15.96 to -2.08
# Successfully processed bias_2019_04.tif
# Original value range: -15.96 to -2.08
# Output value range: -14.42 to -3.40
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -10.27 to 13.54
# Successfully processed bias_2019_05.tif
# Original value range: -10.27 to 13.54
# Output value range: -0.54 to 7.09
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -26.85 to -4.01
# Successfully processed bias_2019_06.tif
# Original value range: -26.85 to -4.01
# Output value range: -21.34 to -7.23
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -47.35 to 60.41
# Successfully processed bias_2019_07.tif
# Original value range: -47.35 to 60.41
# Output value range: -30.30 to 34.03
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -45.52 to 86.57
# Successfully processed bias_2019_08.tif
# Original value range: -45.52 to 86.57
# Output value range: -28.72 to 81.37
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -47.66 to -11.43
# Successfully processed bias_2019_09.tif
# Original value range: -47.66 to -11.43
# Output value range: -45.36 to -18.28
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -12.43 to 18.83
# Successfully processed bias_2019_10.tif
# Original value range: -12.43 to 18.83
# Output value range: -12.29 to 18.35
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -6.40 to 2.87
# Successfully processed bias_2019_11.tif
# Original value range: -6.40 to 2.87
# Output value range: -0.66 to -0.66
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -6.40 to 22.79
# Successfully processed bias_2019_12.tif
# Original value range: -6.40 to 22.79
# Output value range: 1.75 to 21.66
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -1.74 to 33.36
# Successfully processed bias_2020_01.tif
# Original value range: -1.74 to 33.36
# Output value range: 4.47 to 24.30
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -11.40 to -1.24
# Successfully processed bias_2020_02.tif
# Original value range: -11.40 to -1.24
# Output value range: -10.13 to -4.21
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -2.39 to 77.71
# Successfully processed bias_2020_03.tif
# Original value range: -2.39 to 77.71
# Output value range: 11.70 to 75.86
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -11.68 to -2.16
# Successfully processed bias_2020_04.tif
# Original value range: -11.68 to -2.16
# Output value range: -10.00 to -3.04
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.38 to 11.87
# Successfully processed bias_2020_05.tif
# Original value range: -3.38 to 11.87
# Output value range: -1.32 to 11.60
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -18.87 to 42.10
# Successfully processed bias_2020_06.tif
# Original value range: -18.87 to 42.10
# Output value range: -6.67 to 32.86
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.16 to 173.97
# Successfully processed bias_2020_07.tif
# Original value range: -16.16 to 173.97
# Output value range: 8.24 to 173.24
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -21.35 to 202.01
# Successfully processed bias_2020_08.tif
# Original value range: -21.35 to 202.01
# Output value range: 23.56 to 23.56
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -52.94 to -7.88
# Successfully processed bias_2020_09.tif
# Original value range: -52.94 to -7.88
# Output value range: -47.30 to -14.21
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.45 to -1.81
# Successfully processed bias_2020_10.tif
# Original value range: -16.45 to -1.81
# Output value range: -6.48 to -6.48
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -2.62 to -0.32
# Successfully processed bias_2020_11.tif
# Original value range: -2.62 to -0.32
# Output value range: -1.93 to -0.74
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.29 to -0.33
# Successfully processed bias_2020_12.tif
# Original value range: -3.29 to -0.33
# Output value range: -3.21 to -1.05
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.64 to 43.69
# Successfully processed bias_2021_01.tif
# Original value range: -3.64 to 43.69
# Output value range: 7.73 to 7.73
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -10.26 to -1.07
# Successfully processed bias_2021_02.tif
# Original value range: -10.26 to -1.07
# Output value range: -9.42 to -3.83
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -9.90 to 9.34
# Successfully processed bias_2021_03.tif
# Original value range: -9.90 to 9.34
# Output value range: -6.88 to -0.44
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.39 to -2.18
# Successfully processed bias_2021_04.tif
# Original value range: -16.39 to -2.18
# Output value range: -14.77 to -5.25
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -8.10 to 117.58
# Successfully processed bias_2021_05.tif
# Original value range: -8.10 to 117.58
# Output value range: 20.28 to 49.72
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -19.11 to 3.21
# Successfully processed bias_2021_06.tif
# Original value range: -19.11 to 3.21
# Output value range: -15.85 to -3.14
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -30.23 to 356.30
# Successfully processed bias_2021_07.tif
# Original value range: -30.23 to 356.30
# Output value range: 1.87 to 354.61
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -27.19 to 127.94
# Successfully processed bias_2021_08.tif
# Original value range: -27.19 to 127.94
# Output value range: 13.41 to 112.48
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -26.69 to 247.76
# Successfully processed bias_2021_09.tif
# Original value range: -26.69 to 247.76
# Output value range: 41.65 to 236.77
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -4.34 to 79.39
# Successfully processed bias_2021_10.tif
# Original value range: -4.34 to 79.39
# Output value range: 7.28 to 77.70
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.27 to -0.31
# Successfully processed bias_2021_11.tif
# Original value range: -3.27 to -0.31
# Output value range: -3.13 to -1.07
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.60 to 3.80
# Successfully processed bias_2021_12.tif
# Original value range: -3.60 to 3.80
# Output value range: -1.79 to 2.77
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.36 to 85.04
# Successfully processed bias_2022_01.tif
# Original value range: -3.36 to 85.04
# Output value range: 20.86 to 20.86
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -2.88 to 10.31
# Successfully processed bias_2022_02.tif
# Original value range: -2.88 to 10.31
# Output value range: 0.70 to 9.56
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -10.12 to -1.46
# Successfully processed bias_2022_03.tif
# Original value range: -10.12 to -1.46
# Output value range: -9.92 to -3.50
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.42 to -2.08
# Successfully processed bias_2022_04.tif
# Original value range: -16.42 to -2.08
# Output value range: -16.13 to -6.25
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -8.43 to 42.78
# Successfully processed bias_2022_05.tif
# Original value range: -8.43 to 42.78
# Output value range: 0.75 to 38.43
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -15.21 to 21.78
# Successfully processed bias_2022_06.tif
# Original value range: -15.21 to 21.78
# Output value range: -15.11 to 16.64
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -30.70 to 233.62
# Successfully processed bias_2022_07.tif
# Original value range: -30.70 to 233.62
# Output value range: 1.73 to 154.74
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -40.97 to 7.48
# Successfully processed bias_2022_08.tif
# Original value range: -40.97 to 7.48
# Output value range: -34.47 to 7.27
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -21.23 to 171.40
# Successfully processed bias_2022_09.tif
# Original value range: -21.23 to 171.40
# Output value range: 5.91 to 135.71
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -4.65 to 91.70
# Successfully processed bias_2022_10.tif
# Original value range: -4.65 to 91.70
# Output value range: 18.65 to 18.65
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.36 to -0.27
# Successfully processed bias_2022_11.tif
# Original value range: -3.36 to -0.27
# Output value range: -2.90 to -1.28
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.65 to -0.34
# Successfully processed bias_2022_12.tif
# Original value range: -3.65 to -0.34
# Output value range: -2.54 to -1.29

# %% [markdown]
# ### Interpolate Bias Obtained at 0.25 Degree to 0.1 Degree Using Kriging Interpolation

# %%
import os 
import rasterio
from pykrige.ok import OrdinaryKriging
from rasterio.mask import mask
from shapely.geometry import box, Point, Polygon
import geopandas as gpd
import numpy as np

def create_bounds(src_bounds, dst_shape, dst_transform):
    rows, cols = dst_shape
    mask = np.zeros((rows, cols), dtype=bool)
    
    xs = np.linspace(dst_transform[2], 
                    dst_transform[2] + cols * dst_transform[0], 
                    cols)
    ys = np.linspace(dst_transform[5], 
                    dst_transform[5] + rows * dst_transform[4], 
                    rows)
    boundary = box(src_bounds.left, src_bounds.bottom,
                  src_bounds.right, src_bounds.top).buffer(0.1)
    
    X, Y = np.meshgrid(xs, ys)
    points = np.column_stack((X.ravel(), Y.ravel()))
    
    batch_size = 10000
    
    for i in range(0, len(points), batch_size):
        batch_points = points[i:i+batch_size]
        batch_results = [boundary.contains(Point(x, y)) for x, y in batch_points]
        mask.ravel()[i:i+batch_size] = batch_results
    
    return mask

def interpolate_tiff(input_dir, output_dir, variogram_model='spherical', max_points=1000):
    os.makedirs(output_dir, exist_ok=True)

    
    dst_crs = 'EPSG:4326'
    dst_bounds = (76.5, 28.31, 77.5, 28.9)
    width = int((dst_bounds[2] - dst_bounds[0]) / 0.1)  # 0.1 degree per pixel
    height = int((dst_bounds[3] - dst_bounds[1]) / 0.1)  # 0.1 degree per pixel
    dst_shape = (height, width)
    
    dst_transform = rasterio.transform.from_bounds(
        dst_bounds[0], dst_bounds[1], 
        dst_bounds[2], dst_bounds[3], 
        dst_shape[1], dst_shape[0]
    )
    
    dst_y, dst_x = np.mgrid[dst_bounds[1]:dst_bounds[3]:dst_shape[0]*1j,
                           dst_bounds[0]:dst_bounds[2]:dst_shape[1]*1j]
    
    tiff_files = sorted([f for f in os.listdir(input_dir) if f.endswith('.tif')])
    
    for file in tiff_files:
        try:
            input_path = os.path.join(input_dir, file)
            output_path = os.path.join(output_dir, file)
            
            with rasterio.open(input_path) as src:
                src_data = src.read(1)
                nodata_value = src.nodata if src.nodata is not None else -9999
                src_mask = src_data != nodata_value
                
                profile = src.profile.copy()
                profile.update({
                    'crs': dst_crs,
                    'transform': dst_transform,
                    'width': dst_shape[1],
                    'height': dst_shape[0],
                    'nodata': nodata_value,
                })
                
                rows, cols = src_data.shape
                src_y, src_x = np.mgrid[src.bounds.bottom:src.bounds.top:rows*1j,
                                      src.bounds.left:src.bounds.right:cols*1j]
                
                valid_mask = (src_mask & 
                            ~np.isnan(src_data) & 
                            ~np.isinf(src_data) &
                            (src_data != nodata_value))
                
                x_valid = src_x[valid_mask].flatten()
                y_valid = src_y[valid_mask].flatten()
                z_valid = src_data[valid_mask].flatten()
                
                if len(z_valid) < 3:
                    print(f"Warning: Too few valid points ({len(z_valid)}) in {file}")
                    continue
                
                print(f"Number of valid points: {len(z_valid)}")
                print(f"X range: {np.min(x_valid):.2f} to {np.max(x_valid):.2f}")
                print(f"Y range: {np.min(y_valid):.2f} to {np.max(y_valid):.2f}")
                print(f"Z range: {np.min(z_valid):.2f} to {np.max(z_valid):.2f}")
                
                valid_min = np.min(z_valid)
                valid_max = np.max(z_valid)
                
                if len(z_valid) > max_points:
                    idx = np.random.choice(len(z_valid), max_points, replace=False)
                    x_valid = x_valid[idx]
                    y_valid = y_valid[idx]
                    z_valid = z_valid[idx]
                
                try:
                    boundary_mask = create_bounds(src.bounds, dst_shape, dst_transform)
                    
                    ok = OrdinaryKriging(
                        x_valid, y_valid, z_valid,
                        variogram_model=variogram_model,
                        verbose=False,
                        enable_plotting=False
                    )
                    
                    dst_array, _ = ok.execute('grid', dst_x[0, :], dst_y[:, 0])
                    
                    dst_array[~boundary_mask] = nodata_value
                    
                    valid_pixels = (dst_array != nodata_value) & ~np.isnan(dst_array)
                    if np.any(valid_pixels):
                        dst_array[valid_pixels] = np.clip(
                            dst_array[valid_pixels],
                            valid_min,
                            valid_max
                        )
                        
                        with rasterio.open(output_path, 'w', **profile) as dst:
                            dst.write(dst_array.astype(profile['dtype']), 1)
                            dst.update_tags(
                                interpolation_method=f'ordinary_kriging_{variogram_model}',
                                original_value_range=f"{valid_min:.2f} to {valid_max:.2f}",
                                valid_points_count=str(len(z_valid))
                            )
                        print(f"Successfully processed {file}")
                        print(f"Original value range: {valid_min:.2f} to {valid_max:.2f}")
                        print(f"Output value range: {np.min(dst_array[valid_pixels]):.2f} "
                              f"to {np.max(dst_array[valid_pixels]):.2f}")
                    else:
                        print(f"Warning: No valid pixels in output after masking for {file}")
                        
                except Exception as e:
                    print(f"Error in kriging for {file}: {str(e)}")
                    continue
        except Exception as e:
            print(f"Error processing {file}: {str(e)}")
            continue

def main():
    input_dir = r"/home/stormej/dev/rainscale/data/bias/bias_0.25"
    output_dir = r"/home/stormej/dev/rainscale/data/bias/bias_kriging_0.1"
    
    interpolate_tiff(input_dir, output_dir, variogram_model='spherical', max_points=1000)

main()
# Out:
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.32 to 45.95
# Successfully processed bias_2000_02.tif
# Original value range: -3.32 to 45.95
# Output value range: 6.48 to 6.48
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -12.33 to -1.15
# Successfully processed bias_2000_03.tif
# Original value range: -12.33 to -1.15
# Output value range: -10.15 to -4.06
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -15.45 to -2.04
# Successfully processed bias_2000_04.tif
# Original value range: -15.45 to -2.04
# Output value range: -14.11 to -5.05
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -21.97 to 0.76
# Successfully processed bias_2000_05.tif
# Original value range: -21.97 to 0.76
# Output value range: -16.44 to -2.03
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -19.28 to 63.18
# Successfully processed bias_2000_06.tif
# Original value range: -19.28 to 63.18
# Output value range: -9.20 to 34.32
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -53.60 to 107.48
# Successfully processed bias_2000_07.tif
# Original value range: -53.60 to 107.48
# Output value range: 2.28 to 2.28
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -24.30 to 230.10
# Successfully processed bias_2000_08.tif
# Original value range: -24.30 to 230.10
# Output value range: 10.14 to 186.20
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -51.20 to -7.88
# Successfully processed bias_2000_09.tif
# Original value range: -51.20 to -7.88
# Output value range: -22.20 to -22.20
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -20.43 to -1.87
# Successfully processed bias_2000_10.tif
# Original value range: -20.43 to -1.87
# Output value range: -9.90 to -7.09
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -14.81 to -0.35
# Successfully processed bias_2000_11.tif
# Original value range: -14.81 to -0.35
# Output value range: -13.49 to -1.30
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -4.38 to -0.34
# Successfully processed bias_2000_12.tif
# Original value range: -4.38 to -0.34
# Output value range: -3.90 to -1.09
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.41 to 12.70
# Successfully processed bias_2001_01.tif
# Original value range: -3.41 to 12.70
# Output value range: -1.11 to 9.11
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -9.18 to -1.16
# Successfully processed bias_2001_02.tif
# Original value range: -9.18 to -1.16
# Output value range: -3.82 to -3.09
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -8.13 to -0.01
# Successfully processed bias_2001_03.tif
# Original value range: -8.13 to -0.01
# Output value range: -6.47 to -2.15
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -7.69 to 6.37
# Successfully processed bias_2001_04.tif
# Original value range: -7.69 to 6.37
# Output value range: -5.68 to 2.56
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -20.37 to 53.07
# Successfully processed bias_2001_05.tif
# Original value range: -20.37 to 53.07
# Output value range: -12.99 to 37.44
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -11.82 to 98.45
# Successfully processed bias_2001_06.tif
# Original value range: -11.82 to 98.45
# Output value range: 8.52 to 81.58
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -33.47 to 76.05
# Successfully processed bias_2001_07.tif
# Original value range: -33.47 to 76.05
# Output value range: -25.66 to 60.94
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -20.82 to 127.92
# Successfully processed bias_2001_08.tif
# Original value range: -20.82 to 127.92
# Output value range: 4.98 to 4.98
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -42.92 to -8.45
# Successfully processed bias_2001_09.tif
# Original value range: -42.92 to -8.45
# Output value range: -39.11 to -14.15
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -23.95 to 9.73
# Successfully processed bias_2001_10.tif
# Original value range: -23.95 to 9.73
# Output value range: -20.21 to 2.40
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -5.04 to -0.26
# Successfully processed bias_2001_11.tif
# Original value range: -5.04 to -0.26
# Output value range: -4.08 to -1.28
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -5.31 to -0.36
# Successfully processed bias_2001_12.tif
# Original value range: -5.31 to -0.36
# Output value range: -3.17 to -1.96
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -1.36 to 13.93
# Successfully processed bias_2002_01.tif
# Original value range: -1.36 to 13.93
# Output value range: 1.64 to 2.66
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -4.67 to 13.70
# Successfully processed bias_2002_02.tif
# Original value range: -4.67 to 13.70
# Output value range: -1.92 to 8.56
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -10.44 to -1.45
# Successfully processed bias_2002_03.tif
# Original value range: -10.44 to -1.45
# Output value range: -8.58 to -3.98
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.50 to -2.20
# Successfully processed bias_2002_04.tif
# Original value range: -16.50 to -2.20
# Output value range: -9.10 to -7.09
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -14.16 to 111.61
# Successfully processed bias_2002_05.tif
# Original value range: -14.16 to 111.61
# Output value range: 5.31 to 72.42
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -23.23 to 40.54
# Successfully processed bias_2002_06.tif
# Original value range: -23.23 to 40.54
# Output value range: -9.96 to 24.50
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -50.22 to -8.30
# Successfully processed bias_2002_07.tif
# Original value range: -50.22 to -8.30
# Output value range: -42.15 to -18.85
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -76.27 to 250.94
# Successfully processed bias_2002_08.tif
# Original value range: -76.27 to 250.94
# Output value range: -5.57 to -5.57
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -21.67 to 134.50
# Successfully processed bias_2002_09.tif
# Original value range: -21.67 to 134.50
# Output value range: 20.53 to 77.35
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.23 to -1.82
# Successfully processed bias_2002_10.tif
# Original value range: -16.23 to -1.82
# Output value range: -13.06 to -5.97
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.99 to -0.26
# Successfully processed bias_2002_11.tif
# Original value range: -3.99 to -0.26
# Output value range: -3.36 to -1.29
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -0.76 to 10.79
# Successfully processed bias_2002_12.tif
# Original value range: -0.76 to 10.79
# Output value range: 0.84 to 6.43
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -4.22 to 24.19
# Successfully processed bias_2003_01.tif
# Original value range: -4.22 to 24.19
# Output value range: 1.58 to 1.58
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.34 to 53.29
# Successfully processed bias_2003_02.tif
# Original value range: -3.34 to 53.29
# Output value range: 6.64 to 42.57
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -8.78 to -1.15
# Successfully processed bias_2003_03.tif
# Original value range: -8.78 to -1.15
# Output value range: -3.74 to -3.74
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.67 to -2.21
# Successfully processed bias_2003_04.tif
# Original value range: -16.67 to -2.21
# Output value range: -14.87 to -5.93
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -23.67 to -2.87
# Successfully processed bias_2003_05.tif
# Original value range: -23.67 to -2.87
# Output value range: -20.48 to -7.80
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -49.43 to 37.91
# Successfully processed bias_2003_06.tif
# Original value range: -49.43 to 37.91
# Output value range: -22.37 to 20.82
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -58.79 to 479.64
# Successfully processed bias_2003_07.tif
# Original value range: -58.79 to 479.64
# Output value range: 16.03 to 434.93
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -19.74 to 214.97
# Successfully processed bias_2003_08.tif
# Original value range: -19.74 to 214.97
# Output value range: 16.72 to 179.80
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -21.76 to 121.76
# Successfully processed bias_2003_09.tif
# Original value range: -21.76 to 121.76
# Output value range: -3.58 to 31.60
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -17.37 to -1.81
# Successfully processed bias_2003_10.tif
# Original value range: -17.37 to -1.81
# Output value range: -11.05 to -6.69
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -12.89 to -0.27
# Successfully processed bias_2003_11.tif
# Original value range: -12.89 to -0.27
# Output value range: -5.64 to -2.12
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.28 to 32.34
# Successfully processed bias_2003_12.tif
# Original value range: -3.28 to 32.34
# Output value range: 0.72 to 19.51
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.31 to 13.44
# Successfully processed bias_2004_01.tif
# Original value range: -3.31 to 13.44
# Output value range: 0.08 to 11.80
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -10.39 to -1.07
# Successfully processed bias_2004_02.tif
# Original value range: -10.39 to -1.07
# Output value range: -8.29 to -3.79
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -10.80 to -1.46
# Successfully processed bias_2004_03.tif
# Original value range: -10.80 to -1.46
# Output value range: -9.11 to -3.72
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -6.92 to 22.65
# Successfully processed bias_2004_04.tif
# Original value range: -6.92 to 22.65
# Output value range: -3.07 to 2.04
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -6.01 to 31.45
# Successfully processed bias_2004_05.tif
# Original value range: -6.01 to 31.45
# Output value range: 2.84 to 24.13
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -14.18 to 14.52
# Successfully processed bias_2004_06.tif
# Original value range: -14.18 to 14.52
# Output value range: -4.50 to -3.36
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -54.07 to 3.07
# Successfully processed bias_2004_07.tif
# Original value range: -54.07 to 3.07
# Output value range: -45.69 to -15.10
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -26.87 to 292.07
# Successfully processed bias_2004_08.tif
# Original value range: -26.87 to 292.07
# Output value range: 23.24 to 268.50
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -49.22 to -7.88
# Successfully processed bias_2004_09.tif
# Original value range: -49.22 to -7.88
# Output value range: -39.71 to -16.66
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -6.28 to 97.52
# Successfully processed bias_2004_10.tif
# Original value range: -6.28 to 97.52
# Output value range: 17.81 to 17.81
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.17 to -0.28
# Successfully processed bias_2004_11.tif
# Original value range: -3.17 to -0.28
# Output value range: -2.79 to -1.03
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -6.85 to -0.33
# Successfully processed bias_2004_12.tif
# Original value range: -6.85 to -0.33
# Output value range: -1.94 to -1.94
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -4.81 to -0.71
# Successfully processed bias_2005_01.tif
# Original value range: -4.81 to -0.71
# Output value range: -1.91 to -1.91
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.25 to 36.80
# Successfully processed bias_2005_02.tif
# Original value range: -3.25 to 36.80
# Output value range: 3.54 to 27.28
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -2.40 to 19.82
# Successfully processed bias_2005_03.tif
# Original value range: -2.40 to 19.82
# Output value range: -0.81 to 11.47
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -19.94 to -2.33
# Successfully processed bias_2005_04.tif
# Original value range: -19.94 to -2.33
# Output value range: -16.93 to -6.48
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -15.57 to 5.89
# Successfully processed bias_2005_05.tif
# Original value range: -15.57 to 5.89
# Output value range: -4.53 to -4.53
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -14.69 to 25.76
# Successfully processed bias_2005_06.tif
# Original value range: -14.69 to 25.76
# Output value range: -11.64 to 19.39
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -28.49 to 238.77
# Successfully processed bias_2005_07.tif
# Original value range: -28.49 to 238.77
# Output value range: 10.28 to 172.38
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -31.57 to 15.38
# Successfully processed bias_2005_08.tif
# Original value range: -31.57 to 15.38
# Output value range: -23.86 to 4.30
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -24.15 to 210.14
# Successfully processed bias_2005_09.tif
# Original value range: -24.15 to 210.14
# Output value range: 12.08 to 152.51
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.48 to -1.80
# Successfully processed bias_2005_10.tif
# Original value range: -16.48 to -1.80
# Output value range: -13.80 to -5.41
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.30 to -0.26
# Successfully processed bias_2005_11.tif
# Original value range: -3.30 to -0.26
# Output value range: -2.81 to -1.00
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -5.66 to -0.40
# Successfully processed bias_2005_12.tif
# Original value range: -5.66 to -0.40
# Output value range: -1.90 to -1.90
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -7.85 to -0.67
# Successfully processed bias_2006_01.tif
# Original value range: -7.85 to -0.67
# Output value range: -6.01 to -2.74
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -12.13 to -1.07
# Successfully processed bias_2006_02.tif
# Original value range: -12.13 to -1.07
# Output value range: -8.94 to -4.07
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.95 to 25.35
# Successfully processed bias_2006_03.tif
# Original value range: -3.95 to 25.35
# Output value range: 2.01 to 12.58
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.88 to -2.25
# Successfully processed bias_2006_04.tif
# Original value range: -16.88 to -2.25
# Output value range: -14.14 to -7.17
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -13.05 to 0.23
# Successfully processed bias_2006_05.tif
# Original value range: -13.05 to 0.23
# Output value range: -9.37 to -3.86
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -17.45 to 32.16
# Successfully processed bias_2006_06.tif
# Original value range: -17.45 to 32.16
# Output value range: -1.90 to -1.60
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -30.16 to 271.54
# Successfully processed bias_2006_07.tif
# Original value range: -30.16 to 271.54
# Output value range: 16.52 to 53.47
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -38.56 to -5.53
# Successfully processed bias_2006_08.tif
# Original value range: -38.56 to -5.53
# Output value range: -33.89 to -13.53
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -17.67 to 68.21
# Successfully processed bias_2006_09.tif
# Original value range: -17.67 to 68.21
# Output value range: -4.36 to 49.01
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -14.86 to -1.30
# Successfully processed bias_2006_10.tif
# Original value range: -14.86 to -1.30
# Output value range: -4.98 to -4.98
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -4.86 to 5.00
# Successfully processed bias_2006_11.tif
# Original value range: -4.86 to 5.00
# Output value range: -3.29 to 1.44
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -5.37 to -0.37
# Successfully processed bias_2006_12.tif
# Original value range: -5.37 to -0.37
# Output value range: -3.61 to -1.57
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -6.83 to -0.65
# Successfully processed bias_2007_01.tif
# Original value range: -6.83 to -0.65
# Output value range: -2.72 to -2.54
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -6.06 to 43.30
# Successfully processed bias_2007_02.tif
# Original value range: -6.06 to 43.30
# Output value range: 8.09 to 12.10
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -2.46 to 55.28
# Successfully processed bias_2007_03.tif
# Original value range: -2.46 to 55.28
# Output value range: 9.87 to 33.80
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.23 to -2.04
# Successfully processed bias_2007_04.tif
# Original value range: -16.23 to -2.04
# Output value range: -6.29 to -6.29
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.91 to 4.98
# Successfully processed bias_2007_05.tif
# Original value range: -16.91 to 4.98
# Output value range: -4.41 to -4.41
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -11.95 to 65.59
# Successfully processed bias_2007_06.tif
# Original value range: -11.95 to 65.59
# Output value range: -4.53 to 50.11
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -18.74 to 68.25
# Successfully processed bias_2007_07.tif
# Original value range: -18.74 to 68.25
# Output value range: -5.72 to 42.48
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -21.39 to 61.16
# Successfully processed bias_2007_08.tif
# Original value range: -21.39 to 61.16
# Output value range: -16.95 to 48.27
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -49.94 to 31.56
# Successfully processed bias_2007_09.tif
# Original value range: -49.94 to 31.56
# Output value range: -10.94 to -10.94
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -18.46 to -1.82
# Successfully processed bias_2007_10.tif
# Original value range: -18.46 to -1.82
# Output value range: -17.00 to -4.89
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.08 to -0.30
# Successfully processed bias_2007_11.tif
# Original value range: -16.08 to -0.30
# Output value range: -13.37 to -2.42
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -5.83 to 2.81
# Successfully processed bias_2007_12.tif
# Original value range: -5.83 to 2.81
# Output value range: -1.82 to -1.20
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -9.71 to -0.81
# Successfully processed bias_2008_01.tif
# Original value range: -9.71 to -0.81
# Output value range: -8.26 to -2.57
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -15.72 to -1.16
# Successfully processed bias_2008_02.tif
# Original value range: -15.72 to -1.16
# Output value range: -11.72 to -5.10
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -15.44 to -1.62
# Successfully processed bias_2008_03.tif
# Original value range: -15.44 to -1.62
# Output value range: -13.40 to -4.39
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -15.12 to 3.27
# Successfully processed bias_2008_04.tif
# Original value range: -15.12 to 3.27
# Output value range: -13.48 to 2.38
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -24.20 to 77.64
# Successfully processed bias_2008_05.tif
# Original value range: -24.20 to 77.64
# Output value range: -18.43 to 66.65
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -37.18 to 93.02
# Successfully processed bias_2008_06.tif
# Original value range: -37.18 to 93.02
# Output value range: -34.07 to 82.51
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -17.52 to 77.77
# Successfully processed bias_2008_07.tif
# Original value range: -17.52 to 77.77
# Output value range: -8.18 to 39.97
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -24.95 to 80.07
# Successfully processed bias_2008_08.tif
# Original value range: -24.95 to 80.07
# Output value range: 2.57 to 2.57
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -31.55 to 51.70
# Successfully processed bias_2008_09.tif
# Original value range: -31.55 to 51.70
# Output value range: -19.29 to 27.12
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -20.94 to -1.82
# Successfully processed bias_2008_10.tif
# Original value range: -20.94 to -1.82
# Output value range: -18.97 to -5.68
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -5.65 to 5.94
# Successfully processed bias_2008_11.tif
# Original value range: -5.65 to 5.94
# Output value range: -0.54 to -0.17
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -5.91 to -0.37
# Successfully processed bias_2008_12.tif
# Original value range: -5.91 to -0.37
# Output value range: -2.19 to -2.00
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -8.11 to -0.66
# Successfully processed bias_2009_01.tif
# Original value range: -8.11 to -0.66
# Output value range: -6.32 to -2.55
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -10.97 to 1.20
# Successfully processed bias_2009_02.tif
# Original value range: -10.97 to 1.20
# Output value range: -7.49 to -3.42
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -14.72 to 0.71
# Successfully processed bias_2009_03.tif
# Original value range: -14.72 to 0.71
# Output value range: -11.72 to -3.68
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -14.67 to 3.19
# Successfully processed bias_2009_04.tif
# Original value range: -14.67 to 3.19
# Output value range: -5.55 to -3.57
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -10.67 to 13.43
# Successfully processed bias_2009_05.tif
# Original value range: -10.67 to 13.43
# Output value range: -8.46 to 8.40
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -23.69 to -3.65
# Successfully processed bias_2009_06.tif
# Original value range: -23.69 to -3.65
# Output value range: -20.92 to -7.50
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -35.17 to 43.14
# Successfully processed bias_2009_07.tif
# Original value range: -35.17 to 43.14
# Output value range: -28.17 to 25.99
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -40.64 to 66.56
# Successfully processed bias_2009_08.tif
# Original value range: -40.64 to 66.56
# Output value range: -13.36 to -7.85
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -20.94 to 208.14
# Successfully processed bias_2009_09.tif
# Original value range: -20.94 to 208.14
# Output value range: -10.79 to 185.45
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -15.92 to -1.83
# Successfully processed bias_2009_10.tif
# Original value range: -15.92 to -1.83
# Output value range: -14.41 to -4.41
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -7.51 to -0.30
# Successfully processed bias_2009_11.tif
# Original value range: -7.51 to -0.30
# Output value range: -5.58 to -2.29
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -5.39 to -0.34
# Successfully processed bias_2009_12.tif
# Original value range: -5.39 to -0.34
# Output value range: -1.94 to -1.82
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -9.11 to -1.25
# Successfully processed bias_2010_01.tif
# Original value range: -9.11 to -1.25
# Output value range: -4.93 to -3.90
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -4.52 to 3.05
# Successfully processed bias_2010_02.tif
# Original value range: -4.52 to 3.05
# Output value range: -1.82 to -1.07
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -12.46 to -1.69
# Successfully processed bias_2010_03.tif
# Original value range: -12.46 to -1.69
# Output value range: -11.65 to -3.70
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -17.86 to -2.14
# Successfully processed bias_2010_04.tif
# Original value range: -17.86 to -2.14
# Output value range: -16.22 to -5.81
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -26.69 to -2.74
# Successfully processed bias_2010_05.tif
# Original value range: -26.69 to -2.74
# Output value range: -20.45 to -6.40
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -41.87 to -3.95
# Successfully processed bias_2010_06.tif
# Original value range: -41.87 to -3.95
# Output value range: -33.65 to -14.59
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -56.59 to 142.73
# Successfully processed bias_2010_07.tif
# Original value range: -56.59 to 142.73
# Output value range: -1.25 to -1.25
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -54.84 to 226.95
# Successfully processed bias_2010_08.tif
# Original value range: -54.84 to 226.95
# Output value range: 41.47 to 41.47
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -31.23 to 329.87
# Successfully processed bias_2010_09.tif
# Original value range: -31.23 to 329.87
# Output value range: 18.78 to 221.46
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.56 to -1.71
# Successfully processed bias_2010_10.tif
# Original value range: -16.56 to -1.71
# Output value range: -6.16 to -6.16
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.16 to 9.60
# Successfully processed bias_2010_11.tif
# Original value range: -3.16 to 9.60
# Output value range: -2.07 to 4.96
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -4.74 to 4.09
# Successfully processed bias_2010_12.tif
# Original value range: -4.74 to 4.09
# Output value range: -3.41 to -0.29
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -11.53 to -0.79
# Successfully processed bias_2011_01.tif
# Original value range: -11.53 to -0.79
# Output value range: -9.78 to -2.57
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.19 to 19.45
# Successfully processed bias_2011_02.tif
# Original value range: -3.19 to 19.45
# Output value range: -1.86 to 16.35
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -13.62 to -1.62
# Successfully processed bias_2011_03.tif
# Original value range: -13.62 to -1.62
# Output value range: -5.04 to -5.04
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -12.87 to -2.20
# Successfully processed bias_2011_04.tif
# Original value range: -12.87 to -2.20
# Output value range: -10.80 to -4.65
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -6.17 to 37.51
# Successfully processed bias_2011_05.tif
# Original value range: -6.17 to 37.51
# Output value range: -4.07 to 31.74
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -15.37 to 49.36
# Successfully processed bias_2011_06.tif
# Original value range: -15.37 to 49.36
# Output value range: 2.02 to 27.03
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -52.19 to 184.31
# Successfully processed bias_2011_07.tif
# Original value range: -52.19 to 184.31
# Output value range: 1.60 to 1.60
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -32.26 to 134.35
# Successfully processed bias_2011_08.tif
# Original value range: -32.26 to 134.35
# Output value range: -15.73 to 107.80
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -22.20 to 148.57
# Successfully processed bias_2011_09.tif
# Original value range: -22.20 to 148.57
# Output value range: -12.54 to 132.29
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -17.47 to -1.82
# Successfully processed bias_2011_10.tif
# Original value range: -17.47 to -1.82
# Output value range: -15.53 to -5.28
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -14.39 to -0.27
# Successfully processed bias_2011_11.tif
# Original value range: -14.39 to -0.27
# Output value range: -10.51 to -3.39
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -5.21 to -0.38
# Successfully processed bias_2011_12.tif
# Original value range: -5.21 to -0.38
# Output value range: -3.96 to -1.73
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -6.12 to 9.67
# Successfully processed bias_2012_01.tif
# Original value range: -6.12 to 9.67
# Output value range: -4.15 to 2.71
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -15.93 to -1.19
# Successfully processed bias_2012_02.tif
# Original value range: -15.93 to -1.19
# Output value range: -9.63 to -5.56
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -11.86 to 6.38
# Successfully processed bias_2012_03.tif
# Original value range: -11.86 to 6.38
# Output value range: -11.45 to 2.78
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.51 to 4.42
# Successfully processed bias_2012_04.tif
# Original value range: -3.51 to 4.42
# Output value range: -2.53 to -0.08
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -18.84 to -2.78
# Successfully processed bias_2012_05.tif
# Original value range: -18.84 to -2.78
# Output value range: -17.05 to -5.87
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -38.59 to -4.01
# Successfully processed bias_2012_06.tif
# Original value range: -38.59 to -4.01
# Output value range: -30.57 to -13.65
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -44.65 to 42.20
# Successfully processed bias_2012_07.tif
# Original value range: -44.65 to 42.20
# Output value range: -38.52 to -5.09
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -46.29 to 130.21
# Successfully processed bias_2012_08.tif
# Original value range: -46.29 to 130.21
# Output value range: -8.51 to -8.51
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.79 to 68.00
# Successfully processed bias_2012_09.tif
# Original value range: -16.79 to 68.00
# Output value range: -10.13 to 59.79
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.55 to -1.71
# Successfully processed bias_2012_10.tif
# Original value range: -16.55 to -1.71
# Output value range: -12.57 to -6.51
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -15.63 to -0.32
# Successfully processed bias_2012_11.tif
# Original value range: -15.63 to -0.32
# Output value range: -12.23 to -2.76
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -4.23 to 5.87
# Successfully processed bias_2012_12.tif
# Original value range: -4.23 to 5.87
# Output value range: -3.18 to 2.55
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -2.36 to 23.42
# Successfully processed bias_2013_01.tif
# Original value range: -2.36 to 23.42
# Output value range: 5.59 to 12.63
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.16 to 86.33
# Successfully processed bias_2013_02.tif
# Original value range: -3.16 to 86.33
# Output value range: 12.38 to 64.33
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -8.49 to 1.50
# Successfully processed bias_2013_03.tif
# Original value range: -8.49 to 1.50
# Output value range: -7.35 to -0.12
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -14.86 to -2.12
# Successfully processed bias_2013_04.tif
# Original value range: -14.86 to -2.12
# Output value range: -13.03 to -4.49
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -19.08 to -2.73
# Successfully processed bias_2013_05.tif
# Original value range: -19.08 to -2.73
# Output value range: -17.67 to -5.96
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -17.38 to 86.34
# Successfully processed bias_2013_06.tif
# Original value range: -17.38 to 86.34
# Output value range: -0.86 to 48.80
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -53.79 to 101.08
# Successfully processed bias_2013_07.tif
# Original value range: -53.79 to 101.08
# Output value range: -16.81 to 27.65
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -38.10 to 66.65
# Successfully processed bias_2013_08.tif
# Original value range: -38.10 to 66.65
# Output value range: -17.14 to 43.90
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -40.10 to 1.76
# Successfully processed bias_2013_09.tif
# Original value range: -40.10 to 1.76
# Output value range: -17.61 to -10.27
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -8.70 to 28.10
# Successfully processed bias_2013_10.tif
# Original value range: -8.70 to 28.10
# Output value range: -8.70 to 23.95
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -7.39 to -0.27
# Successfully processed bias_2013_11.tif
# Original value range: -7.39 to -0.27
# Output value range: -6.11 to -1.19
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.56 to 1.29
# Successfully processed bias_2013_12.tif
# Original value range: -3.56 to 1.29
# Output value range: -2.61 to -0.55
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.93 to 16.72
# Successfully processed bias_2014_01.tif
# Original value range: -3.93 to 16.72
# Output value range: -1.11 to 0.97
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -5.51 to 24.36
# Successfully processed bias_2014_02.tif
# Original value range: -5.51 to 24.36
# Output value range: 1.17 to 3.48
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -2.55 to 41.35
# Successfully processed bias_2014_03.tif
# Original value range: -2.55 to 41.35
# Output value range: 6.39 to 34.64
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -12.45 to -2.12
# Successfully processed bias_2014_04.tif
# Original value range: -12.45 to -2.12
# Output value range: -11.65 to -2.93
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -11.00 to 28.42
# Successfully processed bias_2014_05.tif
# Original value range: -11.00 to 28.42
# Output value range: -3.88 to 18.87
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -14.96 to 12.64
# Successfully processed bias_2014_06.tif
# Original value range: -14.96 to 12.64
# Output value range: -10.26 to 2.06
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -27.05 to 58.18
# Successfully processed bias_2014_07.tif
# Original value range: -27.05 to 58.18
# Output value range: -11.82 to 38.75
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -25.17 to 46.11
# Successfully processed bias_2014_08.tif
# Original value range: -25.17 to 46.11
# Output value range: -19.30 to 25.02
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.79 to 33.93
# Successfully processed bias_2014_09.tif
# Original value range: -16.79 to 33.93
# Output value range: -10.24 to 1.14
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -20.98 to -1.86
# Successfully processed bias_2014_10.tif
# Original value range: -20.98 to -1.86
# Output value range: -18.38 to -5.80
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -6.90 to -0.26
# Successfully processed bias_2014_11.tif
# Original value range: -6.90 to -0.26
# Output value range: -1.85 to -1.85
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -2.02 to 9.69
# Successfully processed bias_2014_12.tif
# Original value range: -2.02 to 9.69
# Output value range: 0.07 to 0.07
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.93 to 14.67
# Successfully processed bias_2015_01.tif
# Original value range: -3.93 to 14.67
# Output value range: 1.15 to 1.15
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -15.19 to -0.10
# Successfully processed bias_2015_02.tif
# Original value range: -15.19 to -0.10
# Output value range: -12.00 to -4.29
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -2.44 to 99.43
# Successfully processed bias_2015_03.tif
# Original value range: -2.44 to 99.43
# Output value range: 22.25 to 22.25
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -6.39 to 31.34
# Successfully processed bias_2015_04.tif
# Original value range: -6.39 to 31.34
# Output value range: -2.28 to 21.21
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -13.26 to -2.68
# Successfully processed bias_2015_05.tif
# Original value range: -13.26 to -2.68
# Output value range: -8.25 to -4.07
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -9.57 to 42.09
# Successfully processed bias_2015_06.tif
# Original value range: -9.57 to 42.09
# Output value range: 0.46 to 22.09
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -35.87 to 191.13
# Successfully processed bias_2015_07.tif
# Original value range: -35.87 to 191.13
# Output value range: 10.38 to 172.27
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -18.55 to 214.77
# Successfully processed bias_2015_08.tif
# Original value range: -18.55 to 214.77
# Output value range: 4.91 to 186.87
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -42.06 to -7.95
# Successfully processed bias_2015_09.tif
# Original value range: -42.06 to -7.95
# Output value range: -37.84 to -12.98
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -14.74 to -1.81
# Successfully processed bias_2015_10.tif
# Original value range: -14.74 to -1.81
# Output value range: -13.03 to -5.01
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -6.37 to -0.26
# Successfully processed bias_2015_11.tif
# Original value range: -6.37 to -0.26
# Output value range: -1.82 to -1.82
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -5.43 to -0.33
# Successfully processed bias_2015_12.tif
# Original value range: -5.43 to -0.33
# Output value range: -1.77 to -1.77
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -9.96 to -0.68
# Successfully processed bias_2016_01.tif
# Original value range: -9.96 to -0.68
# Output value range: -4.42 to -3.52
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -15.65 to -1.08
# Successfully processed bias_2016_02.tif
# Original value range: -15.65 to -1.08
# Output value range: -14.29 to -4.69
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -2.41 to 13.01
# Successfully processed bias_2016_03.tif
# Original value range: -2.41 to 13.01
# Output value range: -0.01 to 4.73
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -18.11 to -2.08
# Successfully processed bias_2016_04.tif
# Original value range: -18.11 to -2.08
# Output value range: -16.51 to -5.69
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -4.06 to 12.78
# Successfully processed bias_2016_05.tif
# Original value range: -4.06 to 12.78
# Output value range: -1.89 to 9.91
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -22.22 to 28.47
# Successfully processed bias_2016_06.tif
# Original value range: -22.22 to 28.47
# Output value range: -19.55 to 5.46
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -74.96 to 170.65
# Successfully processed bias_2016_07.tif
# Original value range: -74.96 to 170.65
# Output value range: 0.64 to 104.73
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -24.60 to 145.26
# Successfully processed bias_2016_08.tif
# Original value range: -24.60 to 145.26
# Output value range: -1.89 to 80.97
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -47.47 to 9.33
# Successfully processed bias_2016_09.tif
# Original value range: -47.47 to 9.33
# Output value range: -31.71 to 2.84
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -14.72 to -1.82
# Successfully processed bias_2016_10.tif
# Original value range: -14.72 to -1.82
# Output value range: -12.82 to -3.81
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -6.88 to -0.27
# Successfully processed bias_2016_11.tif
# Original value range: -6.88 to -0.27
# Output value range: -1.89 to -1.61
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -5.43 to -0.34
# Successfully processed bias_2016_12.tif
# Original value range: -5.43 to -0.34
# Output value range: -1.81 to -1.81
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -1.70 to 39.61
# Successfully processed bias_2017_01.tif
# Original value range: -1.70 to 39.61
# Output value range: 6.01 to 25.46
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -10.93 to -1.13
# Successfully processed bias_2017_02.tif
# Original value range: -10.93 to -1.13
# Output value range: -9.88 to -3.31
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -9.70 to 1.78
# Successfully processed bias_2017_03.tif
# Original value range: -9.70 to 1.78
# Output value range: -5.61 to -2.06
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -13.57 to 4.33
# Successfully processed bias_2017_04.tif
# Original value range: -13.57 to 4.33
# Output value range: -4.19 to -3.85
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -8.07 to 3.59
# Successfully processed bias_2017_05.tif
# Original value range: -8.07 to 3.59
# Output value range: -3.56 to -3.56
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -10.04 to 162.94
# Successfully processed bias_2017_06.tif
# Original value range: -10.04 to 162.94
# Output value range: 6.42 to 132.50
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -13.44 to 73.94
# Successfully processed bias_2017_07.tif
# Original value range: -13.44 to 73.94
# Output value range: -1.01 to 58.20
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -27.05 to 69.83
# Successfully processed bias_2017_08.tif
# Original value range: -27.05 to 69.83
# Output value range: -4.66 to -4.66
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -29.61 to 172.63
# Successfully processed bias_2017_09.tif
# Original value range: -29.61 to 172.63
# Output value range: -8.49 to 103.60
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.73 to -1.81
# Successfully processed bias_2017_10.tif
# Original value range: -16.73 to -1.81
# Output value range: -13.95 to -6.19
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -12.29 to -0.32
# Successfully processed bias_2017_11.tif
# Original value range: -12.29 to -0.32
# Output value range: -10.84 to -1.83
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -1.90 to 1.14
# Successfully processed bias_2017_12.tif
# Original value range: -1.90 to 1.14
# Output value range: -1.23 to 0.74
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -5.28 to -0.66
# Successfully processed bias_2018_01.tif
# Original value range: -5.28 to -0.66
# Output value range: -4.58 to -1.48
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -15.58 to -1.07
# Successfully processed bias_2018_02.tif
# Original value range: -15.58 to -1.07
# Output value range: -5.24 to -5.10
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -12.62 to -1.55
# Successfully processed bias_2018_03.tif
# Original value range: -12.62 to -1.55
# Output value range: -10.65 to -4.60
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -15.40 to -2.20
# Successfully processed bias_2018_04.tif
# Original value range: -15.40 to -2.20
# Output value range: -14.01 to -3.17
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.64 to -0.97
# Successfully processed bias_2018_05.tif
# Original value range: -16.64 to -0.97
# Output value range: -13.80 to -2.76
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -15.50 to 57.91
# Successfully processed bias_2018_06.tif
# Original value range: -15.50 to 57.91
# Output value range: -14.31 to 40.85
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -53.89 to 160.17
# Successfully processed bias_2018_07.tif
# Original value range: -53.89 to 160.17
# Output value range: 6.98 to 74.30
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -79.36 to 73.69
# Successfully processed bias_2018_08.tif
# Original value range: -79.36 to 73.69
# Output value range: -13.89 to -13.89
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -23.90 to 127.00
# Successfully processed bias_2018_09.tif
# Original value range: -23.90 to 127.00
# Output value range: 6.86 to 98.39
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -17.21 to -1.69
# Successfully processed bias_2018_10.tif
# Original value range: -17.21 to -1.69
# Output value range: -15.75 to -5.11
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -1.46 to 2.75
# Successfully processed bias_2018_11.tif
# Original value range: -1.46 to 2.75
# Output value range: -0.31 to 1.68
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -5.26 to -0.32
# Successfully processed bias_2018_12.tif
# Original value range: -5.26 to -0.32
# Output value range: -3.88 to -1.66
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -1.41 to 31.96
# Successfully processed bias_2019_01.tif
# Original value range: -1.41 to 31.96
# Output value range: 4.46 to 17.18
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -5.94 to 28.07
# Successfully processed bias_2019_02.tif
# Original value range: -5.94 to 28.07
# Output value range: -2.05 to 18.42
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -8.98 to 2.40
# Successfully processed bias_2019_03.tif
# Original value range: -8.98 to 2.40
# Output value range: -3.27 to -2.83
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -15.96 to -2.08
# Successfully processed bias_2019_04.tif
# Original value range: -15.96 to -2.08
# Output value range: -14.42 to -3.40
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -10.27 to 13.54
# Successfully processed bias_2019_05.tif
# Original value range: -10.27 to 13.54
# Output value range: -0.54 to -0.54
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -26.85 to -4.01
# Successfully processed bias_2019_06.tif
# Original value range: -26.85 to -4.01
# Output value range: -21.33 to -7.24
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -47.35 to 60.41
# Successfully processed bias_2019_07.tif
# Original value range: -47.35 to 60.41
# Output value range: -19.37 to 0.24
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -45.52 to 86.57
# Successfully processed bias_2019_08.tif
# Original value range: -45.52 to 86.57
# Output value range: -28.71 to 71.60
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -47.66 to -11.43
# Successfully processed bias_2019_09.tif
# Original value range: -47.66 to -11.43
# Output value range: -41.25 to -19.96
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -12.43 to 18.83
# Successfully processed bias_2019_10.tif
# Original value range: -12.43 to 18.83
# Output value range: -10.24 to 13.64
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -6.40 to 2.87
# Successfully processed bias_2019_11.tif
# Original value range: -6.40 to 2.87
# Output value range: -0.66 to -0.66
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -6.40 to 22.79
# Successfully processed bias_2019_12.tif
# Original value range: -6.40 to 22.79
# Output value range: 1.83 to 16.70
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -1.74 to 33.36
# Successfully processed bias_2020_01.tif
# Original value range: -1.74 to 33.36
# Output value range: 4.47 to 4.47
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -11.40 to -1.24
# Successfully processed bias_2020_02.tif
# Original value range: -11.40 to -1.24
# Output value range: -5.75 to -4.21
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -2.39 to 77.71
# Successfully processed bias_2020_03.tif
# Original value range: -2.39 to 77.71
# Output value range: 11.96 to 57.89
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -11.68 to -2.16
# Successfully processed bias_2020_04.tif
# Original value range: -11.68 to -2.16
# Output value range: -9.96 to -3.05
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.38 to 11.87
# Successfully processed bias_2020_05.tif
# Original value range: -3.38 to 11.87
# Output value range: -1.32 to 9.97
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -18.87 to 42.10
# Successfully processed bias_2020_06.tif
# Original value range: -18.87 to 42.10
# Output value range: -6.67 to 32.85
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.16 to 173.97
# Successfully processed bias_2020_07.tif
# Original value range: -16.16 to 173.97
# Output value range: 8.24 to 168.00
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -21.35 to 202.01
# Successfully processed bias_2020_08.tif
# Original value range: -21.35 to 202.01
# Output value range: 23.56 to 23.56
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -52.94 to -7.88
# Successfully processed bias_2020_09.tif
# Original value range: -52.94 to -7.88
# Output value range: -47.25 to -14.22
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.45 to -1.81
# Successfully processed bias_2020_10.tif
# Original value range: -16.45 to -1.81
# Output value range: -6.48 to -6.48
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -2.62 to -0.32
# Successfully processed bias_2020_11.tif
# Original value range: -2.62 to -0.32
# Output value range: -1.91 to -0.74
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.29 to -0.33
# Successfully processed bias_2020_12.tif
# Original value range: -3.29 to -0.33
# Output value range: -2.72 to -1.07
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.64 to 43.69
# Successfully processed bias_2021_01.tif
# Original value range: -3.64 to 43.69
# Output value range: 7.73 to 7.73
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -10.26 to -1.07
# Successfully processed bias_2021_02.tif
# Original value range: -10.26 to -1.07
# Output value range: -5.96 to -3.83
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -9.90 to 9.34
# Successfully processed bias_2021_03.tif
# Original value range: -9.90 to 9.34
# Output value range: -6.12 to -0.44
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.39 to -2.18
# Successfully processed bias_2021_04.tif
# Original value range: -16.39 to -2.18
# Output value range: -13.38 to -5.32
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -8.10 to 117.58
# Successfully processed bias_2021_05.tif
# Original value range: -8.10 to 117.58
# Output value range: 20.28 to 20.28
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -19.11 to 3.21
# Successfully processed bias_2021_06.tif
# Original value range: -19.11 to 3.21
# Output value range: -13.82 to -4.33
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -30.23 to 356.30
# Successfully processed bias_2021_07.tif
# Original value range: -30.23 to 356.30
# Output value range: 1.87 to 340.74
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -27.19 to 127.94
# Successfully processed bias_2021_08.tif
# Original value range: -27.19 to 127.94
# Output value range: 13.41 to 35.74
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -26.69 to 247.76
# Successfully processed bias_2021_09.tif
# Original value range: -26.69 to 247.76
# Output value range: 41.65 to 137.01
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -4.34 to 79.39
# Successfully processed bias_2021_10.tif
# Original value range: -4.34 to 79.39
# Output value range: 7.47 to 63.03
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.27 to -0.31
# Successfully processed bias_2021_11.tif
# Original value range: -3.27 to -0.31
# Output value range: -2.84 to -1.09
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.60 to 3.80
# Successfully processed bias_2021_12.tif
# Original value range: -3.60 to 3.80
# Output value range: -1.42 to -0.29
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.36 to 85.04
# Successfully processed bias_2022_01.tif
# Original value range: -3.36 to 85.04
# Output value range: 20.86 to 20.86
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -2.88 to 10.31
# Successfully processed bias_2022_02.tif
# Original value range: -2.88 to 10.31
# Output value range: 0.72 to 5.60
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -10.12 to -1.46
# Successfully processed bias_2022_03.tif
# Original value range: -10.12 to -1.46
# Output value range: -9.23 to -3.58
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -16.42 to -2.08
# Successfully processed bias_2022_04.tif
# Original value range: -16.42 to -2.08
# Output value range: -14.20 to -6.31
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -8.43 to 42.78
# Successfully processed bias_2022_05.tif
# Original value range: -8.43 to 42.78
# Output value range: 0.75 to 35.23
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -15.21 to 21.78
# Successfully processed bias_2022_06.tif
# Original value range: -15.21 to 21.78
# Output value range: -13.89 to 16.63
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -30.70 to 233.62
# Successfully processed bias_2022_07.tif
# Original value range: -30.70 to 233.62
# Output value range: 1.99 to 150.52
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -40.97 to 7.48
# Successfully processed bias_2022_08.tif
# Original value range: -40.97 to 7.48
# Output value range: -34.47 to 5.15
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -21.23 to 171.40
# Successfully processed bias_2022_09.tif
# Original value range: -21.23 to 171.40
# Output value range: 5.91 to 135.66
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -4.65 to 91.70
# Successfully processed bias_2022_10.tif
# Original value range: -4.65 to 91.70
# Output value range: 18.65 to 18.65
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.36 to -0.27
# Successfully processed bias_2022_11.tif
# Original value range: -3.36 to -0.27
# Output value range: -2.19 to -1.28
# Number of valid points: 15
# X range: 76.38 to 77.62
# Y range: 28.15 to 29.05
# Z range: -3.65 to -0.34
# Successfully processed bias_2022_12.tif
# Original value range: -3.65 to -0.34
# Output value range: -2.40 to -1.29
