# %%
import os
import rasterio
import numpy as np
import glob
from rasterio.warp import reproject, Resampling
def parse_rainfall_filename(filename):
    try:
        base_name = os.path.basename(filename)
        name_parts = base_name.split('.')
        name_without_ext = name_parts[0]
        
        # Handle rainfall_YYYY-MM format directly
        if name_without_ext.startswith("rainfall_") and "-" in name_without_ext:
            date_part = name_without_ext.split("rainfall_")[1]
            year, month = date_part.split("-")
            if year.isdigit() and month.isdigit() and len(year) == 4:
                month = month.zfill(2)  # Ensure month has 2 digits
                underscore_date = f"{year}_{month}"
                hyphen_date = f"{year}-{month}"
                return underscore_date, hyphen_date
        
        # Existing logic as fallback
        parts = name_without_ext.split('_')
        
        if len(parts) >= 3 and parts[-2].isdigit() and parts[-1].isdigit():
            year = parts[-2]
            month = parts[-1].zfill(2)  # Ensure month has 2 digits
            underscore_date = f"{year}_{month}"
            hyphen_date = f"{year}-{month}"
            return underscore_date, hyphen_date
        
        for i in range(len(parts)):
            if parts[i].isdigit() and len(parts[i]) == 4:  # Potential year
                year = parts[i]
                if i+1 < len(parts) and parts[i+1].isdigit():  # Next part is potential month
                    month = parts[i+1].zfill(2)
                    underscore_date = f"{year}_{month}"
                    hyphen_date = f"{year}-{month}"
                    return underscore_date, hyphen_date
        
        raise ValueError(f"Date pattern not found in filename: {filename}")
    except Exception as e:
        raise ValueError(f"Unable to parse date from filename: {filename}") from e

def resample_bias_to_rainfall(bias_dataset, rainfall_dataset):
    dst_shape = rainfall_dataset.shape
    dst_transform = rainfall_dataset.transform
    dst_crs = rainfall_dataset.crs
    
    resampled_data = np.zeros(dst_shape, dtype='float32')
    
    reproject(
        source=rasterio.band(bias_dataset, 1),
        destination=resampled_data,
        src_transform=bias_dataset.transform,
        src_crs=bias_dataset.crs,
        dst_transform=dst_transform,
        dst_crs=dst_crs,
        resampling=Resampling.bilinear
    )
    
    return resampled_data

def validate_and_correct_data(rainfall_data, bias_data, rainfall_nodata):
    rainfall_mask = (rainfall_data == rainfall_nodata) if rainfall_nodata is not None else np.zeros_like(rainfall_data, dtype=bool)
    bias_mask = np.isnan(bias_data)
    
    valid_mask = ~(rainfall_mask | bias_mask)
    
    corrected_data = np.full_like(rainfall_data, rainfall_nodata if rainfall_nodata is not None else -999)
    
    corrected_data[valid_mask] = rainfall_data[valid_mask] + bias_data[valid_mask]
    
    negative_rainfall = (corrected_data < 0) & valid_mask
    if np.any(negative_rainfall):
        negative_count = np.sum(negative_rainfall)
        total_valid = np.sum(valid_mask)
        print(f"Warning: {negative_count} pixels ({negative_count/total_valid*100:.2f}%) would have negative rainfall after bias correction")
        print("Setting these values to zero")
        corrected_data[negative_rainfall] = 0
    
    max_reasonable_rainfall = 2000  # mm/month (adjust based on your data's units and region)
    excessive_rainfall = (corrected_data > max_reasonable_rainfall) & valid_mask
    
    if np.any(excessive_rainfall):
        excessive_count = np.sum(excessive_rainfall)
        print(f"Warning: {excessive_count} pixels have extremely high rainfall values after correction")
        print(f"Range of these values: {np.min(corrected_data[excessive_rainfall]):.2f} to {np.max(corrected_data[excessive_rainfall]):.2f}")
        corrected_data[excessive_rainfall] = max_reasonable_rainfall
        print(f"Capped extremely high values at {max_reasonable_rainfall}")
    
    return corrected_data

def apply_bias_correction(rainfall_dir, bias_dir, output_dir):
    os.makedirs(output_dir, exist_ok=True)
    
    rainfall_files = glob.glob(os.path.join(rainfall_dir, "*.tif"))
    print(f"Found {len(rainfall_files)} rainfall files to process")
    
    processed = 0
    errors = 0
    skipped = 0
    
    for rainfall_file in rainfall_files:
        try:
            rainfall_filename = os.path.basename(rainfall_file)
            print(f"\nProcessing {rainfall_filename}...")
            
            date_str, date_str_hyphen = parse_rainfall_filename(rainfall_filename)
            year, month = date_str.split('_')
            print(f"Looking for bias file with date: {date_str_hyphen}")
            
            bias_file = os.path.join(bias_dir, f"bias_{year}_{month}.tif")
            if not os.path.exists(bias_file):
                print(f"Skipping {date_str_hyphen}, no matching bias file found.")
                skipped += 1
                continue
            
            with rasterio.open(rainfall_file) as rainfall_dataset, rasterio.open(bias_file) as bias_dataset:
                rainfall_data = rainfall_dataset.read(1)
                
                print(f"Rainfall data statistics:")
                valid_rainfall = rainfall_data[rainfall_data != (rainfall_dataset.nodata if rainfall_dataset.nodata is not None else -999)]
                if valid_rainfall.size > 0:
                    print(f"  Min: {np.min(valid_rainfall):.2f}, Max: {np.max(valid_rainfall):.2f}, Mean: {np.mean(valid_rainfall):.2f}")
                
                print("Resampling bias data...")
                bias_data = resample_bias_to_rainfall(bias_dataset, rainfall_dataset)
                
                print(f"Bias data statistics:")
                valid_bias = bias_data[~np.isnan(bias_data)]
                if valid_bias.size > 0:
                    print(f"  Min: {np.min(valid_bias):.2f}, Max: {np.max(valid_bias):.2f}, Mean: {np.mean(valid_bias):.2f}")
                    if np.mean(valid_bias) < 0 and np.mean(valid_rainfall) > 0:
                        print("  Note: Bias is predominantly negative while rainfall is positive")
                    if abs(np.mean(valid_bias)) > np.mean(valid_rainfall):
                        print("  Warning: Average bias magnitude exceeds average rainfall. Check bias calculation.")
                
                print("Applying bias correction with validation...")
                corrected_rainfall = validate_and_correct_data(
                    rainfall_data, 
                    bias_data, 
                    rainfall_dataset.nodata
                )
                
                valid_mask = corrected_rainfall != (rainfall_dataset.nodata if rainfall_dataset.nodata is not None else -999)
                if np.any(valid_mask):
                    print(f"Valid corrected data statistics:")
                    print(f"  Min: {np.min(corrected_rainfall[valid_mask]):.2f}")
                    print(f"  Max: {np.max(corrected_rainfall[valid_mask]):.2f}")
                    print(f"  Mean: {np.mean(corrected_rainfall[valid_mask]):.2f}")
                    
                    if valid_rainfall.size > 0:
                        total_rainfall_before = np.sum(valid_rainfall)
                        total_rainfall_after = np.sum(corrected_rainfall[valid_mask])
                        change_percent = ((total_rainfall_after - total_rainfall_before) / total_rainfall_before) * 100
                        
                        print(f"  Total rainfall before correction: {total_rainfall_before:.2f}")
                        print(f"  Total rainfall after correction: {total_rainfall_after:.2f}")
                        print(f"  Change in total rainfall: {change_percent:.2f}%")
                        
                        if abs(change_percent) > 50:
                            print("  WARNING: Very large change in total rainfall after bias correction!")
                output_profile = rainfall_dataset.profile.copy()
                output_profile.update({
                    'compress': 'lzw',
                    'nodata': rainfall_dataset.nodata if rainfall_dataset.nodata is not None else -999,
                    'dtype': 'float32'
                })
                
                output_file = os.path.join(output_dir, f"corrected_{rainfall_filename}")
                with rasterio.open(output_file, 'w', **output_profile) as dst:
                    dst.write(corrected_rainfall.astype('float32'), 1)
                
                processed += 1
                print(f"Successfully processed: {output_file}")
                
        except Exception as e:
            print(f"Error processing {os.path.basename(rainfall_file)}: {str(e)}")
            errors += 1
            import traceback
            print("Detailed error:")
            print(traceback.format_exc())
    
    print(f"\nProcessing Summary:")
    print(f"Total files: {len(rainfall_files)}")
    print(f"Successfully processed: {processed}")
    print(f"Skipped: {skipped}")
    print(f"Errors: {errors}")

def main():
    rainfall_dir = r"/home/stormej/dev/rainscale/data/ml/prediction/prediction_0.01"
    bias_dir = r"/home/stormej/dev/rainscale/data/bias/bias_kriging_0.01"
    output_dir = r"/home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01"
    
    print("Starting rainfall bias correction...")
    apply_bias_correction(rainfall_dir, bias_dir, output_dir)
    print("Correction completed!")

main()
# Out:
# Starting rainfall bias correction...
# Found 277 rainfall files to process
#
# Processing rainfall_2000-02.tif...
# Looking for bias file with date: 2000-02
# Rainfall data statistics:
#   Min: 9.63, Max: 25.11, Mean: 14.54
# Resampling bias data...
# Bias data statistics:
#   Min: 6.48, Max: 6.48, Mean: 6.48
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 16.11
#   Max: 31.59
#   Mean: 21.01
#   Total rainfall before correction: 85760.03
#   Total rainfall after correction: 123963.45
#   Change in total rainfall: 44.55%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2000-02.tif
#
# Processing rainfall_2000-03.tif...
# Looking for bias file with date: 2000-03
# Rainfall data statistics:
#   Min: 9.83, Max: 44.98, Mean: 14.17
# Resampling bias data...
# Bias data statistics:
#   Min: -11.62, Max: -4.02, Mean: -5.02
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 2.05
#   Max: 40.10
#   Mean: 9.15
#   Total rainfall before correction: 83618.28
#   Total rainfall after correction: 53978.55
#   Change in total rainfall: -35.45%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2000-03.tif
#
# Processing rainfall_2000-04.tif...
# Looking for bias file with date: 2000-04
# Rainfall data statistics:
#   Min: 11.81, Max: 74.56, Mean: 14.95
# Resampling bias data...
# Bias data statistics:
#   Min: -15.12, Max: -5.02, Mean: -8.77
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 299 pixels (5.07%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 64.17
#   Mean: 6.23
#   Total rainfall before correction: 88209.77
#   Total rainfall after correction: 36745.25
#   Change in total rainfall: -58.34%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2000-04.tif
#
# Processing rainfall_2000-05.tif...
# Looking for bias file with date: 2000-05
# Rainfall data statistics:
#   Min: 16.91, Max: 78.22, Mean: 31.37
# Resampling bias data...
# Bias data statistics:
#   Min: -16.43, Max: -1.03, Mean: -7.22
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 2.01
#   Max: 74.46
#   Mean: 24.15
#   Total rainfall before correction: 185065.91
#   Total rainfall after correction: 142485.22
#   Change in total rainfall: -23.01%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2000-05.tif
#
# Processing rainfall_2000-06.tif...
# Looking for bias file with date: 2000-06
# Rainfall data statistics:
#   Min: 36.31, Max: 94.80, Mean: 74.62
# Resampling bias data...
# Bias data statistics:
#   Min: -12.28, Max: 57.44, Mean: 2.02
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 34.86
#   Max: 148.13
#   Mean: 76.64
#   Total rainfall before correction: 440276.53
#   Total rainfall after correction: 452196.88
#   Change in total rainfall: 2.71%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2000-06.tif
#
# Processing rainfall_2000-07.tif...
# Looking for bias file with date: 2000-07
# Rainfall data statistics:
#   Min: 86.39, Max: 191.89, Mean: 139.46
# Resampling bias data...
# Bias data statistics:
#   Min: 2.28, Max: 58.82, Mean: 2.42
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 88.67
#   Max: 222.21
#   Mean: 141.87
#   Total rainfall before correction: 822798.00
#   Total rainfall after correction: 837049.75
#   Change in total rainfall: 1.73%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2000-07.tif
#
# Processing rainfall_2000-08.tif...
# Looking for bias file with date: 2000-08
# Rainfall data statistics:
#   Min: 60.42, Max: 208.96, Mean: 111.94
# Resampling bias data...
# Bias data statistics:
#   Min: 9.69, Max: 186.12, Mean: 73.57
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 71.65
#   Max: 345.96
#   Mean: 185.51
#   Total rainfall before correction: 660430.38
#   Total rainfall after correction: 1094508.25
#   Change in total rainfall: 65.73%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2000-08.tif
#
# Processing rainfall_2000-09.tif...
# Looking for bias file with date: 2000-09
# Rainfall data statistics:
#   Min: 56.87, Max: 175.24, Mean: 88.09
# Resampling bias data...
# Bias data statistics:
#   Min: -22.20, Max: -22.20, Mean: -22.20
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 34.67
#   Max: 153.04
#   Mean: 65.89
#   Total rainfall before correction: 519734.62
#   Total rainfall after correction: 388774.66
#   Change in total rainfall: -25.20%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2000-09.tif
#
# Processing rainfall_2000-10.tif...
# Looking for bias file with date: 2000-10
# Rainfall data statistics:
#   Min: 9.77, Max: 73.08, Mean: 16.08
# Resampling bias data...
# Bias data statistics:
#   Min: -17.61, Max: -7.09, Mean: -7.23
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 15 pixels (0.25%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 64.19
#   Mean: 8.86
#   Total rainfall before correction: 94863.77
#   Total rainfall after correction: 52250.94
#   Change in total rainfall: -44.92%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2000-10.tif
#
# Processing rainfall_2000-11.tif...
# Looking for bias file with date: 2000-11
# Rainfall data statistics:
#   Min: 1.64, Max: 70.22, Mean: 12.45
# Resampling bias data...
# Bias data statistics:
#   Min: -14.13, Max: -1.29, Mean: -5.00
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 1571 pixels (26.63%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 64.03
#   Mean: 7.94
#   Total rainfall before correction: 73467.98
#   Total rainfall after correction: 46868.73
#   Change in total rainfall: -36.21%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2000-11.tif
#
# Processing rainfall_2000-12.tif...
# Looking for bias file with date: 2000-12
# Rainfall data statistics:
#   Min: 2.16, Max: 8.81, Mean: 3.33
# Resampling bias data...
# Bias data statistics:
#   Min: -4.25, Max: -1.08, Mean: -2.00
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 517 pixels (8.76%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 6.79
#   Mean: 1.35
#   Total rainfall before correction: 19639.21
#   Total rainfall after correction: 7975.46
#   Change in total rainfall: -59.39%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2000-12.tif
#
# Processing rainfall_2001-01.tif...
# Looking for bias file with date: 2001-01
# Rainfall data statistics:
#   Min: 6.45, Max: 15.50, Mean: 8.74
# Resampling bias data...
# Bias data statistics:
#   Min: -1.11, Max: 9.48, Mean: 4.09
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 6.09
#   Max: 24.51
#   Mean: 12.83
#   Total rainfall before correction: 51566.98
#   Total rainfall after correction: 75723.28
#   Change in total rainfall: 46.84%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2001-01.tif
#
# Processing rainfall_2001-02.tif...
# Looking for bias file with date: 2001-02
# Rainfall data statistics:
#   Min: 9.63, Max: 33.18, Mean: 14.05
# Resampling bias data...
# Bias data statistics:
#   Min: -3.82, Max: -3.08, Mean: -3.32
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 6.18
#   Max: 29.85
#   Mean: 10.73
#   Total rainfall before correction: 82901.50
#   Total rainfall after correction: 63312.80
#   Change in total rainfall: -23.63%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2001-02.tif
#
# Processing rainfall_2001-03.tif...
# Looking for bias file with date: 2001-03
# Rainfall data statistics:
#   Min: 9.70, Max: 48.09, Mean: 14.85
# Resampling bias data...
# Bias data statistics:
#   Min: -6.48, Max: -2.15, Mean: -4.47
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 4.18
#   Max: 43.02
#   Mean: 10.38
#   Total rainfall before correction: 87638.98
#   Total rainfall after correction: 61258.07
#   Change in total rainfall: -30.10%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2001-03.tif
#
# Processing rainfall_2001-04.tif...
# Looking for bias file with date: 2001-04
# Rainfall data statistics:
#   Min: 11.81, Max: 77.95, Mean: 18.40
# Resampling bias data...
# Bias data statistics:
#   Min: -6.28, Max: 4.04, Mean: -1.72
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 6.00
#   Max: 79.21
#   Mean: 16.68
#   Total rainfall before correction: 108541.84
#   Total rainfall after correction: 98393.90
#   Change in total rainfall: -9.35%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2001-04.tif
#
# Processing rainfall_2001-05.tif...
# Looking for bias file with date: 2001-05
# Rainfall data statistics:
#   Min: 17.82, Max: 92.76, Mean: 54.27
# Resampling bias data...
# Bias data statistics:
#   Min: -13.06, Max: 42.70, Mean: 13.75
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 6.34
#   Max: 131.62
#   Mean: 68.02
#   Total rainfall before correction: 320201.62
#   Total rainfall after correction: 401324.81
#   Change in total rainfall: 25.34%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2001-05.tif
#
# Processing rainfall_2001-06.tif...
# Looking for bias file with date: 2001-06
# Rainfall data statistics:
#   Min: 29.18, Max: 93.50, Mean: 66.10
# Resampling bias data...
# Bias data statistics:
#   Min: 8.21, Max: 94.20, Mean: 26.39
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 41.49
#   Max: 171.23
#   Mean: 92.49
#   Total rainfall before correction: 389972.44
#   Total rainfall after correction: 545662.00
#   Change in total rainfall: 39.92%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2001-06.tif
#
# Processing rainfall_2001-07.tif...
# Looking for bias file with date: 2001-07
# Rainfall data statistics:
#   Min: 90.12, Max: 202.91, Mean: 142.14
# Resampling bias data...
# Bias data statistics:
#   Min: -31.96, Max: 71.95, Mean: -0.25
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 88.01
#   Max: 257.72
#   Mean: 141.89
#   Total rainfall before correction: 838620.56
#   Total rainfall after correction: 837164.50
#   Change in total rainfall: -0.17%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2001-07.tif
#
# Processing rainfall_2001-08.tif...
# Looking for bias file with date: 2001-08
# Rainfall data statistics:
#   Min: 62.44, Max: 199.72, Mean: 100.61
# Resampling bias data...
# Bias data statistics:
#   Min: -3.03, Max: 53.01, Mean: 5.03
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 67.41
#   Max: 204.69
#   Mean: 105.64
#   Total rainfall before correction: 593580.75
#   Total rainfall after correction: 623278.50
#   Change in total rainfall: 5.00%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2001-08.tif
#
# Processing rainfall_2001-09.tif...
# Looking for bias file with date: 2001-09
# Rainfall data statistics:
#   Min: 54.01, Max: 149.18, Mean: 77.21
# Resampling bias data...
# Bias data statistics:
#   Min: -40.07, Max: -13.97, Mean: -25.25
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 18.34
#   Max: 125.96
#   Mean: 51.96
#   Total rainfall before correction: 455544.59
#   Total rainfall after correction: 306563.12
#   Change in total rainfall: -32.70%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2001-09.tif
#
# Processing rainfall_2001-10.tif...
# Looking for bias file with date: 2001-10
# Rainfall data statistics:
#   Min: 9.79, Max: 76.38, Mean: 23.56
# Resampling bias data...
# Bias data statistics:
#   Min: -22.51, Max: 2.40, Mean: -7.19
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 511 pixels (8.66%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 71.86
#   Mean: 16.65
#   Total rainfall before correction: 138982.16
#   Total rainfall after correction: 98210.95
#   Change in total rainfall: -29.34%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2001-10.tif
#
# Processing rainfall_2001-11.tif...
# Looking for bias file with date: 2001-11
# Rainfall data statistics:
#   Min: 1.64, Max: 30.07, Mean: 4.08
# Resampling bias data...
# Bias data statistics:
#   Min: -4.71, Max: -1.25, Mean: -1.72
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 607 pixels (10.29%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 28.60
#   Mean: 2.42
#   Total rainfall before correction: 24099.64
#   Total rainfall after correction: 14266.96
#   Change in total rainfall: -40.80%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2001-11.tif
#
# Processing rainfall_2001-12.tif...
# Looking for bias file with date: 2001-12
# Rainfall data statistics:
#   Min: 2.56, Max: 11.49, Mean: 4.26
# Resampling bias data...
# Bias data statistics:
#   Min: -4.58, Max: -1.96, Mean: -2.02
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 38 pixels (0.64%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 9.42
#   Mean: 2.25
#   Total rainfall before correction: 25152.44
#   Total rainfall after correction: 13258.41
#   Change in total rainfall: -47.29%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2001-12.tif
#
# Processing rainfall_2002-01.tif...
# Looking for bias file with date: 2002-01
# Rainfall data statistics:
#   Min: 6.44, Max: 15.50, Mean: 10.11
# Resampling bias data...
# Bias data statistics:
#   Min: 1.64, Max: 10.70, Mean: 1.70
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 8.08
#   Max: 24.69
#   Mean: 11.80
#   Total rainfall before correction: 59620.98
#   Total rainfall after correction: 69638.39
#   Change in total rainfall: 16.80%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2002-01.tif
#
# Processing rainfall_2002-02.tif...
# Looking for bias file with date: 2002-02
# Rainfall data statistics:
#   Min: 10.02, Max: 28.34, Mean: 18.41
# Resampling bias data...
# Bias data statistics:
#   Min: -2.01, Max: 9.77, Mean: 1.05
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 8.57
#   Max: 32.46
#   Mean: 19.46
#   Total rainfall before correction: 108633.06
#   Total rainfall after correction: 114822.16
#   Change in total rainfall: 5.70%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2002-02.tif
#
# Processing rainfall_2002-03.tif...
# Looking for bias file with date: 2002-03
# Rainfall data statistics:
#   Min: 9.59, Max: 46.30, Mean: 13.51
# Resampling bias data...
# Bias data statistics:
#   Min: -9.84, Max: -3.94, Mean: -5.55
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 1.59
#   Max: 38.24
#   Mean: 7.95
#   Total rainfall before correction: 79700.29
#   Total rainfall after correction: 46930.82
#   Change in total rainfall: -41.12%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2002-03.tif
#
# Processing rainfall_2002-04.tif...
# Looking for bias file with date: 2002-04
# Rainfall data statistics:
#   Min: 11.81, Max: 79.83, Mean: 16.06
# Resampling bias data...
# Bias data statistics:
#   Min: -14.52, Max: -7.09, Mean: -7.19
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 5 pixels (0.08%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 72.74
#   Mean: 8.87
#   Total rainfall before correction: 94744.77
#   Total rainfall after correction: 52343.12
#   Change in total rainfall: -44.75%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2002-04.tif
#
# Processing rainfall_2002-05.tif...
# Looking for bias file with date: 2002-05
# Rainfall data statistics:
#   Min: 16.78, Max: 86.70, Mean: 32.77
# Resampling bias data...
# Bias data statistics:
#   Min: 5.32, Max: 99.01, Mean: 18.58
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 25.05
#   Max: 173.33
#   Mean: 51.35
#   Total rainfall before correction: 193358.27
#   Total rainfall after correction: 302981.44
#   Change in total rainfall: 56.69%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2002-05.tif
#
# Processing rainfall_2002-06.tif...
# Looking for bias file with date: 2002-06
# Rainfall data statistics:
#   Min: 28.88, Max: 90.65, Mean: 50.08
# Resampling bias data...
# Bias data statistics:
#   Min: -12.56, Max: 36.40, Mean: -2.60
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 17.94
#   Max: 94.69
#   Mean: 47.48
#   Total rainfall before correction: 295451.81
#   Total rainfall after correction: 280112.47
#   Change in total rainfall: -5.19%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2002-06.tif
#
# Processing rainfall_2002-07.tif...
# Looking for bias file with date: 2002-07
# Rainfall data statistics:
#   Min: 69.29, Max: 183.58, Mean: 100.29
# Resampling bias data...
# Bias data statistics:
#   Min: -45.12, Max: -18.69, Mean: -27.91
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 32.42
#   Max: 154.09
#   Mean: 72.37
#   Total rainfall before correction: 591690.00
#   Total rainfall after correction: 426995.62
#   Change in total rainfall: -27.83%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2002-07.tif
#
# Processing rainfall_2002-08.tif...
# Looking for bias file with date: 2002-08
# Rainfall data statistics:
#   Min: 80.19, Max: 207.54, Mean: 150.95
# Resampling bias data...
# Bias data statistics:
#   Min: -43.83, Max: 14.35, Mean: -5.59
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 74.61
#   Max: 205.84
#   Mean: 145.36
#   Total rainfall before correction: 890580.00
#   Total rainfall after correction: 857612.69
#   Change in total rainfall: -3.70%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2002-08.tif
#
# Processing rainfall_2002-09.tif...
# Looking for bias file with date: 2002-09
# Rainfall data statistics:
#   Min: 63.03, Max: 187.36, Mean: 105.16
# Resampling bias data...
# Bias data statistics:
#   Min: 20.38, Max: 117.06, Mean: 23.13
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 83.78
#   Max: 254.37
#   Mean: 128.28
#   Total rainfall before correction: 620437.44
#   Total rainfall after correction: 756877.19
#   Change in total rainfall: 21.99%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2002-09.tif
#
# Processing rainfall_2002-10.tif...
# Looking for bias file with date: 2002-10
# Rainfall data statistics:
#   Min: 9.79, Max: 77.57, Mean: 16.32
# Resampling bias data...
# Bias data statistics:
#   Min: -14.75, Max: -5.90, Mean: -7.58
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 174 pixels (2.95%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 68.51
#   Mean: 8.77
#   Total rainfall before correction: 96285.02
#   Total rainfall after correction: 51772.08
#   Change in total rainfall: -46.23%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2002-10.tif
#
# Processing rainfall_2002-11.tif...
# Looking for bias file with date: 2002-11
# Rainfall data statistics:
#   Min: 1.64, Max: 44.05, Mean: 4.47
# Resampling bias data...
# Bias data statistics:
#   Min: -3.81, Max: -1.25, Mean: -1.75
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 669 pixels (11.34%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 42.63
#   Mean: 2.77
#   Total rainfall before correction: 26396.46
#   Total rainfall after correction: 16348.73
#   Change in total rainfall: -38.06%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2002-11.tif
#
# Processing rainfall_2002-12.tif...
# Looking for bias file with date: 2002-12
# Rainfall data statistics:
#   Min: 2.53, Max: 11.76, Mean: 4.07
# Resampling bias data...
# Bias data statistics:
#   Min: 0.35, Max: 10.12, Mean: 2.48
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 3.10
#   Max: 17.09
#   Mean: 6.55
#   Total rainfall before correction: 24007.13
#   Total rainfall after correction: 38650.16
#   Change in total rainfall: 60.99%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2002-12.tif
#
# Processing rainfall_2003-01.tif...
# Looking for bias file with date: 2003-01
# Rainfall data statistics:
#   Min: 7.52, Max: 16.19, Mean: 12.05
# Resampling bias data...
# Bias data statistics:
#   Min: 1.58, Max: 1.58, Mean: 1.58
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 9.10
#   Max: 17.77
#   Mean: 13.63
#   Total rainfall before correction: 71106.11
#   Total rainfall after correction: 80433.69
#   Change in total rainfall: 13.12%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2003-01.tif
#
# Processing rainfall_2003-02.tif...
# Looking for bias file with date: 2003-02
# Rainfall data statistics:
#   Min: 11.04, Max: 25.40, Mean: 21.26
# Resampling bias data...
# Bias data statistics:
#   Min: 6.41, Max: 50.84, Mean: 11.00
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 19.30
#   Max: 74.03
#   Mean: 32.26
#   Total rainfall before correction: 125456.39
#   Total rainfall after correction: 190339.69
#   Change in total rainfall: 51.72%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2003-02.tif
#
# Processing rainfall_2003-03.tif...
# Looking for bias file with date: 2003-03
# Rainfall data statistics:
#   Min: 10.75, Max: 48.11, Mean: 15.17
# Resampling bias data...
# Bias data statistics:
#   Min: -5.45, Max: -3.74, Mean: -3.74
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 6.74
#   Max: 44.37
#   Mean: 11.43
#   Total rainfall before correction: 89483.23
#   Total rainfall after correction: 67424.75
#   Change in total rainfall: -24.65%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2003-03.tif
#
# Processing rainfall_2003-04.tif...
# Looking for bias file with date: 2003-04
# Rainfall data statistics:
#   Min: 11.81, Max: 78.25, Mean: 17.12
# Resampling bias data...
# Bias data statistics:
#   Min: -15.87, Max: -5.87, Mean: -10.16
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 514 pixels (8.71%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 64.96
#   Mean: 7.02
#   Total rainfall before correction: 100985.11
#   Total rainfall after correction: 41444.99
#   Change in total rainfall: -58.96%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2003-04.tif
#
# Processing rainfall_2003-05.tif...
# Looking for bias file with date: 2003-05
# Rainfall data statistics:
#   Min: 17.33, Max: 86.54, Mean: 28.46
# Resampling bias data...
# Bias data statistics:
#   Min: -22.05, Max: -7.71, Mean: -12.48
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 33 pixels (0.56%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 74.22
#   Mean: 15.98
#   Total rainfall before correction: 167903.42
#   Total rainfall after correction: 94299.66
#   Change in total rainfall: -43.84%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2003-05.tif
#
# Processing rainfall_2003-06.tif...
# Looking for bias file with date: 2003-06
# Rainfall data statistics:
#   Min: 28.88, Max: 84.67, Mean: 48.43
# Resampling bias data...
# Bias data statistics:
#   Min: -22.36, Max: 32.52, Mean: -7.19
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 13.56
#   Max: 92.06
#   Mean: 41.24
#   Total rainfall before correction: 285709.00
#   Total rainfall after correction: 243289.84
#   Change in total rainfall: -14.85%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2003-06.tif
#
# Processing rainfall_2003-07.tif...
# Looking for bias file with date: 2003-07
# Rainfall data statistics:
#   Min: 77.55, Max: 192.93, Mean: 133.11
# Resampling bias data...
# Bias data statistics:
#   Min: 16.03, Max: 441.16, Mean: 206.00
#   Warning: Average bias magnitude exceeds average rainfall. Check bias calculation.
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 137.79
#   Max: 612.75
#   Mean: 339.11
#   Total rainfall before correction: 785369.56
#   Total rainfall after correction: 2000753.00
#   Change in total rainfall: 154.75%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2003-07.tif
#
# Processing rainfall_2003-08.tif...
# Looking for bias file with date: 2003-08
# Rainfall data statistics:
#   Min: 77.02, Max: 199.86, Mean: 127.09
# Resampling bias data...
# Bias data statistics:
#   Min: 16.69, Max: 179.71, Mean: 88.44
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 101.68
#   Max: 357.18
#   Mean: 215.53
#   Total rainfall before correction: 749853.81
#   Total rainfall after correction: 1271637.75
#   Change in total rainfall: 69.58%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2003-08.tif
#
# Processing rainfall_2003-09.tif...
# Looking for bias file with date: 2003-09
# Rainfall data statistics:
#   Min: 72.36, Max: 191.85, Mean: 121.68
# Resampling bias data...
# Bias data statistics:
#   Min: -14.09, Max: 56.54, Mean: 0.88
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 72.83
#   Max: 194.48
#   Mean: 122.56
#   Total rainfall before correction: 717930.12
#   Total rainfall after correction: 723111.31
#   Change in total rainfall: 0.72%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2003-09.tif
#
# Processing rainfall_2003-10.tif...
# Looking for bias file with date: 2003-10
# Rainfall data statistics:
#   Min: 9.77, Max: 74.72, Mean: 15.50
# Resampling bias data...
# Bias data statistics:
#   Min: -15.83, Max: -6.69, Mean: -6.94
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 35 pixels (0.59%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 65.25
#   Mean: 8.56
#   Total rainfall before correction: 91422.59
#   Total rainfall after correction: 50513.50
#   Change in total rainfall: -44.75%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2003-10.tif
#
# Processing rainfall_2003-11.tif...
# Looking for bias file with date: 2003-11
# Rainfall data statistics:
#   Min: 1.64, Max: 66.69, Mean: 6.55
# Resampling bias data...
# Bias data statistics:
#   Min: -10.44, Max: -2.12, Mean: -2.20
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 1230 pixels (20.85%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 64.56
#   Mean: 4.45
#   Total rainfall before correction: 38637.84
#   Total rainfall after correction: 26265.37
#   Change in total rainfall: -32.02%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2003-11.tif
#
# Processing rainfall_2003-12.tif...
# Looking for bias file with date: 2003-12
# Rainfall data statistics:
#   Min: 2.36, Max: 14.05, Mean: 7.35
# Resampling bias data...
# Bias data statistics:
#   Min: 0.72, Max: 19.52, Mean: 6.41
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 3.86
#   Max: 31.35
#   Mean: 13.76
#   Total rainfall before correction: 43347.40
#   Total rainfall after correction: 81175.19
#   Change in total rainfall: 87.27%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2003-12.tif
#
# Processing rainfall_2004-01.tif...
# Looking for bias file with date: 2004-01
# Rainfall data statistics:
#   Min: 7.40, Max: 15.80, Mean: 11.23
# Resampling bias data...
# Bias data statistics:
#   Min: 0.07, Max: 13.00, Mean: 4.81
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 7.97
#   Max: 27.43
#   Mean: 16.04
#   Total rainfall before correction: 66264.31
#   Total rainfall after correction: 94663.25
#   Change in total rainfall: 42.86%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2004-01.tif
#
# Processing rainfall_2004-02.tif...
# Looking for bias file with date: 2004-02
# Rainfall data statistics:
#   Min: 9.63, Max: 22.54, Mean: 13.42
# Resampling bias data...
# Bias data statistics:
#   Min: -9.94, Max: -3.74, Mean: -5.24
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 2.38
#   Max: 16.81
#   Mean: 8.18
#   Total rainfall before correction: 79173.84
#   Total rainfall after correction: 48234.98
#   Change in total rainfall: -39.08%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2004-02.tif
#
# Processing rainfall_2004-03.tif...
# Looking for bias file with date: 2004-03
# Rainfall data statistics:
#   Min: 9.59, Max: 41.10, Mean: 12.09
# Resampling bias data...
# Bias data statistics:
#   Min: -10.05, Max: -3.67, Mean: -6.07
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 0.08
#   Max: 33.39
#   Mean: 6.02
#   Total rainfall before correction: 71337.20
#   Total rainfall after correction: 35542.72
#   Change in total rainfall: -50.18%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2004-03.tif
#
# Processing rainfall_2004-04.tif...
# Looking for bias file with date: 2004-04
# Rainfall data statistics:
#   Min: 11.82, Max: 79.67, Mean: 23.78
# Resampling bias data...
# Bias data statistics:
#   Min: -5.43, Max: 6.13, Mean: -1.14
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 6.86
#   Max: 78.47
#   Mean: 22.64
#   Total rainfall before correction: 140327.19
#   Total rainfall after correction: 133587.44
#   Change in total rainfall: -4.80%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2004-04.tif
#
# Processing rainfall_2004-05.tif...
# Looking for bias file with date: 2004-05
# Rainfall data statistics:
#   Min: 17.27, Max: 85.99, Mean: 22.92
# Resampling bias data...
# Bias data statistics:
#   Min: 2.72, Max: 29.89, Mean: 9.16
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 20.24
#   Max: 104.36
#   Mean: 32.08
#   Total rainfall before correction: 135204.98
#   Total rainfall after correction: 189248.50
#   Change in total rainfall: 39.97%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2004-05.tif
#
# Processing rainfall_2004-06.tif...
# Looking for bias file with date: 2004-06
# Rainfall data statistics:
#   Min: 28.78, Max: 87.37, Mean: 45.13
# Resampling bias data...
# Bias data statistics:
#   Min: -11.35, Max: 9.24, Mean: -3.79
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 18.25
#   Max: 83.55
#   Mean: 41.34
#   Total rainfall before correction: 266265.44
#   Total rainfall after correction: 243905.08
#   Change in total rainfall: -8.40%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2004-06.tif
#
# Processing rainfall_2004-07.tif...
# Looking for bias file with date: 2004-07
# Rainfall data statistics:
#   Min: 68.50, Max: 188.08, Mean: 104.86
# Resampling bias data...
# Bias data statistics:
#   Min: -49.88, Max: -15.01, Mean: -22.14
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 44.34
#   Max: 166.94
#   Mean: 82.73
#   Total rainfall before correction: 618701.75
#   Total rainfall after correction: 488090.06
#   Change in total rainfall: -21.11%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2004-07.tif
#
# Processing rainfall_2004-08.tif...
# Looking for bias file with date: 2004-08
# Rainfall data statistics:
#   Min: 85.26, Max: 205.32, Mean: 143.12
# Resampling bias data...
# Bias data statistics:
#   Min: 23.20, Max: 287.87, Mean: 123.33
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 122.26
#   Max: 461.86
#   Mean: 266.45
#   Total rainfall before correction: 844420.62
#   Total rainfall after correction: 1572052.12
#   Change in total rainfall: 86.17%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2004-08.tif
#
# Processing rainfall_2004-09.tif...
# Looking for bias file with date: 2004-09
# Rainfall data statistics:
#   Min: 57.01, Max: 166.56, Mean: 87.84
# Resampling bias data...
# Bias data statistics:
#   Min: -42.51, Max: -16.53, Mean: -23.61
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 20.70
#   Max: 139.28
#   Mean: 64.23
#   Total rainfall before correction: 518285.34
#   Total rainfall after correction: 378958.31
#   Change in total rainfall: -26.88%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2004-09.tif
#
# Processing rainfall_2004-10.tif...
# Looking for bias file with date: 2004-10
# Rainfall data statistics:
#   Min: 10.44, Max: 73.92, Mean: 29.68
# Resampling bias data...
# Bias data statistics:
#   Min: 17.81, Max: 17.81, Mean: 17.81
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 28.25
#   Max: 91.73
#   Mean: 47.49
#   Total rainfall before correction: 175089.72
#   Total rainfall after correction: 280180.41
#   Change in total rainfall: 60.02%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2004-10.tif
#
# Processing rainfall_2004-11.tif...
# Looking for bias file with date: 2004-11
# Rainfall data statistics:
#   Min: 1.64, Max: 35.21, Mean: 3.85
# Resampling bias data...
# Bias data statistics:
#   Min: -3.03, Max: -1.01, Mean: -1.77
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 764 pixels (12.95%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 33.89
#   Mean: 2.13
#   Total rainfall before correction: 22730.61
#   Total rainfall after correction: 12561.80
#   Change in total rainfall: -44.74%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2004-11.tif
#
# Processing rainfall_2004-12.tif...
# Looking for bias file with date: 2004-12
# Rainfall data statistics:
#   Min: 2.59, Max: 12.95, Mean: 4.99
# Resampling bias data...
# Bias data statistics:
#   Min: -2.26, Max: -1.94, Mean: -1.94
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 0.65
#   Max: 11.01
#   Mean: 3.04
#   Total rainfall before correction: 29412.15
#   Total rainfall after correction: 17940.36
#   Change in total rainfall: -39.00%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2004-12.tif
#
# Processing rainfall_2005-01.tif...
# Looking for bias file with date: 2005-01
# Rainfall data statistics:
#   Min: 6.65, Max: 15.53, Mean: 10.17
# Resampling bias data...
# Bias data statistics:
#   Min: -2.96, Max: -1.91, Mean: -1.91
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 4.74
#   Max: 13.62
#   Mean: 8.26
#   Total rainfall before correction: 60025.90
#   Total rainfall after correction: 48750.60
#   Change in total rainfall: -18.78%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2005-01.tif
#
# Processing rainfall_2005-02.tif...
# Looking for bias file with date: 2005-02
# Rainfall data statistics:
#   Min: 9.95, Max: 24.94, Mean: 19.43
# Resampling bias data...
# Bias data statistics:
#   Min: 3.48, Max: 27.27, Mean: 13.97
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 16.25
#   Max: 50.07
#   Mean: 33.40
#   Total rainfall before correction: 114647.26
#   Total rainfall after correction: 197081.78
#   Change in total rainfall: 71.90%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2005-02.tif
#
# Processing rainfall_2005-03.tif...
# Looking for bias file with date: 2005-03
# Rainfall data statistics:
#   Min: 10.06, Max: 48.22, Mean: 14.31
# Resampling bias data...
# Bias data statistics:
#   Min: -2.00, Max: 14.82, Mean: 2.83
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 10.79
#   Max: 55.53
#   Mean: 17.14
#   Total rainfall before correction: 84413.82
#   Total rainfall after correction: 101110.75
#   Change in total rainfall: 19.78%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2005-03.tif
#
# Processing rainfall_2005-04.tif...
# Looking for bias file with date: 2005-04
# Rainfall data statistics:
#   Min: 11.81, Max: 79.62, Mean: 20.20
# Resampling bias data...
# Bias data statistics:
#   Min: -18.68, Max: -6.35, Mean: -9.30
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 115 pixels (1.95%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 69.58
#   Mean: 10.91
#   Total rainfall before correction: 119150.56
#   Total rainfall after correction: 64379.85
#   Change in total rainfall: -45.97%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2005-04.tif
#
# Processing rainfall_2005-05.tif...
# Looking for bias file with date: 2005-05
# Rainfall data statistics:
#   Min: 16.66, Max: 72.41, Mean: 20.78
# Resampling bias data...
# Bias data statistics:
#   Min: -5.45, Max: -4.33, Mean: -4.53
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 11.81
#   Max: 67.87
#   Mean: 16.25
#   Total rainfall before correction: 122617.83
#   Total rainfall after correction: 95863.30
#   Change in total rainfall: -21.82%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2005-05.tif
#
# Processing rainfall_2005-06.tif...
# Looking for bias file with date: 2005-06
# Rainfall data statistics:
#   Min: 28.78, Max: 69.95, Mean: 41.33
# Resampling bias data...
# Bias data statistics:
#   Min: -14.08, Max: 24.67, Mean: 2.18
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 14.83
#   Max: 81.47
#   Mean: 43.51
#   Total rainfall before correction: 243846.23
#   Total rainfall after correction: 256704.50
#   Change in total rainfall: 5.27%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2005-06.tif
#
# Processing rainfall_2005-07.tif...
# Looking for bias file with date: 2005-07
# Rainfall data statistics:
#   Min: 81.98, Max: 191.89, Mean: 127.94
# Resampling bias data...
# Bias data statistics:
#   Min: 9.92, Max: 172.39, Mean: 60.05
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 103.17
#   Max: 335.50
#   Mean: 187.99
#   Total rainfall before correction: 754826.12
#   Total rainfall after correction: 1109121.25
#   Change in total rainfall: 46.94%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2005-07.tif
#
# Processing rainfall_2005-08.tif...
# Looking for bias file with date: 2005-08
# Rainfall data statistics:
#   Min: 61.81, Max: 164.45, Mean: 96.48
# Resampling bias data...
# Bias data statistics:
#   Min: -26.36, Max: 8.31, Mean: -10.76
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 43.71
#   Max: 164.63
#   Mean: 85.72
#   Total rainfall before correction: 569213.88
#   Total rainfall after correction: 505756.31
#   Change in total rainfall: -11.15%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2005-08.tif
#
# Processing rainfall_2005-09.tif...
# Looking for bias file with date: 2005-09
# Rainfall data statistics:
#   Min: 74.87, Max: 199.82, Mean: 127.33
# Resampling bias data...
# Bias data statistics:
#   Min: 11.72, Max: 152.44, Mean: 68.14
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 87.38
#   Max: 324.40
#   Mean: 195.47
#   Total rainfall before correction: 751258.06
#   Total rainfall after correction: 1153260.12
#   Change in total rainfall: 53.51%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2005-09.tif
#
# Processing rainfall_2005-10.tif...
# Looking for bias file with date: 2005-10
# Rainfall data statistics:
#   Min: 9.77, Max: 75.17, Mean: 15.04
# Resampling bias data...
# Bias data statistics:
#   Min: -15.21, Max: -5.33, Mean: -8.36
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 402 pixels (6.81%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 64.27
#   Mean: 6.78
#   Total rainfall before correction: 88758.55
#   Total rainfall after correction: 39976.89
#   Change in total rainfall: -54.96%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2005-10.tif
#
# Processing rainfall_2005-11.tif...
# Looking for bias file with date: 2005-11
# Rainfall data statistics:
#   Min: 1.64, Max: 31.04, Mean: 3.07
# Resampling bias data...
# Bias data statistics:
#   Min: -3.13, Max: -0.99, Mean: -1.53
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 455 pixels (7.71%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 29.86
#   Mean: 1.55
#   Total rainfall before correction: 18087.09
#   Total rainfall after correction: 9150.68
#   Change in total rainfall: -49.41%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2005-11.tif
#
# Processing rainfall_2005-12.tif...
# Looking for bias file with date: 2005-12
# Rainfall data statistics:
# ...
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 2.71
#   Max: 36.89
#   Mean: 9.89
#   Total rainfall before correction: 81453.62
#   Total rainfall after correction: 58369.05
#   Change in total rainfall: -28.34%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2021-02.tif
#
# Processing rainfall_2021-03.tif...
# Looking for bias file with date: 2021-03
# Rainfall data statistics:
#   Min: 9.59, Max: 45.55, Mean: 12.65
# Resampling bias data...
# Bias data statistics:
#   Min: -6.80, Max: -0.45, Mean: -3.57
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 3.42
#   Max: 41.04
#   Mean: 9.08
#   Total rainfall before correction: 74618.67
#   Total rainfall after correction: 53576.59
#   Change in total rainfall: -28.20%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2021-03.tif
#
# Processing rainfall_2021-04.tif...
# Looking for bias file with date: 2021-04
# Rainfall data statistics:
#   Min: 11.81, Max: 72.45, Mean: 15.15
# Resampling bias data...
# Bias data statistics:
#   Min: -14.61, Max: -5.25, Mean: -8.14
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 31 pixels (0.53%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 63.02
#   Mean: 7.01
#   Total rainfall before correction: 89378.83
#   Total rainfall after correction: 41377.72
#   Change in total rainfall: -53.71%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2021-04.tif
#
# Processing rainfall_2021-05.tif...
# Looking for bias file with date: 2021-05
# Rainfall data statistics:
#   Min: 17.68, Max: 91.73, Mean: 39.11
# Resampling bias data...
# Bias data statistics:
#   Min: 20.28, Max: 35.50, Mean: 20.30
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 37.95
#   Max: 112.01
#   Mean: 59.41
#   Total rainfall before correction: 230744.12
#   Total rainfall after correction: 350493.25
#   Change in total rainfall: 51.90%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2021-05.tif
#
# Processing rainfall_2021-06.tif...
# Looking for bias file with date: 2021-06
# Rainfall data statistics:
#   Min: 29.28, Max: 90.96, Mean: 57.65
# Resampling bias data...
# Bias data statistics:
#   Min: -15.63, Max: -3.22, Mean: -6.66
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 22.81
#   Max: 85.75
#   Mean: 50.99
#   Total rainfall before correction: 340135.81
#   Total rainfall after correction: 300813.25
#   Change in total rainfall: -11.56%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2021-06.tif
#
# Processing rainfall_2021-07.tif...
# Looking for bias file with date: 2021-07
# Rainfall data statistics:
#   Min: 84.49, Max: 199.96, Mean: 120.91
# Resampling bias data...
# Bias data statistics:
#   Min: 1.87, Max: 352.33, Mean: 169.57
#   Warning: Average bias magnitude exceeds average rainfall. Check bias calculation.
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 94.87
#   Max: 516.36
#   Mean: 290.48
#   Total rainfall before correction: 713368.56
#   Total rainfall after correction: 1713811.75
#   Change in total rainfall: 140.24%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2021-07.tif
#
# Processing rainfall_2021-08.tif...
# Looking for bias file with date: 2021-08
# Rainfall data statistics:
#   Min: 73.43, Max: 196.38, Mean: 127.24
# Resampling bias data...
# Bias data statistics:
#   Min: 13.41, Max: 103.51, Mean: 14.28
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 86.84
#   Max: 264.82
#   Mean: 141.52
#   Total rainfall before correction: 750696.38
#   Total rainfall after correction: 834949.25
#   Change in total rainfall: 11.22%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2021-08.tif
#
# Processing rainfall_2021-09.tif...
# Looking for bias file with date: 2021-09
# Rainfall data statistics:
#   Min: 73.90, Max: 204.19, Mean: 135.07
# Resampling bias data...
# Bias data statistics:
#   Min: 41.65, Max: 230.25, Mean: 51.11
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 115.61
#   Max: 403.91
#   Mean: 186.18
#   Total rainfall before correction: 796908.88
#   Total rainfall after correction: 1098485.38
#   Change in total rainfall: 37.84%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2021-09.tif
#
# Processing rainfall_2021-10.tif...
# Looking for bias file with date: 2021-10
# Rainfall data statistics:
#   Min: 9.85, Max: 61.44, Mean: 20.83
# Resampling bias data...
# Bias data statistics:
#   Min: 7.28, Max: 76.70, Mean: 21.79
#   Warning: Average bias magnitude exceeds average rainfall. Check bias calculation.
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 18.01
#   Max: 109.57
#   Mean: 42.62
#   Total rainfall before correction: 122907.78
#   Total rainfall after correction: 251453.00
#   Change in total rainfall: 104.59%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2021-10.tif
#
# Processing rainfall_2021-11.tif...
# Looking for bias file with date: 2021-11
# Rainfall data statistics:
#   Min: 1.65, Max: 20.74, Mean: 3.38
# Resampling bias data...
# Bias data statistics:
#   Min: -3.10, Max: -1.07, Mean: -1.79
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 248 pixels (4.20%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 18.54
#   Mean: 1.60
#   Total rainfall before correction: 19958.97
#   Total rainfall after correction: 9441.21
#   Change in total rainfall: -52.70%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2021-11.tif
#
# Processing rainfall_2021-12.tif...
# Looking for bias file with date: 2021-12
# Rainfall data statistics:
#   Min: 2.71, Max: 13.52, Mean: 6.13
# Resampling bias data...
# Bias data statistics:
#   Min: -1.75, Max: 2.55, Mean: -1.05
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 1.63
#   Max: 12.45
#   Mean: 5.08
#   Total rainfall before correction: 36145.90
#   Total rainfall after correction: 29950.07
#   Change in total rainfall: -17.14%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2021-12.tif
#
# Processing rainfall_2022-01.tif...
# Looking for bias file with date: 2022-01
# Rainfall data statistics:
#   Min: 7.37, Max: 16.50, Mean: 12.82
# Resampling bias data...
# Bias data statistics:
#   Min: 20.86, Max: 20.86, Mean: 20.86
#   Warning: Average bias magnitude exceeds average rainfall. Check bias calculation.
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 28.24
#   Max: 37.36
#   Mean: 33.69
#   Total rainfall before correction: 75659.45
#   Total rainfall after correction: 198754.06
#   Change in total rainfall: 162.70%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2022-01.tif
#
# Processing rainfall_2022-02.tif...
# Looking for bias file with date: 2022-02
# Rainfall data statistics:
#   Min: 9.99, Max: 24.90, Mean: 18.00
# Resampling bias data...
# Bias data statistics:
#   Min: 0.70, Max: 9.31, Mean: 1.31
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 10.73
#   Max: 30.96
#   Mean: 19.30
#   Total rainfall before correction: 106177.95
#   Total rainfall after correction: 113892.59
#   Change in total rainfall: 7.27%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2022-02.tif
#
# Processing rainfall_2022-03.tif...
# Looking for bias file with date: 2022-03
# Rainfall data statistics:
#   Min: 9.59, Max: 38.34, Mean: 11.84
# Resampling bias data...
# Bias data statistics:
#   Min: -9.83, Max: -3.50, Mean: -6.18
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 0.24
#   Max: 30.59
#   Mean: 5.66
#   Total rainfall before correction: 69867.25
#   Total rainfall after correction: 33387.07
#   Change in total rainfall: -52.21%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2022-03.tif
#
# Processing rainfall_2022-04.tif...
# Looking for bias file with date: 2022-04
# Rainfall data statistics:
#   Min: 11.81, Max: 69.31, Mean: 14.80
# Resampling bias data...
# Bias data statistics:
#   Min: -15.92, Max: -6.25, Mean: -8.34
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 157 pixels (2.66%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 60.40
#   Mean: 6.48
#   Total rainfall before correction: 87314.06
#   Total rainfall after correction: 38258.69
#   Change in total rainfall: -56.18%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2022-04.tif
#
# Processing rainfall_2022-05.tif...
# Looking for bias file with date: 2022-05
# Rainfall data statistics:
#   Min: 17.33, Max: 92.39, Mean: 32.77
# Resampling bias data...
# Bias data statistics:
#   Min: 0.75, Max: 37.98, Mean: 14.85
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 19.73
#   Max: 118.74
#   Mean: 47.62
#   Total rainfall before correction: 193350.48
#   Total rainfall after correction: 280957.25
#   Change in total rainfall: 45.31%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2022-05.tif
#
# Processing rainfall_2022-06.tif...
# Looking for bias file with date: 2022-06
# Rainfall data statistics:
#   Min: 29.02, Max: 91.16, Mean: 50.52
# Resampling bias data...
# Bias data statistics:
#   Min: -15.05, Max: 16.63, Mean: -2.55
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 26.42
#   Max: 85.15
#   Mean: 47.97
#   Total rainfall before correction: 298075.50
#   Total rainfall after correction: 283049.62
#   Change in total rainfall: -5.04%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2022-06.tif
#
# Processing rainfall_2022-07.tif...
# Looking for bias file with date: 2022-07
# Rainfall data statistics:
#   Min: 80.36, Max: 203.36, Mean: 138.96
# Resampling bias data...
# Bias data statistics:
#   Min: 1.73, Max: 153.52, Mean: 61.33
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 107.26
#   Max: 350.00
#   Mean: 200.29
#   Total rainfall before correction: 819846.88
#   Total rainfall after correction: 1181719.88
#   Change in total rainfall: 44.14%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2022-07.tif
#
# Processing rainfall_2022-08.tif...
# Looking for bias file with date: 2022-08
# Rainfall data statistics:
#   Min: 66.05, Max: 181.35, Mean: 108.14
# Resampling bias data...
# Bias data statistics:
#   Min: -34.47, Max: 7.09, Mean: -10.25
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 49.72
#   Max: 182.02
#   Mean: 97.88
#   Total rainfall before correction: 638019.69
#   Total rainfall after correction: 577515.62
#   Change in total rainfall: -9.48%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2022-08.tif
#
# Processing rainfall_2022-09.tif...
# Looking for bias file with date: 2022-09
# Rainfall data statistics:
#   Min: 73.08, Max: 208.04, Mean: 122.41
# Resampling bias data...
# Bias data statistics:
#   Min: 5.91, Max: 135.59, Mean: 60.13
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 88.03
#   Max: 308.21
#   Mean: 182.54
#   Total rainfall before correction: 722206.06
#   Total rainfall after correction: 1076963.25
#   Change in total rainfall: 49.12%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2022-09.tif
#
# Processing rainfall_2022-10.tif...
# Looking for bias file with date: 2022-10
# Rainfall data statistics:
#   Min: 9.87, Max: 74.65, Mean: 29.16
# Resampling bias data...
# Bias data statistics:
#   Min: 18.65, Max: 18.65, Mean: 18.65
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 28.53
#   Max: 93.30
#   Mean: 47.82
#   Total rainfall before correction: 172050.89
#   Total rainfall after correction: 282113.44
#   Change in total rainfall: 63.97%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2022-10.tif
#
# Processing rainfall_2022-11.tif...
# Looking for bias file with date: 2022-11
# Rainfall data statistics:
#   Min: 1.64, Max: 20.43, Mean: 3.02
# Resampling bias data...
# Bias data statistics:
#   Min: -2.82, Max: -1.28, Mean: -1.33
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 51 pixels (0.86%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 19.15
#   Mean: 1.69
#   Total rainfall before correction: 17833.71
#   Total rainfall after correction: 9971.13
#   Change in total rainfall: -44.09%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2022-11.tif
#
# Processing rainfall_2022-12.tif...
# Looking for bias file with date: 2022-12
# Rainfall data statistics:
#   Min: 2.59, Max: 10.98, Mean: 4.17
# Resampling bias data...
# Bias data statistics:
#   Min: -2.53, Max: -1.29, Mean: -1.79
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 0.34
#   Max: 9.34
#   Mean: 2.38
#   Total rainfall before correction: 24593.15
#   Total rainfall after correction: 14047.94
#   Change in total rainfall: -42.88%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.01/corrected_rainfall_2022-12.tif
#
# Processing rainfall_2023-01.tif...
# Looking for bias file with date: 2023-01
# Skipping 2023-01, no matching bias file found.
#
# Processing rainfall_2023-02.tif...
# Looking for bias file with date: 2023-02
# Skipping 2023-02, no matching bias file found.
#
# Processing Summary:
# Total files: 277
# Successfully processed: 275
# Skipped: 2
# Errors: 0
# Correction completed!

# %%
import os
import rasterio
import numpy as np
import glob
from rasterio.warp import reproject, Resampling
def parse_rainfall_filename(filename):
    try:
        base_name = os.path.basename(filename)
        name_parts = base_name.split('.')
        name_without_ext = name_parts[0]
        
        # Handle rainfall_YYYY-MM format directly
        if name_without_ext.startswith("rainfall_") and "-" in name_without_ext:
            date_part = name_without_ext.split("rainfall_")[1]
            year, month = date_part.split("-")
            if year.isdigit() and month.isdigit() and len(year) == 4:
                month = month.zfill(2)  # Ensure month has 2 digits
                underscore_date = f"{year}_{month}"
                hyphen_date = f"{year}-{month}"
                return underscore_date, hyphen_date
        
        # Existing logic as fallback
        parts = name_without_ext.split('_')
        
        if len(parts) >= 3 and parts[-2].isdigit() and parts[-1].isdigit():
            year = parts[-2]
            month = parts[-1].zfill(2)  # Ensure month has 2 digits
            underscore_date = f"{year}_{month}"
            hyphen_date = f"{year}-{month}"
            return underscore_date, hyphen_date
        
        for i in range(len(parts)):
            if parts[i].isdigit() and len(parts[i]) == 4:  # Potential year
                year = parts[i]
                if i+1 < len(parts) and parts[i+1].isdigit():  # Next part is potential month
                    month = parts[i+1].zfill(2)
                    underscore_date = f"{year}_{month}"
                    hyphen_date = f"{year}-{month}"
                    return underscore_date, hyphen_date
        
        raise ValueError(f"Date pattern not found in filename: {filename}")
    except Exception as e:
        raise ValueError(f"Unable to parse date from filename: {filename}") from e

def resample_bias_to_rainfall(bias_dataset, rainfall_dataset):
    dst_shape = rainfall_dataset.shape
    dst_transform = rainfall_dataset.transform
    dst_crs = rainfall_dataset.crs
    
    resampled_data = np.zeros(dst_shape, dtype='float32')
    
    reproject(
        source=rasterio.band(bias_dataset, 1),
        destination=resampled_data,
        src_transform=bias_dataset.transform,
        src_crs=bias_dataset.crs,
        dst_transform=dst_transform,
        dst_crs=dst_crs,
        resampling=Resampling.bilinear
    )
    
    return resampled_data

def validate_and_correct_data(rainfall_data, bias_data, rainfall_nodata):
    rainfall_mask = (rainfall_data == rainfall_nodata) if rainfall_nodata is not None else np.zeros_like(rainfall_data, dtype=bool)
    bias_mask = np.isnan(bias_data)
    
    valid_mask = ~(rainfall_mask | bias_mask)
    
    corrected_data = np.full_like(rainfall_data, rainfall_nodata if rainfall_nodata is not None else -999)
    
    corrected_data[valid_mask] = rainfall_data[valid_mask] + bias_data[valid_mask]
    
    negative_rainfall = (corrected_data < 0) & valid_mask
    if np.any(negative_rainfall):
        negative_count = np.sum(negative_rainfall)
        total_valid = np.sum(valid_mask)
        print(f"Warning: {negative_count} pixels ({negative_count/total_valid*100:.2f}%) would have negative rainfall after bias correction")
        print("Setting these values to zero")
        corrected_data[negative_rainfall] = 0
    
    max_reasonable_rainfall = 2000  # mm/month (adjust based on your data's units and region)
    excessive_rainfall = (corrected_data > max_reasonable_rainfall) & valid_mask
    
    if np.any(excessive_rainfall):
        excessive_count = np.sum(excessive_rainfall)
        print(f"Warning: {excessive_count} pixels have extremely high rainfall values after correction")
        print(f"Range of these values: {np.min(corrected_data[excessive_rainfall]):.2f} to {np.max(corrected_data[excessive_rainfall]):.2f}")
        corrected_data[excessive_rainfall] = max_reasonable_rainfall
        print(f"Capped extremely high values at {max_reasonable_rainfall}")
    
    return corrected_data

def apply_bias_correction(rainfall_dir, bias_dir, output_dir):
    os.makedirs(output_dir, exist_ok=True)
    
    rainfall_files = glob.glob(os.path.join(rainfall_dir, "*.tif"))
    print(f"Found {len(rainfall_files)} rainfall files to process")
    
    processed = 0
    errors = 0
    skipped = 0
    
    for rainfall_file in rainfall_files:
        try:
            rainfall_filename = os.path.basename(rainfall_file)
            print(f"\nProcessing {rainfall_filename}...")
            
            date_str, date_str_hyphen = parse_rainfall_filename(rainfall_filename)
            year, month = date_str.split('_')
            print(f"Looking for bias file with date: {date_str_hyphen}")
            
            bias_file = os.path.join(bias_dir, f"bias_{year}_{month}.tif")
            if not os.path.exists(bias_file):
                print(f"Skipping {date_str_hyphen}, no matching bias file found.")
                skipped += 1
                continue
            
            with rasterio.open(rainfall_file) as rainfall_dataset, rasterio.open(bias_file) as bias_dataset:
                rainfall_data = rainfall_dataset.read(1)
                
                print(f"Rainfall data statistics:")
                valid_rainfall = rainfall_data[rainfall_data != (rainfall_dataset.nodata if rainfall_dataset.nodata is not None else -999)]
                if valid_rainfall.size > 0:
                    print(f"  Min: {np.min(valid_rainfall):.2f}, Max: {np.max(valid_rainfall):.2f}, Mean: {np.mean(valid_rainfall):.2f}")
                
                print("Resampling bias data...")
                bias_data = resample_bias_to_rainfall(bias_dataset, rainfall_dataset)
                
                print(f"Bias data statistics:")
                valid_bias = bias_data[~np.isnan(bias_data)]
                if valid_bias.size > 0:
                    print(f"  Min: {np.min(valid_bias):.2f}, Max: {np.max(valid_bias):.2f}, Mean: {np.mean(valid_bias):.2f}")
                    if np.mean(valid_bias) < 0 and np.mean(valid_rainfall) > 0:
                        print("  Note: Bias is predominantly negative while rainfall is positive")
                    if abs(np.mean(valid_bias)) > np.mean(valid_rainfall):
                        print("  Warning: Average bias magnitude exceeds average rainfall. Check bias calculation.")
                
                print("Applying bias correction with validation...")
                corrected_rainfall = validate_and_correct_data(
                    rainfall_data, 
                    bias_data, 
                    rainfall_dataset.nodata
                )
                
                valid_mask = corrected_rainfall != (rainfall_dataset.nodata if rainfall_dataset.nodata is not None else -999)
                if np.any(valid_mask):
                    print(f"Valid corrected data statistics:")
                    print(f"  Min: {np.min(corrected_rainfall[valid_mask]):.2f}")
                    print(f"  Max: {np.max(corrected_rainfall[valid_mask]):.2f}")
                    print(f"  Mean: {np.mean(corrected_rainfall[valid_mask]):.2f}")
                    
                    if valid_rainfall.size > 0:
                        total_rainfall_before = np.sum(valid_rainfall)
                        total_rainfall_after = np.sum(corrected_rainfall[valid_mask])
                        change_percent = ((total_rainfall_after - total_rainfall_before) / total_rainfall_before) * 100
                        
                        print(f"  Total rainfall before correction: {total_rainfall_before:.2f}")
                        print(f"  Total rainfall after correction: {total_rainfall_after:.2f}")
                        print(f"  Change in total rainfall: {change_percent:.2f}%")
                        
                        if abs(change_percent) > 50:
                            print("  WARNING: Very large change in total rainfall after bias correction!")
                output_profile = rainfall_dataset.profile.copy()
                output_profile.update({
                    'compress': 'lzw',
                    'nodata': rainfall_dataset.nodata if rainfall_dataset.nodata is not None else -999,
                    'dtype': 'float32'
                })
                
                output_file = os.path.join(output_dir, f"corrected_{rainfall_filename}")
                with rasterio.open(output_file, 'w', **output_profile) as dst:
                    dst.write(corrected_rainfall.astype('float32'), 1)
                
                processed += 1
                print(f"Successfully processed: {output_file}")
                
        except Exception as e:
            print(f"Error processing {os.path.basename(rainfall_file)}: {str(e)}")
            errors += 1
            import traceback
            print("Detailed error:")
            print(traceback.format_exc())
    
    print(f"\nProcessing Summary:")
    print(f"Total files: {len(rainfall_files)}")
    print(f"Successfully processed: {processed}")
    print(f"Skipped: {skipped}")
    print(f"Errors: {errors}")

def main():
    rainfall_dir = r"/home/stormej/dev/rainscale/data/ml/prediction/prediction_0.1"
    bias_dir = r"/home/stormej/dev/rainscale/data/bias/bias_kriging_0.1"
    output_dir = r"/home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1"
    
    print("Starting rainfall bias correction...")
    apply_bias_correction(rainfall_dir, bias_dir, output_dir)
    print("Correction completed!")

main()
# Out:
# Starting rainfall bias correction...
# Found 277 rainfall files to process
#
# Processing rainfall_2000-02.tif...
# Looking for bias file with date: 2000-02
# Rainfall data statistics:
#   Min: 10.66, Max: 20.04, Mean: 14.22
# Resampling bias data...
# Bias data statistics:
#   Min: 6.48, Max: 6.48, Mean: 6.48
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 17.13
#   Max: 26.51
#   Mean: 20.69
#   Total rainfall before correction: 710.89
#   Total rainfall after correction: 1034.64
#   Change in total rainfall: 45.54%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2000-02.tif
#
# Processing rainfall_2000-03.tif...
# Looking for bias file with date: 2000-03
# Rainfall data statistics:
#   Min: 9.89, Max: 19.66, Mean: 13.67
# Resampling bias data...
# Bias data statistics:
#   Min: -8.31, Max: -4.20, Mean: -4.94
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 5.42
#   Max: 13.11
#   Mean: 8.72
#   Total rainfall before correction: 683.36
#   Total rainfall after correction: 436.14
#   Change in total rainfall: -36.18%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2000-03.tif
#
# Processing rainfall_2000-04.tif...
# Looking for bias file with date: 2000-04
# Rainfall data statistics:
#   Min: 11.81, Max: 21.96, Mean: 14.30
# Resampling bias data...
# Bias data statistics:
#   Min: -12.42, Max: -5.09, Mean: -8.46
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 0.20
#   Max: 16.71
#   Mean: 5.84
#   Total rainfall before correction: 714.81
#   Total rainfall after correction: 291.98
#   Change in total rainfall: -59.15%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2000-04.tif
#
# Processing rainfall_2000-05.tif...
# Looking for bias file with date: 2000-05
# Rainfall data statistics:
#   Min: 18.03, Max: 51.15, Mean: 27.49
# Resampling bias data...
# Bias data statistics:
#   Min: -15.23, Max: -2.48, Mean: -7.33
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 7.18
#   Max: 42.27
#   Mean: 20.16
#   Total rainfall before correction: 1374.65
#   Total rainfall after correction: 1008.16
#   Change in total rainfall: -26.66%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2000-05.tif
#
# Processing rainfall_2000-06.tif...
# Looking for bias file with date: 2000-06
# Rainfall data statistics:
#   Min: 42.33, Max: 84.83, Mean: 75.16
# Resampling bias data...
# Bias data statistics:
#   Min: -6.04, Max: 21.19, Mean: 1.72
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 39.29
#   Max: 103.46
#   Mean: 76.88
#   Total rainfall before correction: 3758.04
#   Total rainfall after correction: 3843.94
#   Change in total rainfall: 2.29%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2000-06.tif
#
# Processing rainfall_2000-07.tif...
# Looking for bias file with date: 2000-07
# Rainfall data statistics:
#   Min: 98.39, Max: 183.46, Mean: 140.00
# Resampling bias data...
# Bias data statistics:
#   Min: 2.28, Max: 2.28, Mean: 2.28
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 100.67
#   Max: 185.73
#   Mean: 142.28
#   Total rainfall before correction: 6999.92
#   Total rainfall after correction: 7113.78
#   Change in total rainfall: 1.63%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2000-07.tif
#
# Processing rainfall_2000-08.tif...
# Looking for bias file with date: 2000-08
# Rainfall data statistics:
#   Min: 68.08, Max: 162.82, Mean: 112.54
# Resampling bias data...
# Bias data statistics:
#   Min: 10.14, Max: 167.22, Mean: 70.48
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 94.33
#   Max: 330.04
#   Mean: 183.02
#   Total rainfall before correction: 5626.92
#   Total rainfall after correction: 9151.10
#   Change in total rainfall: 62.63%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2000-08.tif
#
# Processing rainfall_2000-09.tif...
# Looking for bias file with date: 2000-09
# Rainfall data statistics:
#   Min: 59.26, Max: 129.54, Mean: 84.55
# Resampling bias data...
# Bias data statistics:
#   Min: -22.20, Max: -22.20, Mean: -22.20
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 37.06
#   Max: 107.34
#   Mean: 62.35
#   Total rainfall before correction: 4227.57
#   Total rainfall after correction: 3117.74
#   Change in total rainfall: -26.25%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2000-09.tif
#
# Processing rainfall_2000-10.tif...
# Looking for bias file with date: 2000-10
# Rainfall data statistics:
#   Min: 10.16, Max: 38.87, Mean: 14.75
# Resampling bias data...
# Bias data statistics:
#   Min: -8.83, Max: -7.09, Mean: -7.22
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 3.04
#   Max: 31.78
#   Mean: 7.53
#   Total rainfall before correction: 737.61
#   Total rainfall after correction: 376.61
#   Change in total rainfall: -48.94%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2000-10.tif
#
# Processing rainfall_2000-11.tif...
# Looking for bias file with date: 2000-11
# Rainfall data statistics:
#   Min: 1.73, Max: 43.29, Mean: 10.96
# Resampling bias data...
# Bias data statistics:
#   Min: -12.13, Max: -1.46, Mean: -4.87
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 7 pixels (14.00%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 36.31
#   Mean: 6.20
#   Total rainfall before correction: 548.23
#   Total rainfall after correction: 309.82
#   Change in total rainfall: -43.49%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2000-11.tif
#
# Processing rainfall_2000-12.tif...
# Looking for bias file with date: 2000-12
# Rainfall data statistics:
#   Min: 2.25, Max: 7.44, Mean: 3.24
# Resampling bias data...
# Bias data statistics:
#   Min: -3.37, Max: -1.18, Mean: -1.94
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 2 pixels (4.00%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 4.98
#   Mean: 1.31
#   Total rainfall before correction: 162.21
#   Total rainfall after correction: 65.39
#   Change in total rainfall: -59.69%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2000-12.tif
#
# Processing rainfall_2001-01.tif...
# Looking for bias file with date: 2001-01
# Rainfall data statistics:
#   Min: 6.54, Max: 12.76, Mean: 8.41
# Resampling bias data...
# Bias data statistics:
#   Min: -1.11, Max: 8.22, Mean: 3.71
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 6.15
#   Max: 20.39
#   Mean: 12.12
#   Total rainfall before correction: 420.39
#   Total rainfall after correction: 605.85
#   Change in total rainfall: 44.12%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2001-01.tif
#
# Processing rainfall_2001-02.tif...
# Looking for bias file with date: 2001-02
# Rainfall data statistics:
#   Min: 10.04, Max: 20.12, Mean: 13.10
# Resampling bias data...
# Bias data statistics:
#   Min: -3.70, Max: -3.17, Mean: -3.32
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 6.57
#   Max: 16.80
#   Mean: 9.79
#   Total rainfall before correction: 655.22
#   Total rainfall after correction: 489.40
#   Change in total rainfall: -25.31%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2001-02.tif
#
# Processing rainfall_2001-03.tif...
# Looking for bias file with date: 2001-03
# Rainfall data statistics:
#   Min: 10.17, Max: 26.09, Mean: 13.99
# Resampling bias data...
# Bias data statistics:
#   Min: -5.98, Max: -2.42, Mean: -4.31
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 6.27
#   Max: 21.44
#   Mean: 9.68
#   Total rainfall before correction: 699.75
#   Total rainfall after correction: 484.15
#   Change in total rainfall: -30.81%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2001-03.tif
#
# Processing rainfall_2001-04.tif...
# Looking for bias file with date: 2001-04
# Rainfall data statistics:
#   Min: 11.81, Max: 30.60, Mean: 16.96
# Resampling bias data...
# Bias data statistics:
#   Min: -4.91, Max: 1.42, Mean: -1.84
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 7.54
#   Max: 28.11
#   Mean: 15.12
#   Total rainfall before correction: 848.23
#   Total rainfall after correction: 756.06
#   Change in total rainfall: -10.87%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2001-04.tif
#
# Processing rainfall_2001-05.tif...
# Looking for bias file with date: 2001-05
# Rainfall data statistics:
#   Min: 27.47, Max: 76.76, Mean: 52.64
# Resampling bias data...
# Bias data statistics:
#   Min: -12.84, Max: 33.15, Mean: 12.14
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 14.88
#   Max: 109.32
#   Mean: 64.78
#   Total rainfall before correction: 2632.08
#   Total rainfall after correction: 3239.12
#   Change in total rainfall: 23.06%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2001-05.tif
#
# Processing rainfall_2001-06.tif...
# Looking for bias file with date: 2001-06
# Rainfall data statistics:
#   Min: 35.08, Max: 81.48, Mean: 66.19
# Resampling bias data...
# Bias data statistics:
#   Min: 9.15, Max: 64.29, Mean: 24.56
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 51.62
#   Max: 134.77
#   Mean: 90.76
#   Total rainfall before correction: 3309.60
#   Total rainfall after correction: 4537.84
#   Change in total rainfall: 37.11%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2001-06.tif
#
# Processing rainfall_2001-07.tif...
# Looking for bias file with date: 2001-07
# Rainfall data statistics:
#   Min: 101.30, Max: 198.27, Mean: 143.67
# Resampling bias data...
# Bias data statistics:
#   Min: -21.06, Max: 45.98, Mean: -0.31
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 90.44
#   Max: 202.80
#   Mean: 143.36
#   Total rainfall before correction: 7183.63
#   Total rainfall after correction: 7168.10
#   Change in total rainfall: -0.22%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2001-07.tif
#
# Processing rainfall_2001-08.tif...
# Looking for bias file with date: 2001-08
# Rainfall data statistics:
#   Min: 67.44, Max: 160.41, Mean: 99.11
# Resampling bias data...
# Bias data statistics:
#   Min: 4.98, Max: 4.98, Mean: 4.98
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 72.42
#   Max: 165.39
#   Mean: 104.09
#   Total rainfall before correction: 4955.51
#   Total rainfall after correction: 5204.33
#   Change in total rainfall: 5.02%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2001-08.tif
#
# Processing rainfall_2001-09.tif...
# Looking for bias file with date: 2001-09
# Rainfall data statistics:
#   Min: 57.92, Max: 103.26, Mean: 73.60
# Resampling bias data...
# Bias data statistics:
#   Min: -36.30, Max: -16.61, Mean: -25.10
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 25.51
#   Max: 79.06
#   Mean: 48.50
#   Total rainfall before correction: 3679.85
#   Total rainfall after correction: 2424.92
#   Change in total rainfall: -34.10%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2001-09.tif
#
# Processing rainfall_2001-10.tif...
# Looking for bias file with date: 2001-10
# Rainfall data statistics:
#   Min: 10.59, Max: 56.29, Mean: 21.54
# Resampling bias data...
# Bias data statistics:
#   Min: -17.52, Max: 1.48, Mean: -6.73
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 4 pixels (8.00%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 44.65
#   Mean: 14.93
#   Total rainfall before correction: 1076.85
#   Total rainfall after correction: 746.69
#   Change in total rainfall: -30.66%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2001-10.tif
#
# Processing rainfall_2001-11.tif...
# Looking for bias file with date: 2001-11
# Rainfall data statistics:
#   Min: 1.73, Max: 16.80, Mean: 3.50
# Resampling bias data...
# Bias data statistics:
#   Min: -3.27, Max: -1.32, Mean: -1.68
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 6 pixels (12.00%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 15.35
#   Mean: 1.85
#   Total rainfall before correction: 174.82
#   Total rainfall after correction: 92.74
#   Change in total rainfall: -46.95%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2001-11.tif
#
# Processing rainfall_2001-12.tif...
# Looking for bias file with date: 2001-12
# Rainfall data statistics:
#   Min: 2.70, Max: 9.02, Mean: 4.18
# Resampling bias data...
# Bias data statistics:
#   Min: -2.71, Max: -1.96, Mean: -2.03
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 0.24
#   Max: 6.80
#   Mean: 2.15
#   Total rainfall before correction: 209.11
#   Total rainfall after correction: 107.61
#   Change in total rainfall: -48.54%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2001-12.tif
#
# Processing rainfall_2002-01.tif...
# Looking for bias file with date: 2002-01
# Rainfall data statistics:
#   Min: 7.38, Max: 15.04, Mean: 10.16
# Resampling bias data...
# Bias data statistics:
#   Min: 1.64, Max: 2.27, Mean: 1.67
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 9.02
#   Max: 16.68
#   Mean: 11.83
#   Total rainfall before correction: 508.23
#   Total rainfall after correction: 591.64
#   Change in total rainfall: 16.41%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2002-01.tif
#
# Processing rainfall_2002-02.tif...
# Looking for bias file with date: 2002-02
# Rainfall data statistics:
#   Min: 12.05, Max: 23.65, Mean: 18.32
# Resampling bias data...
# Bias data statistics:
#   Min: -1.25, Max: 6.86, Mean: 0.96
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 11.71
#   Max: 27.11
#   Mean: 19.29
#   Total rainfall before correction: 916.18
#   Total rainfall after correction: 964.27
#   Change in total rainfall: 5.25%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2002-02.tif
#
# Processing rainfall_2002-03.tif...
# Looking for bias file with date: 2002-03
# Rainfall data statistics:
#   Min: 9.74, Max: 17.48, Mean: 12.73
# Resampling bias data...
# Bias data statistics:
#   Min: -7.46, Max: -4.12, Mean: -5.44
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 3.50
#   Max: 11.04
#   Mean: 7.29
#   Total rainfall before correction: 636.33
#   Total rainfall after correction: 364.46
#   Change in total rainfall: -42.72%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2002-03.tif
#
# Processing rainfall_2002-04.tif...
# Looking for bias file with date: 2002-04
# Rainfall data statistics:
#   Min: 11.81, Max: 23.47, Mean: 14.71
# Resampling bias data...
# Bias data statistics:
#   Min: -8.34, Max: -7.09, Mean: -7.18
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 4.01
#   Max: 16.38
#   Mean: 7.53
#   Total rainfall before correction: 735.47
#   Total rainfall after correction: 376.37
#   Change in total rainfall: -48.83%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2002-04.tif
#
# Processing rainfall_2002-05.tif...
# Looking for bias file with date: 2002-05
# Rainfall data statistics:
#   Min: 18.68, Max: 55.97, Mean: 28.93
# Resampling bias data...
# Bias data statistics:
#   Min: 6.75, Max: 55.41, Mean: 17.36
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 27.05
#   Max: 83.59
#   Mean: 46.29
#   Total rainfall before correction: 1446.48
#   Total rainfall after correction: 2314.46
#   Change in total rainfall: 60.01%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2002-05.tif
#
# Processing rainfall_2002-06.tif...
# Looking for bias file with date: 2002-06
# Rainfall data statistics:
#   Min: 29.28, Max: 67.98, Mean: 48.60
# Resampling bias data...
# Bias data statistics:
#   Min: -7.60, Max: 13.71, Mean: -2.67
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 24.24
#   Max: 64.20
#   Mean: 45.93
#   Total rainfall before correction: 2430.06
#   Total rainfall after correction: 2296.75
#   Change in total rainfall: -5.49%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2002-06.tif
#
# Processing rainfall_2002-07.tif...
# Looking for bias file with date: 2002-07
# Rainfall data statistics:
#   Min: 78.15, Max: 136.90, Mean: 98.17
# Resampling bias data...
# Bias data statistics:
#   Min: -37.76, Max: -18.85, Mean: -27.38
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 44.47
#   Max: 106.13
#   Mean: 70.79
#   Total rainfall before correction: 4908.32
#   Total rainfall after correction: 3539.57
#   Change in total rainfall: -27.89%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2002-07.tif
#
# Processing rainfall_2002-08.tif...
# Looking for bias file with date: 2002-08
# Rainfall data statistics:
#   Min: 116.87, Max: 192.29, Mean: 150.02
# Resampling bias data...
# Bias data statistics:
#   Min: -5.57, Max: -5.57, Mean: -5.57
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 111.30
#   Max: 186.71
#   Mean: 144.45
#   Total rainfall before correction: 7501.15
#   Total rainfall after correction: 7222.42
#   Change in total rainfall: -3.72%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2002-08.tif
#
# Processing rainfall_2002-09.tif...
# Looking for bias file with date: 2002-09
# Rainfall data statistics:
#   Min: 67.56, Max: 147.17, Mean: 103.60
# Resampling bias data...
# Bias data statistics:
#   Min: 20.61, Max: 55.76, Mean: 23.57
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 88.30
#   Max: 187.82
#   Mean: 127.16
#   Total rainfall before correction: 5179.89
#   Total rainfall after correction: 6358.14
#   Change in total rainfall: 22.75%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2002-09.tif
#
# Processing rainfall_2002-10.tif...
# Looking for bias file with date: 2002-10
# Rainfall data statistics:
#   Min: 9.81, Max: 32.74, Mean: 14.95
# Resampling bias data...
# Bias data statistics:
#   Min: -10.95, Max: -6.11, Mean: -7.44
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 0.29
#   Max: 26.48
#   Mean: 7.51
#   Total rainfall before correction: 747.37
#   Total rainfall after correction: 375.29
#   Change in total rainfall: -49.78%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2002-10.tif
#
# Processing rainfall_2002-11.tif...
# Looking for bias file with date: 2002-11
# Rainfall data statistics:
#   Min: 1.73, Max: 17.53, Mean: 3.69
# Resampling bias data...
# Bias data statistics:
#   Min: -2.78, Max: -1.33, Mean: -1.71
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 5 pixels (10.00%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 15.92
#   Mean: 2.01
#   Total rainfall before correction: 184.55
#   Total rainfall after correction: 100.50
#   Change in total rainfall: -45.54%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2002-11.tif
#
# Processing rainfall_2002-12.tif...
# Looking for bias file with date: 2002-12
# Rainfall data statistics:
#   Min: 2.64, Max: 8.68, Mean: 4.04
# Resampling bias data...
# Bias data statistics:
#   Min: 1.33, Max: 4.81, Mean: 2.46
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 4.18
#   Max: 13.49
#   Mean: 6.50
#   Total rainfall before correction: 201.89
#   Total rainfall after correction: 325.01
#   Change in total rainfall: 60.98%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2002-12.tif
#
# Processing rainfall_2003-01.tif...
# Looking for bias file with date: 2003-01
# Rainfall data statistics:
#   Min: 8.38, Max: 15.41, Mean: 12.42
# Resampling bias data...
# Bias data statistics:
#   Min: 1.58, Max: 1.58, Mean: 1.58
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 9.96
#   Max: 16.99
#   Mean: 14.00
#   Total rainfall before correction: 621.16
#   Total rainfall after correction: 700.21
#   Change in total rainfall: 12.73%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2003-01.tif
#
# Processing rainfall_2003-02.tif...
# Looking for bias file with date: 2003-02
# Rainfall data statistics:
#   Min: 18.61, Max: 24.34, Mean: 21.45
# Resampling bias data...
# Bias data statistics:
#   Min: 6.84, Max: 32.00, Mean: 10.66
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 26.50
#   Max: 54.86
#   Mean: 32.11
#   Total rainfall before correction: 1072.67
#   Total rainfall after correction: 1605.56
#   Change in total rainfall: 49.68%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2003-02.tif
#
# Processing rainfall_2003-03.tif...
# Looking for bias file with date: 2003-03
# Rainfall data statistics:
#   Min: 11.99, Max: 25.87, Mean: 14.73
# Resampling bias data...
# Bias data statistics:
#   Min: -3.74, Max: -3.74, Mean: -3.74
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 8.25
#   Max: 22.14
#   Mean: 11.00
#   Total rainfall before correction: 736.69
#   Total rainfall after correction: 549.92
#   Change in total rainfall: -25.35%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2003-03.tif
#
# Processing rainfall_2003-04.tif...
# Looking for bias file with date: 2003-04
# Rainfall data statistics:
#   Min: 11.81, Max: 29.89, Mean: 16.11
# Resampling bias data...
# Bias data statistics:
#   Min: -13.27, Max: -6.05, Mean: -9.83
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 1 pixels (2.00%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 23.53
#   Mean: 6.28
#   Total rainfall before correction: 805.49
#   Total rainfall after correction: 314.13
#   Change in total rainfall: -61.00%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2003-04.tif
#
# Processing rainfall_2003-05.tif...
# Looking for bias file with date: 2003-05
# Rainfall data statistics:
#   Min: 18.36, Max: 54.88, Mean: 25.14
# Resampling bias data...
# Bias data statistics:
#   Min: -18.23, Max: -7.89, Mean: -12.20
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 3.20
#   Max: 41.60
#   Mean: 12.95
#   Total rainfall before correction: 1257.19
#   Total rainfall after correction: 647.42
#   Change in total rainfall: -48.50%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2003-05.tif
#
# Processing rainfall_2003-06.tif...
# Looking for bias file with date: 2003-06
# Rainfall data statistics:
#   Min: 34.92, Max: 67.08, Mean: 47.63
# Resampling bias data...
# Bias data statistics:
#   Min: -18.75, Max: 13.13, Mean: -7.45
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 22.98
#   Max: 70.60
#   Mean: 40.18
#   Total rainfall before correction: 2381.49
#   Total rainfall after correction: 2008.75
#   Change in total rainfall: -15.65%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2003-06.tif
#
# Processing rainfall_2003-07.tif...
# Looking for bias file with date: 2003-07
# Rainfall data statistics:
#   Min: 86.02, Max: 179.35, Mean: 131.32
# Resampling bias data...
# Bias data statistics:
#   Min: 16.03, Max: 399.41, Mean: 194.39
#   Warning: Average bias magnitude exceeds average rainfall. Check bias calculation.
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 183.30
#   Max: 500.55
#   Mean: 325.72
#   Total rainfall before correction: 6566.20
#   Total rainfall after correction: 16285.84
#   Change in total rainfall: 148.03%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2003-07.tif
#
# Processing rainfall_2003-08.tif...
# Looking for bias file with date: 2003-08
# Rainfall data statistics:
#   Min: 90.39, Max: 161.07, Mean: 125.23
# Resampling bias data...
# Bias data statistics:
#   Min: 20.47, Max: 161.23, Mean: 85.55
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 112.72
#   Max: 296.41
#   Mean: 210.78
#   Total rainfall before correction: 6261.74
#   Total rainfall after correction: 10539.25
#   Change in total rainfall: 68.31%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2003-08.tif
#
# Processing rainfall_2003-09.tif...
# Looking for bias file with date: 2003-09
# Rainfall data statistics:
#   Min: 80.11, Max: 154.42, Mean: 119.52
# Resampling bias data...
# Bias data statistics:
#   Min: -2.04, Max: 19.72, Mean: 1.02
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 80.58
#   Max: 152.98
#   Mean: 120.54
#   Total rainfall before correction: 5976.19
#   Total rainfall after correction: 6027.19
#   Change in total rainfall: 0.85%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2003-09.tif
#
# Processing rainfall_2003-10.tif...
# Looking for bias file with date: 2003-10
# Rainfall data statistics:
#   Min: 10.00, Max: 39.27, Mean: 13.63
# Resampling bias data...
# Bias data statistics:
#   Min: -9.39, Max: -6.69, Mean: -7.00
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 2.13
#   Max: 32.58
#   Mean: 6.63
#   Total rainfall before correction: 681.51
#   Total rainfall after correction: 331.66
#   Change in total rainfall: -51.33%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2003-10.tif
#
# Processing rainfall_2003-11.tif...
# Looking for bias file with date: 2003-11
# Rainfall data statistics:
#   Min: 1.73, Max: 42.58, Mean: 4.91
# Resampling bias data...
# Bias data statistics:
#   Min: -4.30, Max: -2.12, Mean: -2.22
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 14 pixels (28.00%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 40.46
#   Mean: 2.77
#   Total rainfall before correction: 245.25
#   Total rainfall after correction: 138.38
#   Change in total rainfall: -43.58%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2003-11.tif
#
# Processing rainfall_2003-12.tif...
# Looking for bias file with date: 2003-12
# Rainfall data statistics:
#   Min: 3.18, Max: 13.66, Mean: 7.47
# Resampling bias data...
# Bias data statistics:
#   Min: 0.75, Max: 17.74, Mean: 6.20
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 3.93
#   Max: 29.19
#   Mean: 13.67
#   Total rainfall before correction: 373.55
#   Total rainfall after correction: 683.38
#   Change in total rainfall: 82.94%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2003-12.tif
#
# Processing rainfall_2004-01.tif...
# Looking for bias file with date: 2004-01
# Rainfall data statistics:
#   Min: 8.06, Max: 15.47, Mean: 11.31
# Resampling bias data...
# Bias data statistics:
#   Min: 0.87, Max: 9.84, Mean: 4.50
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 10.04
#   Max: 24.21
#   Mean: 15.81
#   Total rainfall before correction: 565.61
#   Total rainfall after correction: 790.44
#   Change in total rainfall: 39.75%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2004-01.tif
#
# Processing rainfall_2004-02.tif...
# Looking for bias file with date: 2004-02
# Rainfall data statistics:
#   Min: 10.04, Max: 16.24, Mean: 12.79
# Resampling bias data...
# Bias data statistics:
#   Min: -7.24, Max: -4.06, Mean: -5.16
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 3.90
#   Max: 10.73
#   Mean: 7.64
#   Total rainfall before correction: 639.63
#   Total rainfall after correction: 381.84
#   Change in total rainfall: -40.30%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2004-02.tif
#
# Processing rainfall_2004-03.tif...
# Looking for bias file with date: 2004-03
# Rainfall data statistics:
#   Min: 9.59, Max: 14.86, Mean: 11.47
# Resampling bias data...
# Bias data statistics:
#   Min: -8.04, Max: -3.88, Mean: -5.90
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 2.73
#   Max: 8.95
#   Mean: 5.57
#   Total rainfall before correction: 573.42
#   Total rainfall after correction: 278.64
#   Change in total rainfall: -51.41%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2004-03.tif
#
# Processing rainfall_2004-04.tif...
# Looking for bias file with date: 2004-04
# Rainfall data statistics:
#   Min: 12.07, Max: 45.32, Mean: 22.30
# Resampling bias data...
# Bias data statistics:
#   Min: -2.35, Max: 0.80, Mean: -1.14
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 10.01
#   Max: 44.12
#   Mean: 21.16
#   Total rainfall before correction: 1115.03
#   Total rainfall after correction: 1058.04
#   Change in total rainfall: -5.11%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2004-04.tif
#
# Processing rainfall_2004-05.tif...
# Looking for bias file with date: 2004-05
# Rainfall data statistics:
#   Min: 17.36, Max: 40.19, Mean: 20.74
# Resampling bias data...
# Bias data statistics:
#   Min: 3.20, Max: 19.25, Mean: 8.60
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 21.65
#   Max: 52.96
#   Mean: 29.33
#   Total rainfall before correction: 1036.87
#   Total rainfall after correction: 1466.71
#   Change in total rainfall: 41.45%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2004-05.tif
#
# Processing rainfall_2004-06.tif...
# Looking for bias file with date: 2004-06
# Rainfall data statistics:
#   Min: 29.31, Max: 67.84, Mean: 43.76
# Resampling bias data...
# Bias data statistics:
#   Min: -4.24, Max: -3.54, Mean: -3.83
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 25.13
#   Max: 64.02
#   Mean: 39.93
#   Total rainfall before correction: 2187.82
#   Total rainfall after correction: 1996.55
#   Change in total rainfall: -8.74%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2004-06.tif
#
# Processing rainfall_2004-07.tif...
# Looking for bias file with date: 2004-07
# Rainfall data statistics:
#   Min: 73.88, Max: 153.54, Mean: 102.12
# Resampling bias data...
# Bias data statistics:
#   Min: -39.57, Max: -15.10, Mean: -21.38
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 47.88
#   Max: 125.41
#   Mean: 80.74
#   Total rainfall before correction: 5106.14
#   Total rainfall after correction: 4037.20
#   Change in total rainfall: -20.93%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2004-07.tif
#
# Processing rainfall_2004-08.tif...
# Looking for bias file with date: 2004-08
# Rainfall data statistics:
#   Min: 103.50, Max: 176.47, Mean: 145.66
# Resampling bias data...
# Bias data statistics:
#   Min: 23.24, Max: 237.75, Mean: 115.40
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 159.63
#   Max: 400.56
#   Mean: 261.06
#   Total rainfall before correction: 7283.13
#   Total rainfall after correction: 13053.09
#   Change in total rainfall: 79.22%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2004-08.tif
#
# Processing rainfall_2004-09.tif...
# Looking for bias file with date: 2004-09
# Rainfall data statistics:
#   Min: 58.83, Max: 128.02, Mean: 84.32
# Resampling bias data...
# Bias data statistics:
#   Min: -35.22, Max: -18.04, Mean: -23.17
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 30.48
#   Max: 108.44
#   Mean: 61.15
#   Total rainfall before correction: 4216.10
#   Total rainfall after correction: 3057.42
#   Change in total rainfall: -27.48%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2004-09.tif
#
# Processing rainfall_2004-10.tif...
# Looking for bias file with date: 2004-10
# Rainfall data statistics:
#   Min: 13.89, Max: 50.67, Mean: 28.86
# Resampling bias data...
# Bias data statistics:
#   Min: 17.81, Max: 17.81, Mean: 17.81
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 31.71
#   Max: 68.48
#   Mean: 46.67
#   Total rainfall before correction: 1442.91
#   Total rainfall after correction: 2333.51
#   Change in total rainfall: 61.72%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2004-10.tif
#
# Processing rainfall_2004-11.tif...
# Looking for bias file with date: 2004-11
# Rainfall data statistics:
#   Min: 1.72, Max: 16.30, Mean: 3.10
# Resampling bias data...
# Bias data statistics:
#   Min: -2.44, Max: -1.11, Mean: -1.72
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 8 pixels (16.00%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 14.76
#   Mean: 1.43
#   Total rainfall before correction: 154.92
#   Total rainfall after correction: 71.37
#   Change in total rainfall: -53.93%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2004-11.tif
#
# Processing rainfall_2004-12.tif...
# Looking for bias file with date: 2004-12
# Rainfall data statistics:
#   Min: 2.99, Max: 11.73, Mean: 4.77
# Resampling bias data...
# Bias data statistics:
#   Min: -1.94, Max: -1.94, Mean: -1.94
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 1.05
#   Max: 9.79
#   Mean: 2.82
#   Total rainfall before correction: 238.42
#   Total rainfall after correction: 141.22
#   Change in total rainfall: -40.77%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2004-12.tif
#
# Processing rainfall_2005-01.tif...
# Looking for bias file with date: 2005-01
# Rainfall data statistics:
#   Min: 7.48, Max: 15.01, Mean: 9.99
# Resampling bias data...
# Bias data statistics:
#   Min: -1.91, Max: -1.91, Mean: -1.91
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 5.57
#   Max: 13.10
#   Mean: 8.08
#   Total rainfall before correction: 499.50
#   Total rainfall after correction: 404.03
#   Change in total rainfall: -19.11%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2005-01.tif
#
# Processing rainfall_2005-02.tif...
# Looking for bias file with date: 2005-02
# Rainfall data statistics:
#   Min: 12.33, Max: 23.76, Mean: 19.61
# Resampling bias data...
# Bias data statistics:
#   Min: 3.54, Max: 24.37, Mean: 13.25
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 22.62
#   Max: 46.32
#   Mean: 32.86
#   Total rainfall before correction: 980.74
#   Total rainfall after correction: 1643.19
#   Change in total rainfall: 67.54%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2005-02.tif
#
# Processing rainfall_2005-03.tif...
# Looking for bias file with date: 2005-03
# Rainfall data statistics:
#   Min: 10.73, Max: 19.93, Mean: 13.66
# Resampling bias data...
# Bias data statistics:
#   Min: 0.40, Max: 8.07, Mean: 2.82
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 13.14
#   Max: 24.52
#   Mean: 16.48
#   Total rainfall before correction: 683.06
#   Total rainfall after correction: 824.06
#   Change in total rainfall: 20.64%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2005-03.tif
#
# Processing rainfall_2005-04.tif...
# Looking for bias file with date: 2005-04
# Rainfall data statistics:
#   Min: 12.00, Max: 33.54, Mean: 19.07
# Resampling bias data...
# Bias data statistics:
#   Min: -14.52, Max: -6.57, Mean: -9.11
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 0.39
#   Max: 23.51
#   Mean: 9.96
#   Total rainfall before correction: 953.37
#   Total rainfall after correction: 497.93
#   Change in total rainfall: -47.77%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2005-04.tif
#
# Processing rainfall_2005-05.tif...
# Looking for bias file with date: 2005-05
# Rainfall data statistics:
#   Min: 16.79, Max: 23.20, Mean: 18.56
# Resampling bias data...
# Bias data statistics:
#   Min: -4.53, Max: -4.53, Mean: -4.53
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 12.25
#   Max: 18.67
#   Mean: 14.03
#   Total rainfall before correction: 928.22
#   Total rainfall after correction: 701.52
#   Change in total rainfall: -24.42%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2005-05.tif
#
# Processing rainfall_2005-06.tif...
# Looking for bias file with date: 2005-06
# Rainfall data statistics:
#   Min: 31.03, Max: 63.36, Mean: 39.95
# Resampling bias data...
# Bias data statistics:
#   Min: -9.27, Max: 15.28, Mean: 2.09
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 25.26
#   Max: 69.94
#   Mean: 42.04
#   Total rainfall before correction: 1997.32
#   Total rainfall after correction: 2101.81
#   Change in total rainfall: 5.23%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2005-06.tif
#
# Processing rainfall_2005-07.tif...
# Looking for bias file with date: 2005-07
# Rainfall data statistics:
#   Min: 104.89, Max: 183.31, Mean: 127.02
# Resampling bias data...
# Bias data statistics:
#   Min: 13.21, Max: 155.00, Mean: 60.26
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 127.93
#   Max: 290.52
#   Mean: 187.29
#   Total rainfall before correction: 6351.19
#   Total rainfall after correction: 9364.42
#   Change in total rainfall: 47.44%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2005-07.tif
#
# Processing rainfall_2005-08.tif...
# Looking for bias file with date: 2005-08
# Rainfall data statistics:
#   Min: 65.91, Max: 123.46, Mean: 93.79
# Resampling bias data...
# Bias data statistics:
#   Min: -21.51, Max: 1.13, Mean: -11.14
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 53.07
#   Max: 121.08
#   Mean: 82.65
#   Total rainfall before correction: 4689.43
#   Total rainfall after correction: 4132.33
#   Change in total rainfall: -11.88%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2005-08.tif
#
# Processing rainfall_2005-09.tif...
# Looking for bias file with date: 2005-09
# Rainfall data statistics:
#   Min: 96.38, Max: 159.88, Mean: 127.66
# Resampling bias data...
# Bias data statistics:
#   Min: 12.08, Max: 136.49, Mean: 65.36
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 121.68
#   Max: 262.41
#   Mean: 193.02
#   Total rainfall before correction: 6383.02
#   Total rainfall after correction: 9651.25
#   Change in total rainfall: 51.20%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2005-09.tif
#
# Processing rainfall_2005-10.tif...
# Looking for bias file with date: 2005-10
# Rainfall data statistics:
#   Min: 9.98, Max: 33.47, Mean: 12.93
# Resampling bias data...
# Bias data statistics:
#   Min: -11.87, Max: -5.58, Mean: -8.14
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 4 pixels (8.00%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 23.78
#   Mean: 4.81
#   Total rainfall before correction: 646.33
#   Total rainfall after correction: 240.37
#   Change in total rainfall: -62.81%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2005-10.tif
#
# Processing rainfall_2005-11.tif...
# Looking for bias file with date: 2005-11
# Rainfall data statistics:
#   Min: 1.64, Max: 5.52, Mean: 2.61
# Resampling bias data...
# Bias data statistics:
#   Min: -2.38, Max: -1.07, Mean: -1.49
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 4 pixels (8.00%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 3.82
#   Mean: 1.13
#   Total rainfall before correction: 130.71
#   Total rainfall after correction: 56.49
#   Change in total rainfall: -56.79%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2005-11.tif
#
# Processing rainfall_2005-12.tif...
# Looking for bias file with date: 2005-12
# Rainfall data statistics:
#   Min: 2.96, Max: 11.41, Mean: 4.86
# Resampling bias data...
# Bias data statistics:
#   Min: -1.90, Max: -1.90, Mean: -1.90
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 1.06
#   Max: 9.51
#   Mean: 2.97
#   Total rainfall before correction: 243.20
#   Total rainfall after correction: 148.31
#   Change in total rainfall: -39.02%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2005-12.tif
#
# Processing rainfall_2006-01.tif...
# Looking for bias file with date: 2006-01
# Rainfall data statistics:
#   Min: 7.46, Max: 15.14, Mean: 10.36
# Resampling bias data...
# Bias data statistics:
#   Min: -4.81, Max: -2.76, Mean: -3.07
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 4.70
#   Max: 12.31
#   Mean: 7.29
#   Total rainfall before correction: 517.93
#   Total rainfall after correction: 364.58
#   Change in total rainfall: -29.61%
# ...
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2021-01.tif
#
# Processing rainfall_2021-02.tif...
# Looking for bias file with date: 2021-02
# Rainfall data statistics:
#   Min: 9.87, Max: 25.40, Mean: 13.24
# Resampling bias data...
# Bias data statistics:
#   Min: -5.15, Max: -3.83, Mean: -3.93
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 6.04
#   Max: 21.57
#   Mean: 9.31
#   Total rainfall before correction: 661.94
#   Total rainfall after correction: 465.43
#   Change in total rainfall: -29.69%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2021-02.tif
#
# Processing rainfall_2021-03.tif...
# Looking for bias file with date: 2021-03
# Rainfall data statistics:
#   Min: 9.69, Max: 16.47, Mean: 11.83
# Resampling bias data...
# Bias data statistics:
#   Min: -5.21, Max: -1.11, Mean: -3.44
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 6.14
#   Max: 12.69
#   Mean: 8.39
#   Total rainfall before correction: 591.26
#   Total rainfall after correction: 419.45
#   Change in total rainfall: -29.06%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2021-03.tif
#
# Processing rainfall_2021-04.tif...
# Looking for bias file with date: 2021-04
# Rainfall data statistics:
#   Min: 12.10, Max: 19.04, Mean: 14.10
# Resampling bias data...
# Bias data statistics:
#   Min: -11.65, Max: -5.36, Mean: -7.93
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 1.90
#   Max: 13.50
#   Mean: 6.18
#   Total rainfall before correction: 705.21
#   Total rainfall after correction: 308.75
#   Change in total rainfall: -56.22%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2021-04.tif
#
# Processing rainfall_2021-05.tif...
# Looking for bias file with date: 2021-05
# Rainfall data statistics:
#   Min: 19.72, Max: 47.59, Mean: 37.60
# Resampling bias data...
# Bias data statistics:
#   Min: 20.28, Max: 20.28, Mean: 20.28
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 40.00
#   Max: 67.87
#   Mean: 57.87
#   Total rainfall before correction: 1879.77
#   Total rainfall after correction: 2893.57
#   Change in total rainfall: 53.93%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2021-05.tif
#
# Processing rainfall_2021-06.tif...
# Looking for bias file with date: 2021-06
# Rainfall data statistics:
#   Min: 30.10, Max: 70.15, Mean: 58.01
# Resampling bias data...
# Bias data statistics:
#   Min: -11.54, Max: -5.00, Mean: -6.63
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 23.71
#   Max: 65.15
#   Mean: 51.38
#   Total rainfall before correction: 2900.62
#   Total rainfall after correction: 2569.00
#   Change in total rainfall: -11.43%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2021-06.tif
#
# Processing rainfall_2021-07.tif...
# Looking for bias file with date: 2021-07
# Rainfall data statistics:
#   Min: 85.16, Max: 163.93, Mean: 123.19
# Resampling bias data...
# Bias data statistics:
#   Min: 6.75, Max: 308.60, Mean: 155.91
#   Warning: Average bias magnitude exceeds average rainfall. Check bias calculation.
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 98.09
#   Max: 465.59
#   Mean: 279.10
#   Total rainfall before correction: 6159.73
#   Total rainfall after correction: 13955.25
#   Change in total rainfall: 126.56%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2021-07.tif
#
# Processing rainfall_2021-08.tif...
# Looking for bias file with date: 2021-08
# Rainfall data statistics:
#   Min: 90.68, Max: 168.11, Mean: 127.37
# Resampling bias data...
# Bias data statistics:
#   Min: 13.41, Max: 27.23, Mean: 14.06
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 104.09
#   Max: 181.51
#   Mean: 141.43
#   Total rainfall before correction: 6368.40
#   Total rainfall after correction: 7071.43
#   Change in total rainfall: 11.04%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2021-08.tif
#
# Processing rainfall_2021-09.tif...
# Looking for bias file with date: 2021-09
# Rainfall data statistics:
#   Min: 92.89, Max: 177.87, Mean: 136.01
# Resampling bias data...
# Bias data statistics:
#   Min: 41.65, Max: 100.64, Mean: 50.74
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 140.63
#   Max: 257.46
#   Mean: 186.76
#   Total rainfall before correction: 6800.74
#   Total rainfall after correction: 9337.82
#   Change in total rainfall: 37.31%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2021-09.tif
#
# Processing rainfall_2021-10.tif...
# Looking for bias file with date: 2021-10
# Rainfall data statistics:
#   Min: 10.70, Max: 32.29, Mean: 19.61
# Resampling bias data...
# Bias data statistics:
#   Min: 7.58, Max: 52.18, Mean: 20.38
#   Warning: Average bias magnitude exceeds average rainfall. Check bias calculation.
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 20.54
#   Max: 75.40
#   Mean: 39.99
#   Total rainfall before correction: 980.57
#   Total rainfall after correction: 1999.74
#   Change in total rainfall: 103.94%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2021-10.tif
#
# Processing rainfall_2021-11.tif...
# Looking for bias file with date: 2021-11
# Rainfall data statistics:
#   Min: 2.28, Max: 6.41, Mean: 3.01
# Resampling bias data...
# Bias data statistics:
#   Min: -2.48, Max: -1.16, Mean: -1.74
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Warning: 1 pixels (2.00%) would have negative rainfall after bias correction
# Setting these values to zero
# Valid corrected data statistics:
#   Min: 0.00
#   Max: 4.36
#   Mean: 1.27
#   Total rainfall before correction: 150.37
#   Total rainfall after correction: 63.31
#   Change in total rainfall: -57.90%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2021-11.tif
#
# Processing rainfall_2021-12.tif...
# Looking for bias file with date: 2021-12
# Rainfall data statistics:
#   Min: 4.34, Max: 8.96, Mean: 5.99
# Resampling bias data...
# Bias data statistics:
#   Min: -1.29, Max: -0.59, Mean: -1.05
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 3.27
#   Max: 7.89
#   Mean: 4.94
#   Total rainfall before correction: 299.69
#   Total rainfall after correction: 247.10
#   Change in total rainfall: -17.55%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2021-12.tif
#
# Processing rainfall_2022-01.tif...
# Looking for bias file with date: 2022-01
# Rainfall data statistics:
#   Min: 9.11, Max: 16.11, Mean: 13.06
# Resampling bias data...
# Bias data statistics:
#   Min: 20.86, Max: 20.86, Mean: 20.86
#   Warning: Average bias magnitude exceeds average rainfall. Check bias calculation.
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 29.98
#   Max: 36.98
#   Mean: 33.92
#   Total rainfall before correction: 652.94
#   Total rainfall after correction: 1696.11
#   Change in total rainfall: 159.77%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2022-01.tif
#
# Processing rainfall_2022-02.tif...
# Looking for bias file with date: 2022-02
# Rainfall data statistics:
#   Min: 12.55, Max: 22.14, Mean: 17.93
# Resampling bias data...
# Bias data statistics:
#   Min: 0.75, Max: 3.80, Mean: 1.25
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 13.33
#   Max: 24.86
#   Mean: 19.17
#   Total rainfall before correction: 896.27
#   Total rainfall after correction: 958.57
#   Change in total rainfall: 6.95%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2022-02.tif
#
# Processing rainfall_2022-03.tif...
# Looking for bias file with date: 2022-03
# Rainfall data statistics:
#   Min: 9.87, Max: 13.84, Mean: 11.24
# Resampling bias data...
# Bias data statistics:
#   Min: -8.17, Max: -3.74, Mean: -5.98
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 2.76
#   Max: 8.99
#   Mean: 5.25
#   Total rainfall before correction: 561.91
#   Total rainfall after correction: 262.70
#   Change in total rainfall: -53.25%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2022-03.tif
#
# Processing rainfall_2022-04.tif...
# Looking for bias file with date: 2022-04
# Rainfall data statistics:
#   Min: 12.37, Max: 17.99, Mean: 14.16
# Resampling bias data...
# Bias data statistics:
#   Min: -11.98, Max: -6.42, Mean: -8.17
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 1.63
#   Max: 11.02
#   Mean: 5.99
#   Total rainfall before correction: 708.04
#   Total rainfall after correction: 299.65
#   Change in total rainfall: -57.68%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2022-04.tif
#
# Processing rainfall_2022-05.tif...
# Looking for bias file with date: 2022-05
# Rainfall data statistics:
#   Min: 17.98, Max: 47.23, Mean: 31.09
# Resampling bias data...
# Bias data statistics:
#   Min: 0.75, Max: 29.26, Mean: 13.30
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 23.08
#   Max: 66.60
#   Mean: 44.39
#   Total rainfall before correction: 1554.54
#   Total rainfall after correction: 2219.39
#   Change in total rainfall: 42.77%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2022-05.tif
#
# Processing rainfall_2022-06.tif...
# Looking for bias file with date: 2022-06
# Rainfall data statistics:
#   Min: 29.53, Max: 65.63, Mean: 49.27
# Resampling bias data...
# Bias data statistics:
#   Min: -13.32, Max: 15.02, Mean: -2.48
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 34.00
#   Max: 58.40
#   Mean: 46.79
#   Total rainfall before correction: 2463.58
#   Total rainfall after correction: 2339.42
#   Change in total rainfall: -5.04%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2022-06.tif
#
# Processing rainfall_2022-07.tif...
# Looking for bias file with date: 2022-07
# Rainfall data statistics:
#   Min: 103.98, Max: 184.57, Mean: 138.32
# Resampling bias data...
# Bias data statistics:
#   Min: 4.89, Max: 133.25, Mean: 57.51
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 110.79
#   Max: 290.61
#   Mean: 195.83
#   Total rainfall before correction: 6915.98
#   Total rainfall after correction: 9791.69
#   Change in total rainfall: 41.58%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2022-07.tif
#
# Processing rainfall_2022-08.tif...
# Looking for bias file with date: 2022-08
# Rainfall data statistics:
#   Min: 80.42, Max: 141.53, Mean: 105.64
# Resampling bias data...
# Bias data statistics:
#   Min: -32.66, Max: 2.89, Mean: -11.32
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 67.96
#   Max: 133.90
#   Mean: 94.31
#   Total rainfall before correction: 5281.77
#   Total rainfall after correction: 4715.67
#   Change in total rainfall: -10.72%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2022-08.tif
#
# Processing rainfall_2022-09.tif...
# Looking for bias file with date: 2022-09
# Rainfall data statistics:
#   Min: 85.71, Max: 174.74, Mean: 122.24
# Resampling bias data...
# Bias data statistics:
#   Min: 5.91, Max: 120.77, Mean: 56.17
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 112.44
#   Max: 265.31
#   Mean: 178.41
#   Total rainfall before correction: 6112.17
#   Total rainfall after correction: 8920.67
#   Change in total rainfall: 45.95%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2022-09.tif
#
# Processing rainfall_2022-10.tif...
# Looking for bias file with date: 2022-10
# Rainfall data statistics:
#   Min: 13.66, Max: 46.34, Mean: 29.39
# Resampling bias data...
# Bias data statistics:
#   Min: 18.65, Max: 18.65, Mean: 18.65
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 32.31
#   Max: 65.00
#   Mean: 48.04
#   Total rainfall before correction: 1469.48
#   Total rainfall after correction: 2402.22
#   Change in total rainfall: 63.47%
#   WARNING: Very large change in total rainfall after bias correction!
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2022-10.tif
#
# Processing rainfall_2022-11.tif...
# Looking for bias file with date: 2022-11
# Rainfall data statistics:
#   Min: 1.86, Max: 4.40, Mean: 2.79
# Resampling bias data...
# Bias data statistics:
#   Min: -1.84, Max: -1.28, Mean: -1.35
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 0.58
#   Max: 3.13
#   Mean: 1.44
#   Total rainfall before correction: 139.27
#   Total rainfall after correction: 71.99
#   Change in total rainfall: -48.31%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2022-11.tif
#
# Processing rainfall_2022-12.tif...
# Looking for bias file with date: 2022-12
# Rainfall data statistics:
#   Min: 2.73, Max: 5.90, Mean: 3.85
# Resampling bias data...
# Bias data statistics:
#   Min: -2.19, Max: -1.33, Mean: -1.75
#   Note: Bias is predominantly negative while rainfall is positive
# Applying bias correction with validation...
# Valid corrected data statistics:
#   Min: 0.78
#   Max: 4.28
#   Mean: 2.09
#   Total rainfall before correction: 192.35
#   Total rainfall after correction: 104.71
#   Change in total rainfall: -45.56%
# Successfully processed: /home/stormej/dev/rainscale/data/bias_corrected/bias_corrected_kriging_0.1/corrected_rainfall_2022-12.tif
#
# Processing rainfall_2023-01.tif...
# Looking for bias file with date: 2023-01
# Skipping 2023-01, no matching bias file found.
#
# Processing rainfall_2023-02.tif...
# Looking for bias file with date: 2023-02
# Skipping 2023-02, no matching bias file found.
#
# Processing Summary:
# Total files: 277
# Successfully processed: 275
# Skipped: 2
# Errors: 0
# Correction completed!
